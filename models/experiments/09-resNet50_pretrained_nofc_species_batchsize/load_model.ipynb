# %%
# %config IPCompleter.greedy=True

# %%
import sys
import os
import pandas as pd
sys.path.append("../..") # relative path to module toolkit

# %%
#from keras.applications import ResNet50
#from keras.layers import Dense, GlobalAveragePooling2D
from keras.models import Model, load_model
from keras_preprocessing.image import ImageDataGenerator
from toolkit import getLabelsFromDir, plot_confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# setup
batch_size = 1
val_dir = "../../../images/images_species/val/"
val_images = 3381
datasetDir = "images_species/"
saved_model = 'resNet50pretrained_highest_val_acc.h5'
results_file = "results.csv"

# %%
labels = getLabelsFromDir(val_dir)
val_datagen = ImageDataGenerator(rescale=1./255.)
validation_steps = int(val_images/batch_size)

# %%
model = load_model(saved_model)

# %%
val_generator = val_datagen.flow_from_directory(val_dir,
                                                    classes=labels,
                                                    class_mode="categorical",
                                                    batch_size=batch_size,
                                                    color_mode='rgb',
                                                    target_size=(224, 224),
                                                    shuffle=False,
                                                    seed=1)
# Out:
# Found 3381 images belonging to 200 classes.

# %%
Y_pred = model.predict_generator(val_generator, steps=validation_steps, verbose=1)
# Out:
# 3381/3381 [==============================] - 50s 15ms/step

# %%
y_pred = np.argmax(Y_pred, axis=1)
y_pred3 = [y[-3:] for y in np.argsort(Y_pred, axis=1)]

# %%
def classification_report_csv(report):
    report_data = []
    lines = report.split('\n')
    for line in lines[2:-3]:
        row = {}
        if line == '':
            continue
        row_data = line.split(' ')
        row_data = [data for data in row_data if data]
        row['class'] = row_data[0] + " " + row_data[1]
        row['precision'] = float(row_data[2])
        row['recall'] = float(row_data[3])
        row['f1_score'] = float(row_data[4])
        row['support'] = float(row_data[5])
        report_data.append(row)
    dataframe = pd.DataFrame.from_dict(report_data)
    dataframe.to_csv('classification_report2.csv', index = False)

# %%
report = classification_report(val_generator.classes, y_pred, target_names=labels)
classification_report_csv(report)
print(report)
# Out:
#                              precision    recall  f1-score   support
#
#      Philonthus tenuicornis       0.36      0.78      0.49        27
#       Paederidus ruficollis       1.00      1.00      1.00        49
#        Philonthus splendens       0.92      0.94      0.93        35
#     Pseudomedon obscurellus       1.00      1.00      1.00        29
#   Staphylinus erythropterus       1.00      0.88      0.93         8
#     Lobrathium multipunctum       0.94      0.77      0.85        22
#     Philonthus nitidicollis       1.00      0.50      0.67         2
#         Xantholinus dvoraki       0.64      1.00      0.78         7
#          Lathrobium geminum       0.65      0.61      0.63        18
#           Paederus riparius       0.98      0.96      0.97        56
#        Heterothops praevius       0.85      1.00      0.92        11
#           Gabrius osseticus       0.83      0.77      0.80        13
#      Philonthus carbonarius       0.91      0.73      0.81        71
#          Quedius semiaeneus       0.64      1.00      0.78         9
#           Cafius xantholoma       0.98      1.00      0.99        58
#          Othius punctulatus       1.00      0.91      0.95        11
#       Heterothops binotatus       0.55      0.80      0.65        15
#        Philonthus succicola       0.73      0.50      0.59        44
#      Philonthus rectangulus       0.80      1.00      0.89        16
#         Ocypus ophthalmicus       1.00      0.67      0.80         6
#          Quedius maurorufus       0.92      0.71      0.80        17
#           Quedius suturalis       0.89      1.00      0.94        16
#     Ontholestes tessellatus       0.88      1.00      0.93         7
#        Bisnius subuliformis       0.93      1.00      0.96        13
#          Philonthus lepidus       0.85      0.92      0.88        12
# Heterothops quadripunctulus       0.82      0.75      0.78        12
#         Philonthus addendus       0.83      0.28      0.42        18
#           Quedius auricomus       0.92      1.00      0.96        12
#          Philonthus punctus       1.00      0.75      0.86         8
#          Quedius levicollis       1.00      0.44      0.62         9
#                Ocypus olens       0.83      1.00      0.91         5
#        Ocypus aeneocephalus       1.00      1.00      1.00         9
#    Ochthephilum fracticorne       0.97      0.92      0.94        37
#              Quedius scitus       0.90      1.00      0.95         9
#      Philonthus mannerheimi       0.47      0.82      0.60        11
#  Acylophorus wagenschieberi       1.00      1.00      1.00         8
#        Astenus immacullatus       1.00      1.00      1.00        26
#         Quedius brevicornis       0.83      0.77      0.80        13
#         Quedius fuliginosus       0.87      0.93      0.90        14
#      Tetartopeus terminatus       0.93      0.89      0.91        45
#        Platydracus fulvipes       1.00      0.86      0.92         7
#       Philonthus cruentatus       0.67      1.00      0.80         8
#         Quedius scintillans       0.93      0.78      0.85        18
#         Megalinus glabratus       0.88      1.00      0.93         7
#           Heterothops niger       0.89      0.89      0.89         9
#           Quedius lateralis       1.00      0.92      0.96        12
#        Philonthus corruscus       1.00      1.00      1.00         4
#           Tasgius morsitans       1.00      1.00      1.00         9
#              Medon ripicola       0.89      0.50      0.64        16
#      Gyrohypnus punctulatus       0.86      0.35      0.50        17
#             Quedius cinctus       0.81      0.93      0.87        14
#      Philonthus longicornis       0.75      0.38      0.50        16
#            Astenus gracilis       0.52      0.63      0.57        19
#        Lathrobium brunnipes       0.95      0.95      0.95        58
#        Bisnius pseudoparcus       1.00      1.00      1.00         5
#          Quedius infuscatus       1.00      0.75      0.86         4
#              Quedius maurus       0.75      0.60      0.67        10
#          Quedius persimilis       0.62      0.83      0.71        12
#         Gabrius breviventer       0.25      0.29      0.27        17
#            Scopaeus minutus       0.79      1.00      0.88        19
#            Bisnius sordidus       0.87      0.82      0.85        50
#               Ocypus nitens       0.93      1.00      0.96        13
#          Tasgius melanarius       1.00      1.00      1.00        11
#        Gauropterus fulgidus       1.00      0.93      0.96        14
#        Xantholinus gallicus       0.00      0.00      0.00         2
#          Gabrius nigritulus       0.50      0.08      0.13        26
#       Philonthus marginatus       0.94      1.00      0.97        33
#      Philonthus rubripennis       1.00      1.00      1.00        17
#       Lathrobium fulvipenne       0.83      0.92      0.87        49
#              Sunius bicolor       0.86      1.00      0.92        18
#          Tasgius globulifer       1.00      1.00      1.00         5
#            Astenus procerus       1.00      0.60      0.75        15
#      Gabrius appendiculatus       0.37      0.92      0.52        12
#          Philonthus rufipes       0.64      0.58      0.61        12
#               Quedius boops       0.62      0.71      0.67         7
#            Quedius cruentus       0.94      0.79      0.86        19
#          Velleius dilatatus       1.00      1.00      1.00         5
#    Neobisnius lathrobioides       0.96      0.87      0.91        30
#         Quedius fulvicollis       1.00      0.50      0.67         2
#              Medon brunneus       0.83      0.94      0.88        16
#          Philonthus jurgans       0.12      0.25      0.17         8
#        Scopaeus sulcicollis       1.00      0.71      0.83        17
#   Philonthus quisquiliarius       0.69      0.85      0.76        13
#       Gyrohypnus angustatus       0.75      1.00      0.86         9
#       Staphylinus caesareus       0.00      0.00      0.00         5
#           Quedius xanthopus       0.65      1.00      0.78        20
#        Lithocharis ochracea       1.00      0.92      0.96        39
#              Bisnius parcus       1.00      0.71      0.83         7
#        Philonthus binotatus       1.00      0.25      0.40         4
#      Quedius nigrocaeruleus       0.33      1.00      0.50         4
#       Pseudomedon obsoletus       1.00      1.00      1.00        12
#          Philonthus varians       0.77      0.77      0.77        13
#          Gyrohypnus atratus       1.00      0.80      0.89        10
#         Ontholestes murinus       0.92      1.00      0.96        11
#      Xantholinus laevigatus       0.80      0.67      0.73         6
#         Leptacinus pusillus       0.50      1.00      0.67         6
#          Lathrobium fovulum       0.93      0.90      0.91        29
#              Quedius brevis       1.00      0.88      0.93         8
#         Paederus littoralis       1.00      0.97      0.99        38
#             Achenium humile       0.89      1.00      0.94         8
#           Paederus fuscipes       0.93      1.00      0.97        28
#          Quedius truncicola       0.80      1.00      0.89         4
#        Quedius puncticollis       0.88      0.94      0.91        16
#             Quedius microps       0.95      1.00      0.98        21
#         Quedius longicornis       0.94      1.00      0.97        15
#       Quedius simplicifrons       0.64      1.00      0.78         7
#          Astenus pulchellus       0.78      1.00      0.88        25
#         Quedius mesomelinus       1.00      0.67      0.80        15
#      Dinothenarus pubescens       1.00      1.00      1.00         8
#        Xantholinus tricolor       0.93      1.00      0.97        14
#         Philonthus cognatus       0.95      0.81      0.88        70
#         Rugilus orbiculatus       0.85      0.93      0.89        59
#     Erichsonius cinerascens       0.97      0.94      0.96        36
#             Medon castaneus       1.00      1.00      1.00         9
#        Gabrius splendidulus       0.72      0.95      0.82        19
#     Platydracus latebricola       1.00      0.80      0.89         5
#             Rugilus rufipes       0.98      1.00      0.99        49
#       Creophilus maxillosus       1.00      1.00      1.00         9
#        Lathrobium elongatum       0.93      0.79      0.85        48
#      Philonthus micantoides       0.80      1.00      0.89         4
#    Xantholinus longiventris       0.53      0.91      0.67        11
#         Lathrobium pallidum       0.82      1.00      0.90         9
#       Sunius melanocephalus       1.00      0.87      0.93        23
#          Quedius molochinus       0.92      0.86      0.89        14
#           Gabrius trossulus       0.83      1.00      0.91        10
#      Heterothops dissimilis       0.00      0.00      0.00         7
#      Philonthus intermedius       0.81      0.87      0.84        15
#          Philonthus alpinus       0.50      0.25      0.33         4
#             Quedius picipes       0.85      0.92      0.88        12
#        Lathrobium impressum       0.98      0.96      0.97        54
#       Philonthus discoideus       0.71      1.00      0.83        20
#           Quedius nigriceps       1.00      1.00      1.00         9
#           Atrecus longiceps       0.83      1.00      0.91         5
#         Quedius curtipennis       0.75      0.43      0.55         7
#          Bisnius fimetarius       0.93      0.67      0.78        60
#          Lathrobium dilutum       0.25      0.50      0.33         2
#
#                   micro avg       0.84      0.84      0.84      3381
#                   macro avg       0.83      0.83      0.81      3381
#                weighted avg       0.86      0.84      0.84      3381
# /home/herri/.local/lib/python3.5/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
y_true = val_generator.classes
matplotlib.rcParams['figure.figsize'] = [10, 10]
plot_confusion_matrix(y_true, y_pred, np.array(labels))
# Out:
# Confusion matrix, without normalization
# [[21  0  0 ...  0  0  0]
#  [ 0 49  0 ...  0  0  0]
#  [ 0  0 33 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  3  0  0]
#  [ 1  0  0 ...  0 40  0]
#  [ 0  0  0 ...  0  0  1]]
# (<Figure size 720x720 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f05b810fe48>)

# %%
labels = (val_generator.class_indices) # dict of label:index
labels = dict((i,l) for l,i in labels.items()) # dict of index:label

# %%
# create pd.dataframe and save predictions to .csv
filenames=[datasetDir + name for name in val_generator.filenames]
y_pred_labels = [labels[y] for y in y_pred]
y_true_labels = [labels[y] for y in y_true]
y_pred3_labels = []
for i,top3 in enumerate(y_pred3):
    l = []
    for top in top3:
        l.append((labels[top], Y_pred[i][top]))
    y_pred3_labels.append(l)

results=pd.DataFrame({"Filename":filenames,
                      "Label":y_true_labels,
                      "Prediction1":y_pred_labels,
                      "Prediction3":y_pred3_labels})
results.to_csv(results_file,index=True)
