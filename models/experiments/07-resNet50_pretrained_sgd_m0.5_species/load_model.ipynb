# %%
# %config IPCompleter.greedy=True

# %%
import sys
import os
import pandas as pd
sys.path.append("../..") # relative path to module toolkit

# %%
#from keras.applications import ResNet50
#from keras.layers import Dense, GlobalAveragePooling2D
from keras.models import Model, load_model
from keras_preprocessing.image import ImageDataGenerator
from toolkit import getLabelsFromDir, plot_confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# tf.estimator package not installed.
# tf.estimator package not installed.

# %%
# setup
batch_size = 1
val_dir = "../../../images/images_species/val/"
val_images = 3381
datasetDir = "images_species/"
saved_model = 'highest_val_acc.h5'
results_file = "results.csv"

# %%
labels = getLabelsFromDir(val_dir)
val_datagen = ImageDataGenerator(rescale=1./255.)
validation_steps = int(val_images/batch_size)

# %%
model = load_model(saved_model)

# %%
val_generator = val_datagen.flow_from_directory(val_dir,
                                                    classes=labels,
                                                    class_mode="categorical",
                                                    batch_size=batch_size,
                                                    color_mode='rgb',
                                                    target_size=(224, 224),
                                                    shuffle=False,
                                                    seed=1)
# Out:
# Found 3381 images belonging to 200 classes.

# %%
Y_pred = model.predict_generator(val_generator, steps=validation_steps, verbose=1)
# Out:
# 3381/3381 [==============================] - 85s 25ms/step

# %%
y_pred = np.argmax(Y_pred, axis=1)
y_pred3 = [y[-3:] for y in np.argsort(Y_pred, axis=1)]

# %%
#print(classification_report(val_generator.classes, y_pred, target_names=labels))
print(classification_report(val_generator.classes, y_pred, target_names=labels))
# Out:
#                              precision    recall  f1-score   support
#
#             Achenium humile       0.89      1.00      0.94         8
#     Acylophorus glaberrimus       0.92      1.00      0.96        12
#  Acylophorus wagenschieberi       1.00      1.00      1.00         8
#            Astenus gracilis       0.57      0.63      0.60        19
#        Astenus immacullatus       1.00      1.00      1.00        26
#          Astenus lyonessius       0.70      0.63      0.67        30
#            Astenus procerus       1.00      0.80      0.89        15
#          Astenus pulchellus       0.77      0.92      0.84        25
#             Atrecus affinis       1.00      1.00      1.00         9
#           Atrecus longiceps       0.83      1.00      0.91         5
#          Bisnius cephalotes       0.67      0.83      0.74        35
#          Bisnius fimetarius       0.94      0.80      0.86        60
#           Bisnius nitidulus       0.93      1.00      0.97        28
#              Bisnius parcus       0.83      0.71      0.77         7
#        Bisnius pseudoparcus       0.62      1.00      0.77         5
#              Bisnius puella       0.88      1.00      0.93         7
#        Bisnius subuliformis       1.00      1.00      1.00        13
#           Cafius xantholoma       1.00      0.84      0.92        58
#       Creophilus maxillosus       1.00      0.89      0.94         9
#      Dinothenarus pubescens       0.80      1.00      0.89         8
#                 Emus hirtus       0.80      1.00      0.89         4
#     Erichsonius cinerascens       1.00      0.94      0.97        36
#           Euryporus picipes       1.00      1.00      1.00         8
#      Gabrius appendiculatus       0.80      0.67      0.73        12
#          Gabrius austriacus       0.57      0.67      0.62         6
#         Gabrius breviventer       0.57      0.71      0.63        17
#             Gabrius exiguus       0.00      0.00      0.00         3
#           Gabrius keysianus       1.00      0.88      0.93         8
#          Gabrius nigritulus       0.33      0.08      0.12        26
#           Gabrius osseticus       0.92      0.85      0.88        13
#        Gabrius splendidulus       0.64      0.95      0.77        19
#           Gabrius trossulus       0.67      1.00      0.80        10
#        Gauropterus fulgidus       0.78      1.00      0.88        14
#       Gyrohypnus angustatus       0.57      0.44      0.50         9
#          Gyrohypnus atratus       0.78      0.70      0.74        10
#     Gyrohypnus fracticornis       0.71      0.67      0.69        15
#      Gyrohypnus punctulatus       0.64      0.41      0.50        17
#       Heterothops binotatus       0.75      0.80      0.77        15
#      Heterothops dissimilis       1.00      0.43      0.60         7
#         Heterothops minutus       0.86      1.00      0.92         6
#           Heterothops niger       1.00      1.00      1.00         9
#        Heterothops praevius       0.92      1.00      0.96        11
# Heterothops quadripunctulus       1.00      1.00      1.00        12
#   Heterothops stiglundbergi       1.00      1.00      1.00         3
#        Lathrobium brunnipes       0.98      0.98      0.98        58
#          Lathrobium dilutum       1.00      0.50      0.67         2
#        Lathrobium elongatum       0.78      0.75      0.77        48
#          Lathrobium fovulum       1.00      0.90      0.95        29
#          Lathrobium geminum       0.56      0.28      0.37        18
#        Lathrobium impressum       0.98      0.96      0.97        54
#         Lathrobium pallidum       0.75      1.00      0.86         9
#        Lathrobium rufipenne       0.85      1.00      0.92        22
#        Leptacinus batychrus       0.50      0.59      0.54        22
#     Leptacinus formicetorum       0.67      1.00      0.80         8
#      Leptacinus intermedius       0.83      0.83      0.83         6
#         Leptacinus pusillus       0.50      0.50      0.50         6
#       Lithocharis nigriceps       0.94      0.94      0.94        16
#        Lithocharis ochracea       0.97      0.97      0.97        39
#     Lobrathium multipunctum       0.85      1.00      0.92        22
#              Medon apicalis       1.00      0.83      0.91        12
#              Medon brunneus       0.68      0.94      0.79        16
#             Medon castaneus       1.00      0.89      0.94         9
#              Medon ripicola       0.85      0.69      0.76        16
#         Megalinus glabratus       1.00      0.43      0.60         7
#            Bisnius sordidus       0.82      0.84      0.83        50
#        Gabronthus thermarum       0.42      1.00      0.59         5
#       Lathrobium fulvipenne       0.92      0.90      0.91        49
#    Neobisnius lathrobioides       0.93      0.90      0.92        30
#       Paederidus ruficollis       1.00      1.00      1.00        49
#          Philonthus debilis       0.79      0.95      0.86        20
#          Philonthus nitidus       1.00      1.00      1.00        32
#    Platydracus stercorarius       1.00      1.00      1.00        10
#          Quedius levicollis       0.69      1.00      0.82         9
#        Quedius semiobscurus       0.89      1.00      0.94         8
#       Neobisnius villosulus       0.78      1.00      0.88         7
#             Nudobius lentus       1.00      0.86      0.92        14
#        Ochthephilum collare       1.00      0.50      0.67         2
#    Ochthephilum fracticorne       0.95      1.00      0.97        37
#        Ocypus aeneocephalus       0.75      1.00      0.86         9
#            Ocypus brunnipes       1.00      1.00      1.00        11
#             Ocypus fuscatus       0.06      0.62      0.11         8
#               Ocypus nitens       0.72      1.00      0.84        13
#                Ocypus olens       0.83      1.00      0.91         5
#         Ocypus ophthalmicus       0.71      0.83      0.77         6
#           Ocypus picipennis       1.00      1.00      1.00        11
#         Ontholestes murinus       0.79      1.00      0.88        11
#     Ontholestes tessellatus       1.00      0.86      0.92         7
#             Othius angustus       0.93      0.78      0.85        18
#          Othius punctulatus       1.00      1.00      1.00        11
#         Othius subuliformis       0.71      0.91      0.80        11
#           Paederus fuscipes       1.00      1.00      1.00        28
#         Paederus littoralis       0.87      0.89      0.88        38
#           Paederus riparius       0.96      0.79      0.86        56
# Phacophallus parumpunctatus       0.50      1.00      0.67         6
#         Philonthus addendus       0.67      0.67      0.67        18
#          Philonthus albipes       0.79      1.00      0.88        30
#          Philonthus alpinus       0.67      0.50      0.57         4
#          Philonthus atratus       0.89      0.74      0.81        34
#        Philonthus binotatus       1.00      0.50      0.67         4
#      Philonthus carbonarius       0.90      0.73      0.81        71
#         Philonthus cognatus       0.98      0.74      0.85        70
#        Philonthus concinnus       0.77      0.71      0.74        14
#         Philonthus confinis       0.50      1.00      0.67         3
#        Philonthus corruscus       1.00      1.00      1.00         4
#         Philonthus corvinus       0.75      0.75      0.75         8
#       Philonthus cruentatus       0.62      1.00      0.76         8
#          Philonthus decorus       0.92      0.49      0.64        45
#       Philonthus discoideus       0.87      1.00      0.93        20
#         Philonthus ebeninus       0.60      1.00      0.75         6
#         Philonthus fumarius       1.00      1.00      1.00        16
#         Philonthus furcifer       1.00      0.50      0.67         8
#      Philonthus intermedius       0.39      0.80      0.52        15
#          Philonthus jurgans       0.00      0.00      0.00         8
#        Philonthus laminatus       0.87      0.79      0.83        34
#          Philonthus lepidus       0.92      1.00      0.96        12
#      Philonthus longicornis       0.88      0.44      0.58        16
#      Philonthus mannerheimi       0.31      0.73      0.43        11
#       Philonthus marginatus       1.00      0.97      0.98        33
#           Philonthus micans       1.00      0.89      0.94        18
#      Philonthus micantoides       0.57      1.00      0.73         4
#          Philonthus nigrita       1.00      1.00      1.00        11
#     Philonthus nitidicollis       0.50      0.50      0.50         2
#      Philonthus parvicornis       0.50      0.89      0.64         9
#          Philonthus politus       0.81      0.33      0.47        51
#          Philonthus punctus       0.88      0.88      0.88         8
#   Philonthus quisquiliarius       0.80      0.92      0.86        13
#      Philonthus rectangulus       0.94      1.00      0.97        16
#      Philonthus rubripennis       0.89      1.00      0.94        17
#          Philonthus rufipes       0.41      0.58      0.48        12
#          Philonthus salinus       0.92      0.85      0.88        13
#   Philonthus sanguinolentus       0.89      1.00      0.94        17
#        Philonthus splendens       0.89      0.49      0.63        35
#        Philonthus succicola       0.69      0.57      0.62        44
#      Philonthus tenuicornis       0.78      0.67      0.72        27
#          Philonthus varians       0.64      0.54      0.58        13
#        Philonthus ventralis       0.89      0.73      0.80        11
#        Platydracus fulvipes       1.00      1.00      1.00         7
#     Platydracus latebricola       0.71      1.00      0.83         5
#     Pseudomedon obscurellus       0.97      1.00      0.98        29
#       Pseudomedon obsoletus       1.00      1.00      1.00        12
#           Quedius auricomus       1.00      1.00      1.00        12
#           Quedius boopoides       0.50      1.00      0.67         6
#               Quedius boops       0.71      0.71      0.71         7
#         Quedius brevicornis       0.86      0.92      0.89        13
#              Quedius brevis       1.00      0.88      0.93         8
#             Quedius cinctus       1.00      0.86      0.92        14
#            Quedius cruentus       0.94      0.89      0.92        19
#         Quedius curtipennis       0.50      0.29      0.36         7
#            Quedius fulgidus       1.00      1.00      1.00         5
#         Quedius fuliginosus       0.79      0.79      0.79        14
#         Quedius fulvicollis       1.00      1.00      1.00         2
#             Quedius fumatus       1.00      1.00      1.00        16
#          Quedius infuscatus       1.00      1.00      1.00         4
#           Quedius lateralis       1.00      0.83      0.91        12
#         Quedius longicornis       1.00      1.00      1.00        15
#           Quedius lucidulus       0.75      0.88      0.81        17
#          Quedius maurorufus       0.84      0.94      0.89        17
#              Quedius maurus       0.82      0.90      0.86        10
#         Quedius mesomelinus       1.00      0.53      0.70        15
#             Quedius microps       1.00      1.00      1.00        21
#          Quedius molochinus       1.00      0.93      0.96        14
#           Quedius nigriceps       1.00      1.00      1.00         9
#      Quedius nigrocaeruleus       0.67      1.00      0.80         4
#          Quedius nitipennis       1.00      0.31      0.48        16
#          Quedius persimilis       0.77      0.83      0.80        12
#             Quedius picipes       1.00      1.00      1.00        12
#        Quedius puncticollis       1.00      0.88      0.93        16
#         Quedius scintillans       0.87      0.72      0.79        18
#              Quedius scitus       0.90      1.00      0.95         9
#          Quedius semiaeneus       0.69      1.00      0.82         9
#       Quedius simplicifrons       1.00      1.00      1.00         7
#           Quedius suturalis       0.94      0.94      0.94        16
#          Quedius truncicola       0.80      1.00      0.89         4
#            Quedius umbrinus       0.95      0.90      0.92        20
#           Quedius xanthopus       0.69      1.00      0.82        20
#              Remus sericeus       1.00      1.00      1.00        24
#           Rugilus erichsoni       0.90      0.84      0.87        31
#         Rugilus orbiculatus       0.91      0.83      0.87        59
#             Rugilus rufipes       0.98      1.00      0.99        49
#         Scopaeus laevigatus       1.00      1.00      1.00         2
#            Scopaeus minutus       0.73      1.00      0.84        19
#        Scopaeus sulcicollis       1.00      0.53      0.69        17
#       Staphylinus caesareus       1.00      0.80      0.89         5
# Staphylinus dimidiaticornis       0.80      1.00      0.89         4
#   Staphylinus erythropterus       1.00      1.00      1.00         8
#              Sunius bicolor       0.89      0.94      0.92        18
#       Sunius melanocephalus       0.96      0.96      0.96        23
#                Tasgius ater       1.00      0.71      0.83         7
#          Tasgius globulifer       1.00      1.00      1.00         5
#          Tasgius melanarius       1.00      0.55      0.71        11
#           Tasgius morsitans       1.00      1.00      1.00         9
#       Tetartopeus quadratus       0.97      0.97      0.97        35
#      Tetartopeus terminatus       0.96      0.98      0.97        45
#          Velleius dilatatus       1.00      1.00      1.00         5
#         Xantholinus dvoraki       1.00      0.86      0.92         7
#        Xantholinus gallicus       0.67      1.00      0.80         2
#      Xantholinus laevigatus       0.57      0.67      0.62         6
#        Xantholinus linearis       1.00      0.67      0.80        12
#    Xantholinus longiventris       0.90      0.82      0.86        11
#        Xantholinus tricolor       0.87      0.93      0.90        14
#
#                   micro avg       0.84      0.84      0.84      3381
#                   macro avg       0.84      0.84      0.82      3381
#                weighted avg       0.87      0.84      0.84      3381
# /usr/local/lib/python2.7/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
y_true = val_generator.classes
matplotlib.rcParams['figure.figsize'] = [10, 10]
plot_confusion_matrix(y_true, y_pred, np.array(labels))
# Out:
# Confusion matrix, without normalization
# [[ 8  0  0 ...,  0  0  0]
#  [ 0 12  0 ...,  0  0  0]
#  [ 0  0  8 ...,  0  0  0]
#  ...,
#  [ 0  0  0 ...,  8  1  0]
#  [ 0  0  0 ...,  0  9  0]
#  [ 0  0  0 ...,  0  0 13]]

# %%
labels = (val_generator.class_indices) # dict of label:index
labels = dict((i,l) for l,i in labels.items()) # dict of index:label

# %%
# create pd.dataframe and save predictions to .csv
filenames=[datasetDir + name for name in val_generator.filenames]
y_pred_labels = [labels[y] for y in y_pred]
y_true_labels = [labels[y] for y in y_true]
y_pred3_labels = []
for i,top3 in enumerate(y_pred3):
    l = []
    for top in top3:
        l.append((labels[top], Y_pred[i][top]))
    y_pred3_labels.append(l)

results=pd.DataFrame({"Filename":filenames,
                      "Label":y_true_labels,
                      "Prediction1":y_pred_labels,
                      "Prediction3":y_pred3_labels})
results.to_csv(results_file,index=True)
