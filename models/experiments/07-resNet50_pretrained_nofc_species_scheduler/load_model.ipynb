# %%
# %config IPCompleter.greedy=True

# %%
import sys
import os
import pandas as pd
sys.path.append("../..") # relative path to module toolkit

# %%
#from keras.applications import ResNet50
#from keras.layers import Dense, GlobalAveragePooling2D
from keras.models import Model, load_model
from keras_preprocessing.image import ImageDataGenerator
from toolkit import getLabelsFromDir, plot_confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# setup
batch_size = 1
val_dir = "../../../images/images_species/val/"
val_images = 3381
datasetDir = "images_species/"
saved_model = 'resNet50pretrained_highest_val_acc.h5'
results_file = "results.csv"

# %%
labels = getLabelsFromDir(val_dir)
val_datagen = ImageDataGenerator(rescale=1./255.)
validation_steps = int(val_images/batch_size)

# %%
model = load_model(saved_model)

# %%
val_generator = val_datagen.flow_from_directory(val_dir,
                                                    classes=labels,
                                                    class_mode="categorical",
                                                    batch_size=batch_size,
                                                    color_mode='rgb',
                                                    target_size=(224, 224),
                                                    shuffle=False,
                                                    seed=1)
# Out:
# Found 3381 images belonging to 200 classes.

# %%
Y_pred = model.predict_generator(val_generator, steps=validation_steps, verbose=1)
# Out:
# 3381/3381 [==============================] - 50s 15ms/step

# %%
y_pred = np.argmax(Y_pred, axis=1)
y_pred3 = [y[-3:] for y in np.argsort(Y_pred, axis=1)]

# %%
#print(classification_report(val_generator.classes, y_pred, target_names=labels))
print(classification_report(val_generator.classes, y_pred, target_names=labels))
# Out:
#                              precision    recall  f1-score   support
#
#      Philonthus tenuicornis       0.68      0.70      0.69        27
#       Paederidus ruficollis       0.98      0.96      0.97        49
#        Philonthus splendens       0.87      0.37      0.52        35
#     Pseudomedon obscurellus       0.93      0.86      0.89        29
#   Staphylinus erythropterus       1.00      1.00      1.00         8
#     Lobrathium multipunctum       0.80      0.91      0.85        22
#     Philonthus nitidicollis       0.25      0.50      0.33         2
#         Xantholinus dvoraki       0.75      0.86      0.80         7
#          Lathrobium geminum       0.46      0.33      0.39        18
#           Paederus riparius       0.94      0.54      0.68        56
#        Heterothops praevius       0.82      0.82      0.82        11
#           Gabrius osseticus       1.00      1.00      1.00        13
#      Philonthus carbonarius       0.88      0.51      0.64        71
#          Quedius semiaeneus       0.75      1.00      0.86         9
#           Cafius xantholoma       1.00      0.67      0.80        58
#          Othius punctulatus       1.00      1.00      1.00        11
#       Heterothops binotatus       0.68      0.87      0.76        15
#        Philonthus succicola       0.75      0.55      0.63        44
#      Philonthus rectangulus       0.89      1.00      0.94        16
#         Ocypus ophthalmicus       1.00      0.83      0.91         6
#          Quedius maurorufus       0.82      0.82      0.82        17
#           Quedius suturalis       0.88      0.94      0.91        16
#     Ontholestes tessellatus       0.88      1.00      0.93         7
#        Bisnius subuliformis       0.93      1.00      0.96        13
#          Philonthus lepidus       0.86      1.00      0.92        12
# Heterothops quadripunctulus       1.00      0.92      0.96        12
#         Philonthus addendus       0.67      0.78      0.72        18
#           Quedius auricomus       1.00      1.00      1.00        12
#          Philonthus punctus       0.78      0.88      0.82         8
#          Quedius levicollis       0.73      0.89      0.80         9
#                Ocypus olens       1.00      1.00      1.00         5
#        Ocypus aeneocephalus       1.00      1.00      1.00         9
#    Ochthephilum fracticorne       0.95      0.95      0.95        37
#              Quedius scitus       0.69      1.00      0.82         9
#      Philonthus mannerheimi       0.17      0.55      0.26        11
#  Acylophorus wagenschieberi       1.00      1.00      1.00         8
#        Astenus immacullatus       1.00      1.00      1.00        26
#         Quedius brevicornis       0.75      0.92      0.83        13
#         Quedius fuliginosus       0.71      0.71      0.71        14
#      Tetartopeus terminatus       0.88      0.93      0.90        45
#        Platydracus fulvipes       1.00      1.00      1.00         7
#       Philonthus cruentatus       0.50      1.00      0.67         8
#         Quedius scintillans       0.74      0.78      0.76        18
#         Megalinus glabratus       1.00      0.71      0.83         7
#           Heterothops niger       0.90      1.00      0.95         9
#           Quedius lateralis       0.79      0.92      0.85        12
#        Philonthus corruscus       1.00      1.00      1.00         4
#           Tasgius morsitans       0.90      1.00      0.95         9
#              Medon ripicola       1.00      0.75      0.86        16
#      Gyrohypnus punctulatus       0.69      0.65      0.67        17
#             Quedius cinctus       0.86      0.86      0.86        14
#      Philonthus longicornis       0.80      0.50      0.62        16
#            Astenus gracilis       0.47      0.47      0.47        19
#        Lathrobium brunnipes       0.96      0.86      0.91        58
#        Bisnius pseudoparcus       0.83      1.00      0.91         5
#          Quedius infuscatus       1.00      1.00      1.00         4
#              Quedius maurus       0.64      0.70      0.67        10
#          Quedius persimilis       0.61      0.92      0.73        12
#         Gabrius breviventer       0.52      0.94      0.67        17
#            Scopaeus minutus       0.89      0.89      0.89        19
#            Bisnius sordidus       0.80      0.88      0.84        50
#               Ocypus nitens       1.00      0.92      0.96        13
#          Tasgius melanarius       0.89      0.73      0.80        11
#        Gauropterus fulgidus       0.88      1.00      0.93        14
#        Xantholinus gallicus       0.50      0.50      0.50         2
#          Gabrius nigritulus       0.67      0.08      0.14        26
#       Philonthus marginatus       1.00      1.00      1.00        33
#      Philonthus rubripennis       1.00      1.00      1.00        17
#       Lathrobium fulvipenne       0.84      0.86      0.85        49
#              Sunius bicolor       0.89      0.89      0.89        18
#          Tasgius globulifer       0.57      0.80      0.67         5
#            Astenus procerus       0.86      0.80      0.83        15
#      Gabrius appendiculatus       0.83      0.83      0.83        12
#          Philonthus rufipes       0.28      0.58      0.38        12
#               Quedius boops       0.80      0.57      0.67         7
#            Quedius cruentus       1.00      0.89      0.94        19
#          Velleius dilatatus       1.00      1.00      1.00         5
#    Neobisnius lathrobioides       1.00      0.97      0.98        30
#         Quedius fulvicollis       1.00      1.00      1.00         2
#              Medon brunneus       0.87      0.81      0.84        16
#          Philonthus jurgans       0.00      0.00      0.00         8
#        Scopaeus sulcicollis       0.81      0.76      0.79        17
#   Philonthus quisquiliarius       0.69      0.69      0.69        13
#       Gyrohypnus angustatus       0.57      0.44      0.50         9
#       Staphylinus caesareus       0.80      0.80      0.80         5
#           Quedius xanthopus       0.78      0.90      0.84        20
#        Lithocharis ochracea       1.00      0.92      0.96        39
#              Bisnius parcus       0.88      1.00      0.93         7
#        Philonthus binotatus       1.00      0.50      0.67         4
#      Quedius nigrocaeruleus       0.57      1.00      0.73         4
#       Pseudomedon obsoletus       0.75      1.00      0.86        12
#          Philonthus varians       0.57      0.92      0.71        13
#          Gyrohypnus atratus       0.80      0.80      0.80        10
#         Ontholestes murinus       0.92      1.00      0.96        11
#      Xantholinus laevigatus       0.40      0.67      0.50         6
#         Philonthus corvinus       0.67      0.75      0.71         8
#        Quedius semiobscurus       1.00      1.00      1.00         8
#   Heterothops stiglundbergi       1.00      0.67      0.80         3
#        Philonthus concinnus       0.82      0.64      0.72        14
#          Philonthus nigrita       1.00      0.91      0.95        11
#             Nudobius lentus       1.00      0.93      0.96        14
#          Philonthus debilis       0.89      0.85      0.87        20
#       Lithocharis nigriceps       0.94      1.00      0.97        16
#         Philonthus furcifer       1.00      0.50      0.67         8
#         Philonthus confinis       0.29      0.67      0.40         3
#          Bisnius cephalotes       0.72      0.89      0.79        35
#         Philonthus fumarius       0.94      1.00      0.97        16
#        Lathrobium rufipenne       0.92      1.00      0.96        22
#           Ocypus picipennis       1.00      1.00      1.00        11
#          Astenus lyonessius       0.62      0.50      0.56        30
#            Ocypus brunnipes       1.00      1.00      1.00        11
#           Rugilus erichsoni       0.88      0.71      0.79        31
#             Atrecus affinis       1.00      1.00      1.00         9
#           Bisnius nitidulus       0.93      0.96      0.95        28
#         Scopaeus laevigatus       1.00      1.00      1.00         2
#      Philonthus parvicornis       0.64      0.78      0.70         9
#          Philonthus politus       0.82      0.35      0.49        51
#             Othius angustus       0.93      0.78      0.85        18
#        Philonthus ventralis       0.88      0.64      0.74        11
#         Heterothops minutus       1.00      0.83      0.91         6
#           Philonthus micans       0.94      0.94      0.94        18
#          Quedius nitipennis       0.80      0.50      0.62        16
#     Acylophorus glaberrimus       0.92      1.00      0.96        12
#              Medon apicalis       0.63      1.00      0.77        12
#     Leptacinus formicetorum       1.00      1.00      1.00         8
#     Gyrohypnus fracticornis       0.64      0.60      0.62        15
#           Gabrius keysianus       1.00      1.00      1.00         8
#       Tetartopeus quadratus       0.92      0.97      0.94        35
#          Philonthus salinus       0.93      1.00      0.96        13
#          Philonthus albipes       0.79      1.00      0.88        30
#      Leptacinus intermedius       0.55      1.00      0.71         6
# Staphylinus dimidiaticornis       0.80      1.00      0.89         4
#           Euryporus picipes       1.00      1.00      1.00         8
#          Philonthus nitidus       0.97      1.00      0.98        32
#           Quedius boopoides       0.57      0.67      0.62         6
#                Tasgius ater       0.88      1.00      0.93         7
#        Leptacinus batychrus       0.90      0.41      0.56        22
#          Gabrius austriacus       0.50      0.83      0.62         6
#          Philonthus decorus       1.00      0.47      0.64        45
#             Quedius fumatus       0.88      0.94      0.91        16
#        Xantholinus linearis       0.89      0.67      0.76        12
#          Philonthus atratus       0.53      0.76      0.63        34
# Phacophallus parumpunctatus       0.67      1.00      0.80         6
#             Gabrius exiguus       0.00      0.00      0.00         3
#              Remus sericeus       0.96      1.00      0.98        24
#    Platydracus stercorarius       1.00      1.00      1.00        10
#                 Emus hirtus       1.00      1.00      1.00         4
#   Philonthus sanguinolentus       1.00      0.94      0.97        17
#       Neobisnius villosulus       0.88      1.00      0.93         7
#        Gabronthus thermarum       1.00      1.00      1.00         5
#            Quedius fulgidus       1.00      1.00      1.00         5
#         Philonthus ebeninus       0.83      0.83      0.83         6
#              Bisnius puella       0.88      1.00      0.93         7
#           Quedius lucidulus       0.76      0.76      0.76        17
#         Othius subuliformis       0.77      0.91      0.83        11
#        Philonthus laminatus       0.81      0.50      0.62        34
#            Quedius umbrinus       0.82      0.70      0.76        20
#        Ochthephilum collare       1.00      0.50      0.67         2
#             Ocypus fuscatus       0.07      0.75      0.13         8
#         Leptacinus pusillus       0.55      1.00      0.71         6
#          Lathrobium fovulum       1.00      0.86      0.93        29
#              Quedius brevis       1.00      0.88      0.93         8
#         Paederus littoralis       0.86      0.95      0.90        38
#             Achenium humile       0.80      1.00      0.89         8
#           Paederus fuscipes       0.62      1.00      0.77        28
#          Quedius truncicola       0.80      1.00      0.89         4
#        Quedius puncticollis       0.92      0.75      0.83        16
#             Quedius microps       1.00      1.00      1.00        21
#         Quedius longicornis       1.00      0.93      0.97        15
#       Quedius simplicifrons       0.88      1.00      0.93         7
#          Astenus pulchellus       0.70      0.92      0.79        25
#         Quedius mesomelinus       0.78      0.47      0.58        15
#      Dinothenarus pubescens       1.00      1.00      1.00         8
#        Xantholinus tricolor       0.81      0.93      0.87        14
#         Philonthus cognatus       0.96      0.61      0.75        70
#         Rugilus orbiculatus       0.82      0.80      0.81        59
#     Erichsonius cinerascens       1.00      1.00      1.00        36
#             Medon castaneus       0.82      1.00      0.90         9
#        Gabrius splendidulus       0.76      1.00      0.86        19
#     Platydracus latebricola       0.67      0.80      0.73         5
#             Rugilus rufipes       0.96      1.00      0.98        49
#       Creophilus maxillosus       1.00      1.00      1.00         9
#        Lathrobium elongatum       0.83      0.73      0.78        48
#      Philonthus micantoides       0.75      0.75      0.75         4
#    Xantholinus longiventris       0.90      0.82      0.86        11
#         Lathrobium pallidum       0.82      1.00      0.90         9
#       Sunius melanocephalus       0.92      0.96      0.94        23
#          Quedius molochinus       1.00      0.86      0.92        14
#           Gabrius trossulus       0.83      1.00      0.91        10
#      Heterothops dissimilis       1.00      0.43      0.60         7
#      Philonthus intermedius       0.39      0.93      0.55        15
#          Philonthus alpinus       0.25      0.25      0.25         4
#             Quedius picipes       1.00      1.00      1.00        12
#        Lathrobium impressum       0.98      0.98      0.98        54
#       Philonthus discoideus       1.00      1.00      1.00        20
#           Quedius nigriceps       1.00      1.00      1.00         9
#           Atrecus longiceps       1.00      1.00      1.00         5
#         Quedius curtipennis       0.67      0.29      0.40         7
#          Bisnius fimetarius       0.92      0.77      0.84        60
#          Lathrobium dilutum       0.50      1.00      0.67         2
#
#                   micro avg       0.81      0.81      0.81      3381
#                   macro avg       0.82      0.83      0.81      3381
#                weighted avg       0.85      0.81      0.81      3381
# /home/herri/.local/lib/python3.5/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
y_true = val_generator.classes
matplotlib.rcParams['figure.figsize'] = [10, 10]
plot_confusion_matrix(y_true, y_pred, np.array(labels))
# Out:
# Confusion matrix, without normalization
# [[19  0  0 ...  0  0  0]
#  [ 0 47  0 ...  0  0  0]
#  [ 0  0 13 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  2  0  0]
#  [ 0  0  0 ...  0 46  0]
#  [ 0  0  0 ...  0  0  2]]

# %%
labels = (val_generator.class_indices) # dict of label:index
labels = dict((i,l) for l,i in labels.items()) # dict of index:label

# %%
# create pd.dataframe and save predictions to .csv
filenames=[datasetDir + name for name in val_generator.filenames]
y_pred_labels = [labels[y] for y in y_pred]
y_true_labels = [labels[y] for y in y_true]
y_pred3_labels = []
for i,top3 in enumerate(y_pred3):
    l = []
    for top in top3:
        l.append((labels[top], Y_pred[i][top]))
    y_pred3_labels.append(l)

results=pd.DataFrame({"Filename":filenames,
                      "Label":y_true_labels,
                      "Prediction1":y_pred_labels,
                      "Prediction3":y_pred3_labels})
results.to_csv(results_file,index=True)
