# %%
# %config IPCompleter.greedy=True

# %%
import sys
import os
import pandas as pd
sys.path.append("../..") # relative path to module toolkit

# %%
#from keras.applications import ResNet50
#from keras.layers import Dense, GlobalAveragePooling2D
from keras.models import Model, load_model
from keras_preprocessing.image import ImageDataGenerator
from toolkit import getLabelsFromDir, plot_confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# setup
batch_size = 1
val_dir = "../../../images/images_species_shuffled_aspect_416/val/"
val_images = 3331#3381
datasetDir = "images_species/"
saved_model = 'highest_val_acc.h5'
results_file = "results.csv"

# %%
labels = getLabelsFromDir(val_dir)
val_datagen = ImageDataGenerator(rescale=1./255.)
validation_steps = int(val_images/batch_size)

# %%
model = load_model(saved_model)

# %%
val_generator = val_datagen.flow_from_directory(val_dir,
                                                    classes=labels,
                                                    class_mode="categorical",
                                                    batch_size=batch_size,
                                                    color_mode='rgb',
                                                    target_size=(416, 416),
                                                    shuffle=False,
                                                    seed=1)
# Out:
# Found 3331 images belonging to 200 classes.

# %%
Y_pred = model.predict_generator(val_generator, steps=validation_steps, verbose=1)
# Out:
# 3331/3331 [==============================] - 93s 28ms/step

# %%
y_pred = np.argmax(Y_pred, axis=1)
y_pred3 = [y[-3:] for y in np.argsort(Y_pred, axis=1)]

# %%
def classification_report_csv(report):
    report_data = []
    lines = report.split('\n')
    for line in lines[2:-3]:
        row = {}
        if line == '':
            continue
        row_data = line.split(' ')
        row_data = [data for data in row_data if data]
        row['class'] = row_data[0] + " " + row_data[1]
        row['precision'] = float(row_data[2])
        row['recall'] = float(row_data[3])
        row['f1_score'] = float(row_data[4])
        row['support'] = float(row_data[5])
        report_data.append(row)
    dataframe = pd.DataFrame.from_dict(report_data)
    dataframe.to_csv('classification_report.csv', index = False)

# %%
report = classification_report(val_generator.classes, y_pred, target_names=labels)
classification_report_csv(report)
print(report)
# Out:
#                              precision    recall  f1-score   support
#
#      Philonthus tenuicornis       0.77      0.85      0.81        27
#       Paederidus ruficollis       1.00      1.00      1.00        48
#        Philonthus splendens       0.97      0.97      0.97        34
#     Pseudomedon obscurellus       0.97      0.97      0.97        29
#   Staphylinus erythropterus       1.00      0.86      0.92         7
#     Lobrathium multipunctum       0.96      1.00      0.98        22
#     Philonthus nitidicollis       1.00      1.00      1.00         2
#         Xantholinus dvoraki       0.88      1.00      0.93         7
#          Lathrobium geminum       0.75      0.71      0.73        17
#           Paederus riparius       1.00      1.00      1.00        55
#        Heterothops praevius       0.78      0.64      0.70        11
#           Gabrius osseticus       0.92      1.00      0.96        12
#      Philonthus carbonarius       0.90      0.90      0.90        71
#          Quedius semiaeneus       0.89      0.89      0.89         9
#           Cafius xantholoma       1.00      1.00      1.00        58
#          Othius punctulatus       1.00      1.00      1.00        11
#       Heterothops binotatus       0.67      0.80      0.73        15
#        Philonthus succicola       0.78      0.95      0.86        44
#      Philonthus rectangulus       1.00      1.00      1.00        16
#         Ocypus ophthalmicus       1.00      1.00      1.00         6
#          Quedius maurorufus       0.89      0.94      0.91        17
#           Quedius suturalis       0.93      0.87      0.90        15
#     Ontholestes tessellatus       1.00      1.00      1.00         7
#        Bisnius subuliformis       1.00      1.00      1.00        13
#          Philonthus lepidus       1.00      1.00      1.00        12
# Heterothops quadripunctulus       0.92      1.00      0.96        12
#         Philonthus addendus       0.72      0.76      0.74        17
#           Quedius auricomus       1.00      1.00      1.00        12
#          Philonthus punctus       0.88      0.88      0.88         8
#          Quedius levicollis       1.00      1.00      1.00         9
#                Ocypus olens       1.00      1.00      1.00         5
#        Ocypus aeneocephalus       1.00      1.00      1.00         9
#    Ochthephilum fracticorne       1.00      1.00      1.00        37
#              Quedius scitus       0.90      1.00      0.95         9
#      Philonthus mannerheimi       0.91      0.91      0.91        11
#  Acylophorus wagenschieberi       1.00      1.00      1.00         8
#        Astenus immacullatus       0.96      0.96      0.96        26
#         Quedius brevicornis       0.92      0.85      0.88        13
#         Quedius fuliginosus       0.87      0.93      0.90        14
#      Tetartopeus terminatus       0.98      0.95      0.97        44
#        Platydracus fulvipes       1.00      1.00      1.00         7
#       Philonthus cruentatus       0.73      1.00      0.84         8
#         Quedius scintillans       0.93      0.78      0.85        18
#         Megalinus glabratus       1.00      1.00      1.00         7
#           Heterothops niger       1.00      0.89      0.94         9
#           Quedius lateralis       1.00      0.92      0.96        12
#        Philonthus corruscus       1.00      1.00      1.00         4
#           Tasgius morsitans       1.00      1.00      1.00         9
#              Medon ripicola       1.00      1.00      1.00        16
#      Gyrohypnus punctulatus       0.85      0.69      0.76        16
#             Quedius cinctus       0.93      0.93      0.93        14
#      Philonthus longicornis       0.79      0.69      0.73        16
#            Astenus gracilis       0.47      0.50      0.49        18
#        Lathrobium brunnipes       0.98      0.98      0.98        57
#        Bisnius pseudoparcus       1.00      0.80      0.89         5
#          Quedius infuscatus       1.00      1.00      1.00         3
#              Quedius maurus       1.00      0.80      0.89        10
#          Quedius persimilis       0.59      0.91      0.71        11
#         Gabrius breviventer       0.75      0.71      0.73        17
#            Scopaeus minutus       0.82      0.95      0.88        19
#            Bisnius sordidus       0.87      0.94      0.90        50
#               Ocypus nitens       1.00      0.92      0.96        13
#          Tasgius melanarius       1.00      1.00      1.00        11
#        Gauropterus fulgidus       1.00      1.00      1.00        14
#        Xantholinus gallicus       0.67      1.00      0.80         2
#          Gabrius nigritulus       0.83      0.76      0.79        25
#       Philonthus marginatus       1.00      1.00      1.00        32
#      Philonthus rubripennis       0.94      0.94      0.94        16
#       Lathrobium fulvipenne       0.96      0.94      0.95        48
#              Sunius bicolor       0.94      0.83      0.88        18
#          Tasgius globulifer       1.00      1.00      1.00         5
#            Astenus procerus       1.00      0.93      0.97        15
#      Gabrius appendiculatus       0.79      0.92      0.85        12
#          Philonthus rufipes       1.00      0.75      0.86        12
#               Quedius boops       1.00      0.14      0.25         7
#            Quedius cruentus       0.94      0.89      0.92        19
#          Velleius dilatatus       1.00      1.00      1.00         5
#    Neobisnius lathrobioides       1.00      1.00      1.00        30
#         Quedius fulvicollis       1.00      1.00      1.00         2
#           Euryporus picipes       0.88      1.00      0.93         7
#          Philonthus nitidus       1.00      1.00      1.00        32
#           Quedius boopoides       0.50      0.67      0.57         6
#                Tasgius ater       0.88      1.00      0.93         7
#        Leptacinus batychrus       1.00      1.00      1.00        22
#          Gabrius austriacus       1.00      0.40      0.57         5
#          Philonthus decorus       1.00      1.00      1.00        44
#             Quedius fumatus       0.94      1.00      0.97        15
#        Xantholinus linearis       0.86      1.00      0.92        12
#          Philonthus atratus       0.97      0.94      0.95        33
# Phacophallus parumpunctatus       1.00      1.00      1.00         6
#             Gabrius exiguus       1.00      1.00      1.00         3
#              Remus sericeus       1.00      1.00      1.00        24
#    Platydracus stercorarius       1.00      1.00      1.00         9
#                 Emus hirtus       1.00      1.00      1.00         4
#   Philonthus sanguinolentus       1.00      1.00      1.00        16
#       Neobisnius villosulus       1.00      0.71      0.83         7
#        Gabronthus thermarum       0.83      1.00      0.91         5
#            Quedius fulgidus       1.00      0.80      0.89         5
#         Philonthus ebeninus       1.00      1.00      1.00         6
#              Bisnius puella       1.00      0.86      0.92         7
#           Quedius lucidulus       0.80      0.94      0.86        17
#         Othius subuliformis       0.71      0.91      0.80        11
#        Philonthus laminatus       0.94      0.94      0.94        34
#            Quedius umbrinus       0.94      0.80      0.86        20
#        Ochthephilum collare       1.00      1.00      1.00         2
#             Ocypus fuscatus       0.88      1.00      0.93         7
#         Leptacinus pusillus       1.00      0.83      0.91         6
#          Lathrobium fovulum       1.00      0.93      0.96        28
#              Quedius brevis       1.00      1.00      1.00         7
#         Paederus littoralis       1.00      1.00      1.00        38
#             Achenium humile       1.00      1.00      1.00         8
#           Paederus fuscipes       1.00      1.00      1.00        28
#          Quedius truncicola       1.00      1.00      1.00         4
#        Quedius puncticollis       0.88      0.94      0.91        16
#             Quedius microps       0.95      1.00      0.98        21
#         Quedius longicornis       1.00      1.00      1.00        15
#       Quedius simplicifrons       0.88      1.00      0.93         7
#          Astenus pulchellus       0.88      0.92      0.90        25
#         Quedius mesomelinus       0.81      0.87      0.84        15
#      Dinothenarus pubescens       1.00      1.00      1.00         8
#        Xantholinus tricolor       1.00      1.00      1.00        14
#         Philonthus cognatus       1.00      1.00      1.00        69
#         Rugilus orbiculatus       0.95      0.95      0.95        58
#     Erichsonius cinerascens       1.00      1.00      1.00        36
#             Medon castaneus       1.00      1.00      1.00         9
#        Gabrius splendidulus       0.90      0.95      0.92        19
#     Platydracus latebricola       1.00      1.00      1.00         5
#             Rugilus rufipes       0.98      1.00      0.99        49
#       Creophilus maxillosus       1.00      1.00      1.00         9
#        Lathrobium elongatum       0.92      0.96      0.94        47
#      Philonthus micantoides       1.00      1.00      1.00         3
#    Xantholinus longiventris       1.00      0.80      0.89        10
#         Lathrobium pallidum       0.90      1.00      0.95         9
#       Sunius melanocephalus       0.92      1.00      0.96        23
#          Quedius molochinus       0.88      1.00      0.93        14
#           Gabrius trossulus       0.82      0.90      0.86        10
#      Heterothops dissimilis       0.60      0.43      0.50         7
#      Philonthus intermedius       1.00      0.93      0.96        14
#          Philonthus alpinus       0.75      0.75      0.75         4
#             Quedius picipes       0.91      0.83      0.87        12
#        Lathrobium impressum       0.98      1.00      0.99        54
#       Philonthus discoideus       1.00      1.00      1.00        19
#           Quedius nigriceps       1.00      1.00      1.00         9
#           Atrecus longiceps       0.71      1.00      0.83         5
#         Quedius curtipennis       0.86      0.86      0.86         7
#          Bisnius fimetarius       0.92      0.95      0.93        59
#          Lathrobium dilutum       1.00      0.50      0.67         2
#
#                   micro avg       0.93      0.93      0.93      3331
#                   macro avg       0.92      0.91      0.91      3331
#                weighted avg       0.93      0.93      0.92      3331

# %%
y_true = val_generator.classes
matplotlib.rcParams['figure.figsize'] = [10, 10]
plot_confusion_matrix(y_true, y_pred, np.array(labels))
# Out:
# Confusion matrix, without normalization
# [[23  0  0 ...  0  0  0]
#  [ 0 48  0 ...  0  0  0]
#  [ 1  0 33 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  6  0  0]
#  [ 0  0  0 ...  0 56  0]
#  [ 0  0  0 ...  0  0  1]]
# (<Figure size 720x720 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fcfee813128>)

# %%
labels = (val_generator.class_indices) # dict of label:index
labels = dict((i,l) for l,i in labels.items()) # dict of index:label

# %%
# create pd.dataframe and save predictions to .csv
#filenames=[datasetDir + name for name in val_generator.filenames]
#y_pred_labels = [labels[y] for y in y_pred]
#y_true_labels = [labels[y] for y in y_true]
#y_pred3_labels = []
#for i,top3 in enumerate(y_pred3):
#    l = []
#    for top in top3:
#        l.append((labels[top], Y_pred[i][top]))
#    y_pred3_labels.append(l)
#
#results=pd.DataFrame({"Filename":filenames,
#                      "Label":y_true_labels,
#                      "Prediction1":y_pred_labels,
#                      "Prediction3":y_pred3_labels})
#results.to_csv(results_file,index=True)

# create pd.dataframe and save predictions to .csv
filenames=[datasetDir + name for name in val_generator.filenames]
y_pred_labels = [labels[y] for y in y_pred]
y_true_labels = [labels[y] for y in y_true]
y_pred3_labels_prob = []

for i,top3 in enumerate(y_pred3):
    l = []
    for top in top3:
        l.append(labels[top])
        l.append(Y_pred[i][top])
    y_pred3_labels_prob.append(l)
y_pred3_labels_prob = np.array(y_pred3_labels_prob)

results=pd.DataFrame({"Filename":filenames,
                      "Label":y_true_labels,
                      "Prediction1":y_pred_labels,
                      "Prediction3a":y_pred3_labels_prob[:,0],
                      "Prediction3a_prob":y_pred3_labels_prob[:,1],
                      "Prediction3b":y_pred3_labels_prob[:,2],
                      "Prediction3b_prob":y_pred3_labels_prob[:,3],
                      "Prediction3c":y_pred3_labels_prob[:,4],
                      "Prediction3c_prob":y_pred3_labels_prob[:,5],
                     })
results.to_csv(results_file,index=True)
