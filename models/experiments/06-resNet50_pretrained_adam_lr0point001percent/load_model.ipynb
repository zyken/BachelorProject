# %%
# %config IPCompleter.greedy=True

# %%
import sys
import os
import pandas as pd
sys.path.append("../..") # relative path to module toolkit

# %%
#from keras.applications import ResNet50
#from keras.layers import Dense, GlobalAveragePooling2D
from keras.models import Model, load_model
from keras_preprocessing.image import ImageDataGenerator
from toolkit import getLabelsFromDir, plot_confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# setup
batch_size = 1
val_dir = "../../../images/images_species/val/"
val_images = 3381
datasetDir = "images_species/"
saved_model = 'highest_val_acc.h5'
results_file = "results.csv"

# %%
labels = getLabelsFromDir(val_dir)
val_datagen = ImageDataGenerator(rescale=1./255.)
validation_steps = int(val_images/batch_size)

# %%
model = load_model(saved_model)

# %%
val_generator = val_datagen.flow_from_directory(val_dir,
                                                    classes=labels,
                                                    class_mode="categorical",
                                                    batch_size=batch_size,
                                                    color_mode='rgb',
                                                    target_size=(224, 224),
                                                    shuffle=False,
                                                    seed=1)
# Out:
# Found 3381 images belonging to 200 classes.

# %%
Y_pred = model.predict_generator(val_generator, steps=validation_steps, verbose=1)
# Out:
# 3381/3381 [==============================] - 51s 15ms/step

# %%
y_pred = np.argmax(Y_pred, axis=1)
y_pred3 = [y[-3:] for y in np.argsort(Y_pred, axis=1)]

# %%
print(classification_report(val_generator.classes, y_pred, target_names=labels))
# Out:
#                              precision    recall  f1-score   support
#
#      Philonthus tenuicornis       0.54      0.81      0.65        27
#       Paederidus ruficollis       1.00      1.00      1.00        49
#        Philonthus splendens       0.97      0.91      0.94        35
#     Pseudomedon obscurellus       0.88      1.00      0.94        29
#   Staphylinus erythropterus       0.73      1.00      0.84         8
#     Lobrathium multipunctum       1.00      0.86      0.93        22
#     Philonthus nitidicollis       0.00      0.00      0.00         2
#         Xantholinus dvoraki       0.67      0.86      0.75         7
#          Lathrobium geminum       0.52      0.67      0.59        18
#           Paederus riparius       1.00      0.91      0.95        56
#        Heterothops praevius       0.44      1.00      0.61        11
#           Gabrius osseticus       0.85      0.85      0.85        13
#      Philonthus carbonarius       0.90      0.73      0.81        71
#          Quedius semiaeneus       0.75      1.00      0.86         9
#           Cafius xantholoma       0.97      1.00      0.98        58
#          Othius punctulatus       1.00      0.91      0.95        11
#       Heterothops binotatus       0.50      0.53      0.52        15
#        Philonthus succicola       0.91      0.48      0.63        44
#      Philonthus rectangulus       1.00      1.00      1.00        16
#         Ocypus ophthalmicus       0.83      0.83      0.83         6
#          Quedius maurorufus       0.94      0.88      0.91        17
#           Quedius suturalis       0.82      0.88      0.85        16
#     Ontholestes tessellatus       0.88      1.00      0.93         7
#        Bisnius subuliformis       1.00      1.00      1.00        13
#          Philonthus lepidus       0.92      1.00      0.96        12
# Heterothops quadripunctulus       1.00      1.00      1.00        12
#         Philonthus addendus       0.60      0.67      0.63        18
#           Quedius auricomus       0.86      1.00      0.92        12
#          Philonthus punctus       1.00      0.88      0.93         8
#          Quedius levicollis       0.00      0.00      0.00         9
#                Ocypus olens       0.83      1.00      0.91         5
#        Ocypus aeneocephalus       0.90      1.00      0.95         9
#    Ochthephilum fracticorne       1.00      0.95      0.97        37
#              Quedius scitus       0.90      1.00      0.95         9
#      Philonthus mannerheimi       0.39      0.82      0.53        11
#  Acylophorus wagenschieberi       0.89      1.00      0.94         8
#        Astenus immacullatus       1.00      1.00      1.00        26
#         Quedius brevicornis       0.73      0.85      0.79        13
#         Quedius fuliginosus       0.91      0.71      0.80        14
#      Tetartopeus terminatus       0.91      0.96      0.93        45
#        Platydracus fulvipes       1.00      0.86      0.92         7
#       Philonthus cruentatus       0.78      0.88      0.82         8
#         Quedius scintillans       0.92      0.67      0.77        18
#         Megalinus glabratus       1.00      1.00      1.00         7
#           Heterothops niger       1.00      0.44      0.62         9
#           Quedius lateralis       1.00      0.92      0.96        12
#        Philonthus corruscus       0.67      1.00      0.80         4
#           Tasgius morsitans       0.90      1.00      0.95         9
#              Medon ripicola       0.79      0.94      0.86        16
#      Gyrohypnus punctulatus       0.55      0.71      0.62        17
#             Quedius cinctus       1.00      0.79      0.88        14
#      Philonthus longicornis       1.00      0.31      0.48        16
#            Astenus gracilis       0.48      0.68      0.57        19
#        Lathrobium brunnipes       0.84      0.97      0.90        58
#        Bisnius pseudoparcus       0.71      1.00      0.83         5
#          Quedius infuscatus       1.00      0.50      0.67         4
#              Quedius maurus       0.43      0.60      0.50        10
#          Quedius persimilis       0.64      0.75      0.69        12
#         Gabrius breviventer       0.50      0.82      0.62        17
#            Scopaeus minutus       0.54      1.00      0.70        19
#            Bisnius sordidus       0.90      0.92      0.91        50
#               Ocypus nitens       0.85      0.85      0.85        13
#          Tasgius melanarius       0.78      0.64      0.70        11
#        Gauropterus fulgidus       1.00      1.00      1.00        14
#        Xantholinus gallicus       0.00      0.00      0.00         2
#          Gabrius nigritulus       0.83      0.19      0.31        26
#       Philonthus marginatus       0.97      1.00      0.99        33
#      Philonthus rubripennis       0.89      1.00      0.94        17
#       Lathrobium fulvipenne       0.89      0.86      0.88        49
#              Sunius bicolor       0.71      0.94      0.81        18
#          Tasgius globulifer       0.57      0.80      0.67         5
#            Astenus procerus       0.94      1.00      0.97        15
#      Gabrius appendiculatus       0.83      0.83      0.83        12
#          Philonthus rufipes       0.75      0.50      0.60        12
#               Quedius boops       0.67      0.57      0.62         7
#            Quedius cruentus       1.00      1.00      1.00        19
#          Velleius dilatatus       1.00      1.00      1.00         5
#    Neobisnius lathrobioides       1.00      0.90      0.95        30
#         Quedius fulvicollis       1.00      1.00      1.00         2
#              Medon brunneus       0.93      0.88      0.90        16
#          Philonthus jurgans       0.00      0.00      0.00         8
#        Scopaeus sulcicollis       1.00      0.06      0.11        17
#   Philonthus quisquiliarius       0.55      0.85      0.67        13
#       Gyrohypnus angustatus       1.00      0.67      0.80         9
#       Staphylinus caesareus       1.00      0.40      0.57         5
#           Quedius xanthopus       0.89      0.85      0.87        20
#        Lithocharis ochracea       1.00      0.87      0.93        39
#              Bisnius parcus       1.00      0.57      0.73         7
#        Philonthus binotatus       0.50      0.25      0.33         4
#      Quedius nigrocaeruleus       0.67      1.00      0.80         4
#       Pseudomedon obsoletus       0.92      1.00      0.96        12
#          Philonthus varians       0.48      0.85      0.61        13
#          Gyrohypnus atratus       0.77      1.00      0.87        10
#         Ontholestes murinus       0.92      1.00      0.96        11
#      Xantholinus laevigatus       0.57      0.67      0.62         6
#         Philonthus corvinus       0.47      0.88      0.61         8
#        Quedius semiobscurus       0.62      1.00      0.76         8
#   Heterothops stiglundbergi       1.00      1.00      1.00         3
#        Philonthus concinnus       0.67      0.86      0.75        14
#          Philonthus nigrita       1.00      0.73      0.84        11
#             Nudobius lentus       1.00      0.93      0.96        14
#          Philonthus debilis       0.75      0.75      0.75        20
#       Lithocharis nigriceps       0.89      1.00      0.94        16
#         Philonthus furcifer       0.67      0.50      0.57         8
#         Philonthus confinis       0.75      1.00      0.86         3
#          Bisnius cephalotes       0.76      0.89      0.82        35
#         Philonthus fumarius       0.84      1.00      0.91        16
#        Lathrobium rufipenne       0.92      1.00      0.96        22
#           Ocypus picipennis       0.91      0.91      0.91        11
#          Astenus lyonessius       0.73      0.27      0.39        30
#            Ocypus brunnipes       0.92      1.00      0.96        11
#           Rugilus erichsoni       0.93      0.84      0.88        31
#             Atrecus affinis       0.90      1.00      0.95         9
#           Bisnius nitidulus       1.00      0.96      0.98        28
#         Scopaeus laevigatus       1.00      1.00      1.00         2
#      Philonthus parvicornis       0.75      0.67      0.71         9
#          Philonthus politus       0.78      0.55      0.64        51
#             Othius angustus       1.00      0.72      0.84        18
#        Philonthus ventralis       0.86      0.55      0.67        11
#         Heterothops minutus       1.00      1.00      1.00         6
#           Philonthus micans       1.00      0.67      0.80        18
#          Quedius nitipennis       1.00      0.31      0.48        16
#     Acylophorus glaberrimus       0.92      1.00      0.96        12
#              Medon apicalis       0.75      0.75      0.75        12
#     Leptacinus formicetorum       0.80      1.00      0.89         8
#     Gyrohypnus fracticornis       0.78      0.47      0.58        15
#           Gabrius keysianus       1.00      0.88      0.93         8
#       Tetartopeus quadratus       0.92      0.97      0.94        35
#          Philonthus salinus       1.00      0.85      0.92        13
#          Philonthus albipes       0.78      0.97      0.87        30
#      Leptacinus intermedius       1.00      0.83      0.91         6
# Staphylinus dimidiaticornis       1.00      1.00      1.00         4
#           Euryporus picipes       0.70      0.88      0.78         8
#          Philonthus nitidus       0.91      1.00      0.96        32
#           Quedius boopoides       0.50      0.83      0.62         6
#                Tasgius ater       0.88      1.00      0.93         7
#        Leptacinus batychrus       0.90      0.86      0.88        22
#          Gabrius austriacus       0.67      0.67      0.67         6
#          Philonthus decorus       0.98      0.93      0.95        45
#             Quedius fumatus       1.00      0.94      0.97        16
#        Xantholinus linearis       0.82      0.75      0.78        12
#          Philonthus atratus       0.91      0.85      0.88        34
# Phacophallus parumpunctatus       1.00      1.00      1.00         6
#             Gabrius exiguus       1.00      0.67      0.80         3
#              Remus sericeus       0.92      1.00      0.96        24
#    Platydracus stercorarius       0.91      1.00      0.95        10
#                 Emus hirtus       1.00      1.00      1.00         4
#   Philonthus sanguinolentus       0.84      0.94      0.89        17
#       Neobisnius villosulus       1.00      1.00      1.00         7
#        Gabronthus thermarum       0.56      1.00      0.71         5
#            Quedius fulgidus       1.00      0.80      0.89         5
#         Philonthus ebeninus       1.00      0.83      0.91         6
#              Bisnius puella       0.78      1.00      0.88         7
#           Quedius lucidulus       0.73      0.94      0.82        17
#         Othius subuliformis       0.62      0.91      0.74        11
#        Philonthus laminatus       0.94      0.91      0.93        34
#            Quedius umbrinus       0.90      0.90      0.90        20
#        Ochthephilum collare       1.00      1.00      1.00         2
#             Ocypus fuscatus       1.00      0.75      0.86         8
#         Leptacinus pusillus       0.86      1.00      0.92         6
#          Lathrobium fovulum       0.92      0.79      0.85        29
#              Quedius brevis       1.00      0.88      0.93         8
#         Paederus littoralis       0.90      1.00      0.95        38
#             Achenium humile       1.00      0.88      0.93         8
#           Paederus fuscipes       0.97      1.00      0.98        28
#          Quedius truncicola       0.80      1.00      0.89         4
#        Quedius puncticollis       0.85      0.69      0.76        16
#             Quedius microps       0.95      1.00      0.98        21
#         Quedius longicornis       1.00      1.00      1.00        15
#       Quedius simplicifrons       0.44      1.00      0.61         7
#          Astenus pulchellus       0.69      0.96      0.80        25
#         Quedius mesomelinus       0.88      0.47      0.61        15
#      Dinothenarus pubescens       1.00      1.00      1.00         8
#        Xantholinus tricolor       0.92      0.79      0.85        14
#         Philonthus cognatus       0.98      0.73      0.84        70
#         Rugilus orbiculatus       0.90      0.97      0.93        59
#     Erichsonius cinerascens       0.90      0.97      0.93        36
#             Medon castaneus       0.90      1.00      0.95         9
#        Gabrius splendidulus       0.74      0.89      0.81        19
#     Platydracus latebricola       1.00      0.80      0.89         5
#             Rugilus rufipes       0.98      1.00      0.99        49
#       Creophilus maxillosus       0.82      1.00      0.90         9
#        Lathrobium elongatum       0.93      0.79      0.85        48
#      Philonthus micantoides       0.33      1.00      0.50         4
#    Xantholinus longiventris       0.78      0.64      0.70        11
#         Lathrobium pallidum       0.90      1.00      0.95         9
#       Sunius melanocephalus       0.94      0.65      0.77        23
#          Quedius molochinus       1.00      0.86      0.92        14
#           Gabrius trossulus       0.90      0.90      0.90        10
#      Heterothops dissimilis       0.00      0.00      0.00         7
#      Philonthus intermedius       0.55      0.80      0.65        15
#          Philonthus alpinus       0.50      0.25      0.33         4
#             Quedius picipes       0.92      1.00      0.96        12
#        Lathrobium impressum       0.94      0.93      0.93        54
#       Philonthus discoideus       0.95      1.00      0.98        20
#           Quedius nigriceps       1.00      1.00      1.00         9
#           Atrecus longiceps       1.00      1.00      1.00         5
#         Quedius curtipennis       0.50      0.57      0.53         7
#          Bisnius fimetarius       0.90      0.88      0.89        60
#          Lathrobium dilutum       1.00      1.00      1.00         2
#
#                   micro avg       0.84      0.84      0.84      3381
#                   macro avg       0.83      0.83      0.81      3381
#                weighted avg       0.87      0.84      0.84      3381
# /home/herri/.local/lib/python3.5/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
y_true = val_generator.classes
matplotlib.rcParams['figure.figsize'] = [10, 10]
plot_confusion_matrix(y_true, y_pred, np.array(labels))
# Out:
# Confusion matrix, without normalization
# [[22  0  0 ...  0  0  0]
#  [ 0 49  0 ...  0  0  0]
#  [ 0  0 32 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  4  0  0]
#  [ 0  0  0 ...  0 53  0]
#  [ 0  0  0 ...  0  0  2]]

# %%
labels = (val_generator.class_indices) # dict of label:index
labels = dict((i,l) for l,i in labels.items()) # dict of index:label

# %%
# create pd.dataframe and save predictions to .csv
filenames=[datasetDir + name for name in val_generator.filenames]
y_pred_labels = [labels[y] for y in y_pred]
y_true_labels = [labels[y] for y in y_true]
y_pred3_labels = []
for i,top3 in enumerate(y_pred3):
    l = []
    for top in top3:
        l.append((labels[top], Y_pred[i][top]))
    y_pred3_labels.append(l)

results=pd.DataFrame({"Filename":filenames,
                      "Label":y_true_labels,
                      "Prediction1":y_pred_labels,
                      "Prediction3":y_pred3_labels})
results.to_csv(results_file,index=True)
