# %%
# %config IPCompleter.greedy=True

# %%
import sys
import os
import pandas as pd
sys.path.append("../..") # relative path to module toolkit

# %%
#from keras.applications import ResNet50
#from keras.layers import Dense, GlobalAveragePooling2D
from keras.models import Model, load_model
from keras_preprocessing.image import ImageDataGenerator
from toolkit import getLabelsFromDir, plot_confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# setup
batch_size = 1
val_dir = "../../../images/images_species/val/"
val_images = 3381
datasetDir = "images_species/"
saved_model = 'resNet50pretrained_highest_val_acc.h5'
results_file = "results.csv"

# %%
labels = getLabelsFromDir(val_dir)
val_datagen = ImageDataGenerator(rescale=1./255.)
validation_steps = int(val_images/batch_size)

# %%
model = load_model(saved_model)

# %%
val_generator = val_datagen.flow_from_directory(val_dir,
                                                    classes=labels,
                                                    class_mode="categorical",
                                                    batch_size=batch_size,
                                                    color_mode='rgb',
                                                    target_size=(320, 320),
                                                    shuffle=False,
                                                    seed=1)
# Out:
# Found 3381 images belonging to 200 classes.

# %%
Y_pred = model.predict_generator(val_generator, steps=validation_steps, verbose=1)
# Out:
# 3381/3381 [==============================] - 69s 21ms/step

# %%
y_pred = np.argmax(Y_pred, axis=1)
y_pred3 = [y[-3:] for y in np.argsort(Y_pred, axis=1)]

# %%
def classification_report_csv(report):
    report_data = []
    lines = report.split('\n')
    for line in lines[2:-3]:
        row = {}
        row_data = line.split('      ')
        row['class'] = row_data[0]
        row['precision'] = float(row_data[1])
        row['recall'] = float(row_data[2])
        row['f1_score'] = float(row_data[3])
        row['support'] = float(row_data[4])
        report_data.append(row)
    dataframe = pd.DataFrame.from_dict(report_data)
    dataframe.to_csv('classification_report.csv', index = False)
# Out:
#                              precision    recall  f1-score   support
#
#      Philonthus tenuicornis       0.67      0.81      0.73        27
#       Paederidus ruficollis       1.00      1.00      1.00        49
#        Philonthus splendens       0.97      0.91      0.94        35
#     Pseudomedon obscurellus       1.00      0.97      0.98        29
#   Staphylinus erythropterus       1.00      0.88      0.93         8
#     Lobrathium multipunctum       0.95      0.95      0.95        22
#     Philonthus nitidicollis       0.50      0.50      0.50         2
#         Xantholinus dvoraki       0.70      1.00      0.82         7
#          Lathrobium geminum       0.76      0.72      0.74        18
#           Paederus riparius       1.00      0.96      0.98        56
#        Heterothops praevius       0.75      0.82      0.78        11
#           Gabrius osseticus       1.00      1.00      1.00        13
#      Philonthus carbonarius       0.90      0.75      0.82        71
#          Quedius semiaeneus       0.82      1.00      0.90         9
#           Cafius xantholoma       1.00      1.00      1.00        58
#          Othius punctulatus       1.00      1.00      1.00        11
#       Heterothops binotatus       0.62      0.67      0.65        15
#        Philonthus succicola       0.77      0.68      0.72        44
#      Philonthus rectangulus       1.00      1.00      1.00        16
#         Ocypus ophthalmicus       1.00      1.00      1.00         6
#          Quedius maurorufus       0.88      0.82      0.85        17
#           Quedius suturalis       0.83      0.94      0.88        16
#     Ontholestes tessellatus       1.00      1.00      1.00         7
#        Bisnius subuliformis       1.00      1.00      1.00        13
#          Philonthus lepidus       1.00      1.00      1.00        12
# Heterothops quadripunctulus       0.92      1.00      0.96        12
#         Philonthus addendus       0.85      0.61      0.71        18
#           Quedius auricomus       1.00      1.00      1.00        12
#          Philonthus punctus       0.88      0.88      0.88         8
#          Quedius levicollis       1.00      0.89      0.94         9
#                Ocypus olens       1.00      1.00      1.00         5
#        Ocypus aeneocephalus       0.82      1.00      0.90         9
#    Ochthephilum fracticorne       0.92      0.95      0.93        37
#              Quedius scitus       0.90      1.00      0.95         9
#      Philonthus mannerheimi       0.53      0.91      0.67        11
#  Acylophorus wagenschieberi       1.00      1.00      1.00         8
#        Astenus immacullatus       1.00      0.96      0.98        26
#         Quedius brevicornis       0.92      0.85      0.88        13
#         Quedius fuliginosus       0.88      1.00      0.93        14
#      Tetartopeus terminatus       0.96      0.96      0.96        45
#        Platydracus fulvipes       1.00      1.00      1.00         7
#       Philonthus cruentatus       0.62      1.00      0.76         8
#         Quedius scintillans       0.92      0.67      0.77        18
#         Megalinus glabratus       1.00      1.00      1.00         7
#           Heterothops niger       0.80      0.89      0.84         9
#           Quedius lateralis       0.92      1.00      0.96        12
#        Philonthus corruscus       1.00      1.00      1.00         4
#           Tasgius morsitans       1.00      1.00      1.00         9
#              Medon ripicola       0.86      0.75      0.80        16
#      Gyrohypnus punctulatus       0.75      0.71      0.73        17
#             Quedius cinctus       0.87      0.93      0.90        14
#      Philonthus longicornis       0.89      0.50      0.64        16
#            Astenus gracilis       0.55      0.58      0.56        19
#        Lathrobium brunnipes       1.00      0.97      0.98        58
#        Bisnius pseudoparcus       0.62      1.00      0.77         5
#          Quedius infuscatus       0.80      1.00      0.89         4
#              Quedius maurus       0.90      0.90      0.90        10
#          Quedius persimilis       0.83      0.83      0.83        12
#         Gabrius breviventer       0.44      0.82      0.57        17
#            Scopaeus minutus       0.79      1.00      0.88        19
#            Bisnius sordidus       0.90      0.92      0.91        50
#               Ocypus nitens       1.00      0.92      0.96        13
#          Tasgius melanarius       0.77      0.91      0.83        11
#        Gauropterus fulgidus       1.00      1.00      1.00        14
#        Xantholinus gallicus       1.00      0.50      0.67         2
#          Gabrius nigritulus       0.75      0.12      0.20        26
#       Philonthus marginatus       0.97      1.00      0.99        33
#      Philonthus rubripennis       0.85      1.00      0.92        17
#       Lathrobium fulvipenne       0.92      0.96      0.94        49
#              Sunius bicolor       0.74      0.94      0.83        18
#          Tasgius globulifer       0.71      1.00      0.83         5
#            Astenus procerus       1.00      0.87      0.93        15
#      Gabrius appendiculatus       0.82      0.75      0.78        12
#          Philonthus rufipes       0.70      0.58      0.64        12
#               Quedius boops       0.67      0.86      0.75         7
#            Quedius cruentus       0.89      0.89      0.89        19
#          Velleius dilatatus       1.00      1.00      1.00         5
#    Neobisnius lathrobioides       1.00      0.97      0.98        30
#         Quedius fulvicollis       1.00      1.00      1.00         2
#              Medon brunneus       1.00      0.81      0.90        16
#          Philonthus jurgans       0.14      0.12      0.13         8
#        Scopaeus sulcicollis       0.92      0.71      0.80        17
#   Philonthus quisquiliarius       0.61      0.85      0.71        13
#       Gyrohypnus angustatus       0.60      0.33      0.43         9
#       Staphylinus caesareus       1.00      0.60      0.75         5
#           Quedius xanthopus       0.90      0.95      0.93        20
#        Lithocharis ochracea       1.00      0.92      0.96        39
#              Bisnius parcus       0.83      0.71      0.77         7
#        Philonthus binotatus       0.75      0.75      0.75         4
#      Quedius nigrocaeruleus       0.80      1.00      0.89         4
#       Pseudomedon obsoletus       0.92      1.00      0.96        12
#          Philonthus varians       0.71      0.92      0.80        13
#          Gyrohypnus atratus       1.00      1.00      1.00        10
#         Ontholestes murinus       0.92      1.00      0.96        11
#      Xantholinus laevigatus       0.50      0.67      0.57         6
#         Philonthus corvinus       0.88      0.88      0.88         8
#        Quedius semiobscurus       1.00      1.00      1.00         8
#   Heterothops stiglundbergi       1.00      1.00      1.00         3
#        Philonthus concinnus       0.82      1.00      0.90        14
#          Philonthus nigrita       1.00      1.00      1.00        11
#             Nudobius lentus       1.00      0.93      0.96        14
#          Philonthus debilis       0.87      1.00      0.93        20
#       Lithocharis nigriceps       1.00      1.00      1.00        16
#         Philonthus furcifer       0.80      0.50      0.62         8
#         Philonthus confinis       0.43      1.00      0.60         3
#          Bisnius cephalotes       0.80      0.94      0.87        35
#         Philonthus fumarius       1.00      1.00      1.00        16
#        Lathrobium rufipenne       1.00      1.00      1.00        22
#           Ocypus picipennis       1.00      0.82      0.90        11
#          Astenus lyonessius       0.77      0.67      0.71        30
#            Ocypus brunnipes       1.00      1.00      1.00        11
#           Rugilus erichsoni       0.90      0.87      0.89        31
#             Atrecus affinis       0.90      1.00      0.95         9
#           Bisnius nitidulus       0.96      0.93      0.95        28
#         Scopaeus laevigatus       1.00      1.00      1.00         2
#      Philonthus parvicornis       0.82      1.00      0.90         9
#          Philonthus politus       0.82      0.61      0.70        51
#             Othius angustus       0.93      0.72      0.81        18
#        Philonthus ventralis       0.88      0.64      0.74        11
#         Heterothops minutus       1.00      0.83      0.91         6
#           Philonthus micans       1.00      0.89      0.94        18
#          Quedius nitipennis       0.89      0.50      0.64        16
#     Acylophorus glaberrimus       0.86      1.00      0.92        12
#              Medon apicalis       0.67      1.00      0.80        12
#     Leptacinus formicetorum       0.89      1.00      0.94         8
#     Gyrohypnus fracticornis       0.80      0.80      0.80        15
#           Gabrius keysianus       0.89      1.00      0.94         8
#       Tetartopeus quadratus       0.94      0.97      0.96        35
#          Philonthus salinus       1.00      0.85      0.92        13
#          Philonthus albipes       0.83      1.00      0.91        30
#      Leptacinus intermedius       0.50      1.00      0.67         6
# Staphylinus dimidiaticornis       0.57      1.00      0.73         4
#           Euryporus picipes       1.00      1.00      1.00         8
#          Philonthus nitidus       0.94      1.00      0.97        32
#           Quedius boopoides       0.50      0.83      0.62         6
#                Tasgius ater       1.00      1.00      1.00         7
#        Leptacinus batychrus       0.93      0.59      0.72        22
#          Gabrius austriacus       0.67      0.67      0.67         6
#          Philonthus decorus       0.97      0.73      0.84        45
#             Quedius fumatus       1.00      1.00      1.00        16
#        Xantholinus linearis       1.00      0.67      0.80        12
#          Philonthus atratus       0.97      0.82      0.89        34
# Phacophallus parumpunctatus       0.55      1.00      0.71         6
#             Gabrius exiguus       0.00      0.00      0.00         3
#              Remus sericeus       1.00      1.00      1.00        24
#    Platydracus stercorarius       1.00      1.00      1.00        10
#                 Emus hirtus       1.00      1.00      1.00         4
#   Philonthus sanguinolentus       1.00      0.94      0.97        17
#       Neobisnius villosulus       1.00      1.00      1.00         7
#        Gabronthus thermarum       1.00      1.00      1.00         5
#            Quedius fulgidus       1.00      1.00      1.00         5
#         Philonthus ebeninus       1.00      1.00      1.00         6
#              Bisnius puella       0.75      0.86      0.80         7
#           Quedius lucidulus       0.70      0.94      0.80        17
#         Othius subuliformis       0.62      0.91      0.74        11
#        Philonthus laminatus       0.97      0.91      0.94        34
#            Quedius umbrinus       0.94      0.85      0.89        20
#        Ochthephilum collare       0.00      0.00      0.00         2
#             Ocypus fuscatus       0.24      0.75      0.36         8
#         Leptacinus pusillus       1.00      1.00      1.00         6
#          Lathrobium fovulum       0.93      0.90      0.91        29
#              Quedius brevis       1.00      0.88      0.93         8
#         Paederus littoralis       1.00      1.00      1.00        38
#             Achenium humile       1.00      1.00      1.00         8
#           Paederus fuscipes       0.97      1.00      0.98        28
#          Quedius truncicola       1.00      1.00      1.00         4
#        Quedius puncticollis       0.94      0.94      0.94        16
#             Quedius microps       0.95      1.00      0.98        21
#         Quedius longicornis       1.00      1.00      1.00        15
#       Quedius simplicifrons       0.75      0.86      0.80         7
#          Astenus pulchellus       0.83      1.00      0.91        25
#         Quedius mesomelinus       1.00      0.80      0.89        15
#      Dinothenarus pubescens       1.00      1.00      1.00         8
#        Xantholinus tricolor       0.92      0.86      0.89        14
#         Philonthus cognatus       0.98      0.89      0.93        70
#         Rugilus orbiculatus       0.93      0.88      0.90        59
#     Erichsonius cinerascens       0.97      1.00      0.99        36
#             Medon castaneus       1.00      1.00      1.00         9
#        Gabrius splendidulus       0.79      1.00      0.88        19
#     Platydracus latebricola       1.00      1.00      1.00         5
#             Rugilus rufipes       0.96      1.00      0.98        49
#       Creophilus maxillosus       1.00      1.00      1.00         9
#        Lathrobium elongatum       0.93      0.88      0.90        48
#      Philonthus micantoides       0.44      1.00      0.62         4
#    Xantholinus longiventris       0.82      0.82      0.82        11
#         Lathrobium pallidum       0.69      1.00      0.82         9
#       Sunius melanocephalus       0.90      0.83      0.86        23
#          Quedius molochinus       0.92      0.86      0.89        14
#           Gabrius trossulus       0.69      0.90      0.78        10
#      Heterothops dissimilis       1.00      0.29      0.44         7
#      Philonthus intermedius       0.70      0.93      0.80        15
#          Philonthus alpinus       0.50      0.50      0.50         4
#             Quedius picipes       1.00      1.00      1.00        12
#        Lathrobium impressum       0.98      0.98      0.98        54
#       Philonthus discoideus       1.00      1.00      1.00        20
#           Quedius nigriceps       1.00      1.00      1.00         9
#           Atrecus longiceps       1.00      1.00      1.00         5
#         Quedius curtipennis       0.83      0.71      0.77         7
#          Bisnius fimetarius       0.95      0.88      0.91        60
#          Lathrobium dilutum       0.00      0.00      0.00         2
#
#                   micro avg       0.89      0.89      0.89      3381
#                   macro avg       0.86      0.87      0.86      3381
#                weighted avg       0.90      0.89      0.88      3381
# /home/herri/.local/lib/python3.5/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
report = classification_report(val_generator.classes, y_pred, target_names=labels)
classification_report_csv(report)
print(report)

# %%
y_true = val_generator.classes
matplotlib.rcParams['figure.figsize'] = [10, 10]
plot_confusion_matrix(y_true, y_pred, np.array(labels))
# Out:
# Confusion matrix, without normalization
# [[22  0  0 ...  0  0  0]
#  [ 0 49  0 ...  0  0  0]
#  [ 0  0 32 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  5  0  0]
#  [ 0  0  0 ...  0 53  0]
#  [ 0  0  0 ...  0  0  0]]

# %%
labels = (val_generator.class_indices) # dict of label:index
labels = dict((i,l) for l,i in labels.items()) # dict of index:label

# %%
# create pd.dataframe and save predictions to .csv
filenames=[datasetDir + name for name in val_generator.filenames]
y_pred_labels = [labels[y] for y in y_pred]
y_true_labels = [labels[y] for y in y_true]
y_pred3_labels = []
for i,top3 in enumerate(y_pred3):
    l = []
    for top in top3:
        l.append((labels[top], Y_pred[i][top]))
    y_pred3_labels.append(l)

results=pd.DataFrame({"Filename":filenames,
                      "Label":y_true_labels,
                      "Prediction1":y_pred_labels,
                      "Prediction3":y_pred3_labels})
results.to_csv(results_file,index=True)
