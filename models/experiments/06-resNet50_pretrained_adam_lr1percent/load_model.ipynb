# %%
# %config IPCompleter.greedy=True

# %%
import sys
import os
import pandas as pd
sys.path.append("../..") # relative path to module toolkit

# %%
#from keras.applications import ResNet50
#from keras.layers import Dense, GlobalAveragePooling2D
from keras.models import Model, load_model
from keras_preprocessing.image import ImageDataGenerator
from toolkit import getLabelsFromDir, plot_confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# setup
batch_size = 1
val_dir = "../../../images/images_species/val/"
val_images = 3381
datasetDir = "images_species/"
saved_model = 'highest_val_acc.h5'
results_file = "results.csv"

# %%
labels = getLabelsFromDir(val_dir)
val_datagen = ImageDataGenerator(rescale=1./255.)
validation_steps = int(val_images/batch_size)

# %%
model = load_model(saved_model)

# %%
val_generator = val_datagen.flow_from_directory(val_dir,
                                                    classes=labels,
                                                    class_mode="categorical",
                                                    batch_size=batch_size,
                                                    color_mode='rgb',
                                                    target_size=(224, 224),
                                                    shuffle=False,
                                                    seed=1)
# Out:
# Found 3381 images belonging to 200 classes.

# %%
Y_pred = model.predict_generator(val_generator, steps=validation_steps, verbose=1)
# Out:
# 3381/3381 [==============================] - 51s 15ms/step

# %%
y_pred = np.argmax(Y_pred, axis=1)
y_pred3 = [y[-3:] for y in np.argsort(Y_pred, axis=1)]

# %%
print(classification_report(val_generator.classes, y_pred, target_names=labels))
# Out:
#                              precision    recall  f1-score   support
#
#      Philonthus tenuicornis       0.39      0.52      0.44        27
#       Paederidus ruficollis       0.96      1.00      0.98        49
#        Philonthus splendens       1.00      0.34      0.51        35
#     Pseudomedon obscurellus       0.60      0.97      0.74        29
#   Staphylinus erythropterus       0.88      0.88      0.88         8
#     Lobrathium multipunctum       0.57      0.73      0.64        22
#     Philonthus nitidicollis       0.00      0.00      0.00         2
#         Xantholinus dvoraki       0.55      0.86      0.67         7
#          Lathrobium geminum       0.58      0.61      0.59        18
#           Paederus riparius       0.93      0.91      0.92        56
#        Heterothops praevius       0.53      0.73      0.62        11
#           Gabrius osseticus       0.89      0.62      0.73        13
#      Philonthus carbonarius       0.68      0.38      0.49        71
#          Quedius semiaeneus       0.73      0.89      0.80         9
#           Cafius xantholoma       0.74      0.84      0.79        58
#          Othius punctulatus       0.50      0.82      0.62        11
#       Heterothops binotatus       0.32      0.73      0.45        15
#        Philonthus succicola       0.67      0.32      0.43        44
#      Philonthus rectangulus       1.00      0.44      0.61        16
#         Ocypus ophthalmicus       0.83      0.83      0.83         6
#          Quedius maurorufus       0.44      0.65      0.52        17
#           Quedius suturalis       0.64      0.88      0.74        16
#     Ontholestes tessellatus       1.00      0.43      0.60         7
#        Bisnius subuliformis       0.92      0.92      0.92        13
#          Philonthus lepidus       0.92      0.92      0.92        12
# Heterothops quadripunctulus       1.00      0.58      0.74        12
#         Philonthus addendus       0.50      0.28      0.36        18
#           Quedius auricomus       0.86      1.00      0.92        12
#          Philonthus punctus       0.33      0.38      0.35         8
#          Quedius levicollis       0.70      0.78      0.74         9
#                Ocypus olens       1.00      0.40      0.57         5
#        Ocypus aeneocephalus       0.88      0.78      0.82         9
#    Ochthephilum fracticorne       0.97      0.78      0.87        37
#              Quedius scitus       0.90      1.00      0.95         9
#      Philonthus mannerheimi       0.50      0.64      0.56        11
#  Acylophorus wagenschieberi       1.00      0.88      0.93         8
#        Astenus immacullatus       0.60      0.92      0.73        26
#         Quedius brevicornis       0.75      0.46      0.57        13
#         Quedius fuliginosus       0.33      0.07      0.12        14
#      Tetartopeus terminatus       0.59      0.89      0.71        45
#        Platydracus fulvipes       1.00      0.43      0.60         7
#       Philonthus cruentatus       0.53      1.00      0.70         8
#         Quedius scintillans       0.46      0.33      0.39        18
#         Megalinus glabratus       0.71      0.71      0.71         7
#           Heterothops niger       1.00      0.67      0.80         9
#           Quedius lateralis       0.69      0.92      0.79        12
#        Philonthus corruscus       1.00      0.75      0.86         4
#           Tasgius morsitans       0.73      0.89      0.80         9
#              Medon ripicola       0.90      0.56      0.69        16
#      Gyrohypnus punctulatus       0.50      0.71      0.59        17
#             Quedius cinctus       0.77      0.71      0.74        14
#      Philonthus longicornis       0.77      0.62      0.69        16
#            Astenus gracilis       0.35      0.37      0.36        19
#        Lathrobium brunnipes       0.86      0.66      0.75        58
#        Bisnius pseudoparcus       0.00      0.00      0.00         5
#          Quedius infuscatus       0.67      0.50      0.57         4
#              Quedius maurus       0.50      0.20      0.29        10
#          Quedius persimilis       0.38      0.25      0.30        12
#         Gabrius breviventer       0.48      0.82      0.61        17
#            Scopaeus minutus       0.63      0.89      0.74        19
#            Bisnius sordidus       0.37      0.80      0.51        50
#               Ocypus nitens       0.75      0.46      0.57        13
#          Tasgius melanarius       0.75      0.82      0.78        11
#        Gauropterus fulgidus       0.93      1.00      0.97        14
#        Xantholinus gallicus       0.50      1.00      0.67         2
#          Gabrius nigritulus       0.31      0.15      0.21        26
#       Philonthus marginatus       0.94      0.91      0.92        33
#      Philonthus rubripennis       0.94      1.00      0.97        17
#       Lathrobium fulvipenne       0.77      0.76      0.76        49
#              Sunius bicolor       0.85      0.61      0.71        18
#          Tasgius globulifer       0.60      0.60      0.60         5
#            Astenus procerus       0.82      0.60      0.69        15
#      Gabrius appendiculatus       0.83      0.42      0.56        12
#          Philonthus rufipes       0.33      0.58      0.42        12
#               Quedius boops       0.33      0.29      0.31         7
#            Quedius cruentus       0.67      0.84      0.74        19
#          Velleius dilatatus       1.00      0.60      0.75         5
#    Neobisnius lathrobioides       0.70      0.93      0.80        30
#         Quedius fulvicollis       1.00      0.50      0.67         2
#              Medon brunneus       0.71      0.75      0.73        16
#          Philonthus jurgans       0.25      0.25      0.25         8
#        Scopaeus sulcicollis       0.75      0.35      0.48        17
#   Philonthus quisquiliarius       0.75      0.23      0.35        13
#       Gyrohypnus angustatus       0.30      0.33      0.32         9
#       Staphylinus caesareus       1.00      0.20      0.33         5
#           Quedius xanthopus       0.63      0.85      0.72        20
#        Lithocharis ochracea       0.95      0.90      0.92        39
#              Bisnius parcus       0.67      0.57      0.62         7
#        Philonthus binotatus       1.00      0.50      0.67         4
#      Quedius nigrocaeruleus       0.80      1.00      0.89         4
#       Pseudomedon obsoletus       0.80      1.00      0.89        12
#          Philonthus varians       1.00      0.69      0.82        13
#          Gyrohypnus atratus       0.55      0.60      0.57        10
#         Ontholestes murinus       1.00      0.91      0.95        11
#      Xantholinus laevigatus       0.67      0.33      0.44         6
#         Philonthus corvinus       0.30      0.88      0.45         8
#        Quedius semiobscurus       1.00      0.88      0.93         8
#   Heterothops stiglundbergi       0.00      0.00      0.00         3
#        Philonthus concinnus       0.75      0.64      0.69        14
#          Philonthus nigrita       1.00      0.55      0.71        11
#             Nudobius lentus       1.00      0.64      0.78        14
#          Philonthus debilis       0.72      0.65      0.68        20
#       Lithocharis nigriceps       0.93      0.88      0.90        16
#         Philonthus furcifer       1.00      0.50      0.67         8
#         Philonthus confinis       0.67      0.67      0.67         3
#          Bisnius cephalotes       0.69      0.57      0.62        35
#         Philonthus fumarius       0.93      0.81      0.87        16
#        Lathrobium rufipenne       0.74      0.77      0.76        22
#           Ocypus picipennis       0.80      0.36      0.50        11
#          Astenus lyonessius       0.61      0.67      0.63        30
#            Ocypus brunnipes       0.83      0.91      0.87        11
#           Rugilus erichsoni       0.89      0.77      0.83        31
#             Atrecus affinis       1.00      0.89      0.94         9
#           Bisnius nitidulus       0.84      0.75      0.79        28
#         Scopaeus laevigatus       1.00      1.00      1.00         2
#      Philonthus parvicornis       1.00      0.56      0.71         9
#          Philonthus politus       0.35      0.47      0.40        51
#             Othius angustus       0.80      0.67      0.73        18
#        Philonthus ventralis       0.80      0.36      0.50        11
#         Heterothops minutus       1.00      0.67      0.80         6
#           Philonthus micans       0.48      0.83      0.61        18
#          Quedius nitipennis       0.38      0.50      0.43        16
#     Acylophorus glaberrimus       0.86      1.00      0.92        12
#              Medon apicalis       0.67      0.67      0.67        12
#     Leptacinus formicetorum       0.88      0.88      0.88         8
#     Gyrohypnus fracticornis       1.00      0.27      0.42        15
#           Gabrius keysianus       1.00      0.75      0.86         8
#       Tetartopeus quadratus       0.78      0.83      0.81        35
#          Philonthus salinus       0.87      1.00      0.93        13
#          Philonthus albipes       0.33      0.90      0.48        30
#      Leptacinus intermedius       0.29      0.33      0.31         6
# Staphylinus dimidiaticornis       0.60      0.75      0.67         4
#           Euryporus picipes       0.83      0.62      0.71         8
#          Philonthus nitidus       0.86      0.97      0.91        32
#           Quedius boopoides       0.25      0.33      0.29         6
#                Tasgius ater       0.71      0.71      0.71         7
#        Leptacinus batychrus       0.56      0.23      0.32        22
#          Gabrius austriacus       0.13      0.33      0.19         6
#          Philonthus decorus       0.70      0.71      0.70        45
#             Quedius fumatus       0.88      0.44      0.58        16
#        Xantholinus linearis       0.62      0.42      0.50        12
#          Philonthus atratus       0.74      0.41      0.53        34
# Phacophallus parumpunctatus       0.80      0.67      0.73         6
#             Gabrius exiguus       0.00      0.00      0.00         3
#              Remus sericeus       0.48      1.00      0.65        24
#    Platydracus stercorarius       0.83      1.00      0.91        10
#                 Emus hirtus       1.00      0.75      0.86         4
#   Philonthus sanguinolentus       1.00      0.71      0.83        17
#       Neobisnius villosulus       0.55      0.86      0.67         7
#        Gabronthus thermarum       0.75      0.60      0.67         5
#            Quedius fulgidus       0.67      0.80      0.73         5
#         Philonthus ebeninus       1.00      0.17      0.29         6
#              Bisnius puella       1.00      0.71      0.83         7
#           Quedius lucidulus       0.48      0.76      0.59        17
#         Othius subuliformis       0.75      0.55      0.63        11
#        Philonthus laminatus       0.84      0.62      0.71        34
#            Quedius umbrinus       0.58      0.55      0.56        20
#        Ochthephilum collare       1.00      0.50      0.67         2
#             Ocypus fuscatus       0.62      0.62      0.62         8
#         Leptacinus pusillus       0.33      0.67      0.44         6
#          Lathrobium fovulum       0.88      0.79      0.84        29
#              Quedius brevis       1.00      0.62      0.77         8
#         Paederus littoralis       0.95      0.92      0.93        38
#             Achenium humile       1.00      0.25      0.40         8
#           Paederus fuscipes       0.90      0.96      0.93        28
#          Quedius truncicola       0.67      1.00      0.80         4
#        Quedius puncticollis       0.87      0.81      0.84        16
#             Quedius microps       0.76      0.90      0.83        21
#         Quedius longicornis       0.85      0.73      0.79        15
#       Quedius simplicifrons       0.75      0.86      0.80         7
#          Astenus pulchellus       0.89      0.68      0.77        25
#         Quedius mesomelinus       0.50      0.53      0.52        15
#      Dinothenarus pubescens       0.86      0.75      0.80         8
#        Xantholinus tricolor       0.79      0.79      0.79        14
#         Philonthus cognatus       0.90      0.87      0.88        70
#         Rugilus orbiculatus       0.82      0.85      0.83        59
#     Erichsonius cinerascens       0.87      0.75      0.81        36
#             Medon castaneus       1.00      0.44      0.62         9
#        Gabrius splendidulus       0.56      1.00      0.72        19
#     Platydracus latebricola       0.67      0.80      0.73         5
#             Rugilus rufipes       0.85      0.92      0.88        49
#       Creophilus maxillosus       0.80      0.89      0.84         9
#        Lathrobium elongatum       0.83      0.73      0.78        48
#      Philonthus micantoides       0.00      0.00      0.00         4
#    Xantholinus longiventris       0.62      0.45      0.53        11
#         Lathrobium pallidum       0.58      0.78      0.67         9
#       Sunius melanocephalus       0.74      0.61      0.67        23
#          Quedius molochinus       0.56      0.71      0.63        14
#           Gabrius trossulus       1.00      0.60      0.75        10
#      Heterothops dissimilis       0.00      0.00      0.00         7
#      Philonthus intermedius       0.63      0.80      0.71        15
#          Philonthus alpinus       0.00      0.00      0.00         4
#             Quedius picipes       1.00      0.67      0.80        12
#        Lathrobium impressum       0.96      0.81      0.88        54
#       Philonthus discoideus       0.93      0.65      0.76        20
#           Quedius nigriceps       1.00      0.89      0.94         9
#           Atrecus longiceps       1.00      0.80      0.89         5
#         Quedius curtipennis       0.44      0.57      0.50         7
#          Bisnius fimetarius       0.82      0.62      0.70        60
#          Lathrobium dilutum       0.29      1.00      0.44         2
#
#                   micro avg       0.70      0.70      0.70      3381
#                   macro avg       0.71      0.66      0.65      3381
#                weighted avg       0.74      0.70      0.69      3381
# /home/herri/.local/lib/python3.5/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
y_true = val_generator.classes
matplotlib.rcParams['figure.figsize'] = [10, 10]
plot_confusion_matrix(y_true, y_pred, np.array(labels))
# Out:
# Confusion matrix, without normalization
# [[14  0  0 ...  0  0  0]
#  [ 0 49  0 ...  0  0  0]
#  [ 7  0 12 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  4  0  0]
#  [ 0  0  0 ...  0 37  0]
#  [ 0  0  0 ...  0  0  2]]

# %%
labels = (val_generator.class_indices) # dict of label:index
labels = dict((i,l) for l,i in labels.items()) # dict of index:label

# %%
# create pd.dataframe and save predictions to .csv
filenames=[datasetDir + name for name in val_generator.filenames]
y_pred_labels = [labels[y] for y in y_pred]
y_true_labels = [labels[y] for y in y_true]
y_pred3_labels = []
for i,top3 in enumerate(y_pred3):
    l = []
    for top in top3:
        l.append((labels[top], Y_pred[i][top]))
    y_pred3_labels.append(l)

results=pd.DataFrame({"Filename":filenames,
                      "Label":y_true_labels,
                      "Prediction1":y_pred_labels,
                      "Prediction3":y_pred3_labels})
results.to_csv(results_file,index=True)
