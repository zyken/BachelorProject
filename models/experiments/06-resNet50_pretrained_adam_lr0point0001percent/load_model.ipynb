# %%
# %config IPCompleter.greedy=True

# %%
import sys
import os
import pandas as pd
sys.path.append("../..") # relative path to module toolkit

# %%
#from keras.applications import ResNet50
#from keras.layers import Dense, GlobalAveragePooling2D
from keras.models import Model, load_model
from keras_preprocessing.image import ImageDataGenerator
from toolkit import getLabelsFromDir, plot_confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# setup
batch_size = 1
val_dir = "../../../images/images_species/val/"
val_images = 3381
datasetDir = "images_species/"
saved_model = 'highest_val_acc.h5'
results_file = "results.csv"

# %%
labels = getLabelsFromDir(val_dir)
val_datagen = ImageDataGenerator(rescale=1./255.)
validation_steps = int(val_images/batch_size)

# %%
model = load_model(saved_model)

# %%
val_generator = val_datagen.flow_from_directory(val_dir,
                                                    classes=labels,
                                                    class_mode="categorical",
                                                    batch_size=batch_size,
                                                    color_mode='rgb',
                                                    target_size=(224, 224),
                                                    shuffle=False,
                                                    seed=1)
# Out:
# Found 3381 images belonging to 200 classes.

# %%
Y_pred = model.predict_generator(val_generator, steps=validation_steps, verbose=1)
# Out:
# 3381/3381 [==============================] - 51s 15ms/step

# %%
y_pred = np.argmax(Y_pred, axis=1)
y_pred3 = [y[-3:] for y in np.argsort(Y_pred, axis=1)]

# %%
print(classification_report(val_generator.classes, y_pred, target_names=labels))
# Out:
#                              precision    recall  f1-score   support
#
#      Philonthus tenuicornis       0.47      0.59      0.52        27
#       Paederidus ruficollis       0.98      1.00      0.99        49
#        Philonthus splendens       0.89      0.71      0.79        35
#     Pseudomedon obscurellus       0.81      0.90      0.85        29
#   Staphylinus erythropterus       0.88      0.88      0.88         8
#     Lobrathium multipunctum       0.75      0.95      0.84        22
#     Philonthus nitidicollis       0.00      0.00      0.00         2
#         Xantholinus dvoraki       0.58      1.00      0.74         7
#          Lathrobium geminum       0.67      0.56      0.61        18
#           Paederus riparius       0.95      0.93      0.94        56
#        Heterothops praevius       0.67      0.91      0.77        11
#           Gabrius osseticus       1.00      0.85      0.92        13
#      Philonthus carbonarius       0.92      0.69      0.79        71
#          Quedius semiaeneus       0.56      1.00      0.72         9
#           Cafius xantholoma       0.97      1.00      0.98        58
#          Othius punctulatus       1.00      0.91      0.95        11
#       Heterothops binotatus       0.62      0.67      0.65        15
#        Philonthus succicola       0.66      0.52      0.58        44
#      Philonthus rectangulus       0.94      1.00      0.97        16
#         Ocypus ophthalmicus       0.80      0.67      0.73         6
#          Quedius maurorufus       0.88      0.88      0.88        17
#           Quedius suturalis       0.89      1.00      0.94        16
#     Ontholestes tessellatus       0.78      1.00      0.88         7
#        Bisnius subuliformis       1.00      1.00      1.00        13
#          Philonthus lepidus       0.92      0.92      0.92        12
# Heterothops quadripunctulus       0.92      1.00      0.96        12
#         Philonthus addendus       0.82      0.50      0.62        18
#           Quedius auricomus       1.00      1.00      1.00        12
#          Philonthus punctus       1.00      0.88      0.93         8
#          Quedius levicollis       0.80      0.44      0.57         9
#                Ocypus olens       1.00      1.00      1.00         5
#        Ocypus aeneocephalus       0.90      1.00      0.95         9
#    Ochthephilum fracticorne       0.97      0.89      0.93        37
#              Quedius scitus       0.69      1.00      0.82         9
#      Philonthus mannerheimi       0.64      0.82      0.72        11
#  Acylophorus wagenschieberi       0.89      1.00      0.94         8
#        Astenus immacullatus       0.96      0.96      0.96        26
#         Quedius brevicornis       0.83      0.77      0.80        13
#         Quedius fuliginosus       0.83      0.71      0.77        14
#      Tetartopeus terminatus       0.91      0.96      0.93        45
#        Platydracus fulvipes       1.00      0.86      0.92         7
#       Philonthus cruentatus       0.53      1.00      0.70         8
#         Quedius scintillans       0.72      0.72      0.72        18
#         Megalinus glabratus       1.00      1.00      1.00         7
#           Heterothops niger       0.78      0.78      0.78         9
#           Quedius lateralis       0.85      0.92      0.88        12
#        Philonthus corruscus       0.80      1.00      0.89         4
#           Tasgius morsitans       0.82      1.00      0.90         9
#              Medon ripicola       0.93      0.88      0.90        16
#      Gyrohypnus punctulatus       0.67      0.47      0.55        17
#             Quedius cinctus       0.85      0.79      0.81        14
#      Philonthus longicornis       0.90      0.56      0.69        16
#            Astenus gracilis       0.73      0.42      0.53        19
#        Lathrobium brunnipes       0.96      0.91      0.94        58
#        Bisnius pseudoparcus       0.75      0.60      0.67         5
#          Quedius infuscatus       1.00      0.75      0.86         4
#              Quedius maurus       0.80      0.80      0.80        10
#          Quedius persimilis       0.57      1.00      0.73        12
#         Gabrius breviventer       0.31      0.53      0.39        17
#            Scopaeus minutus       0.63      1.00      0.78        19
#            Bisnius sordidus       0.72      0.86      0.78        50
#               Ocypus nitens       0.55      0.92      0.69        13
#          Tasgius melanarius       1.00      0.45      0.62        11
#        Gauropterus fulgidus       1.00      1.00      1.00        14
#        Xantholinus gallicus       1.00      0.50      0.67         2
#          Gabrius nigritulus       0.67      0.08      0.14        26
#       Philonthus marginatus       0.94      1.00      0.97        33
#      Philonthus rubripennis       0.71      1.00      0.83        17
#       Lathrobium fulvipenne       0.89      0.86      0.88        49
#              Sunius bicolor       0.92      0.61      0.73        18
#          Tasgius globulifer       0.57      0.80      0.67         5
#            Astenus procerus       1.00      0.80      0.89        15
#      Gabrius appendiculatus       0.37      0.92      0.52        12
#          Philonthus rufipes       0.64      0.58      0.61        12
#               Quedius boops       0.80      0.57      0.67         7
#            Quedius cruentus       0.94      0.89      0.92        19
#          Velleius dilatatus       1.00      1.00      1.00         5
#    Neobisnius lathrobioides       1.00      0.97      0.98        30
#         Quedius fulvicollis       1.00      0.50      0.67         2
#              Medon brunneus       0.82      0.88      0.85        16
#          Philonthus jurgans       0.12      0.12      0.12         8
#        Scopaeus sulcicollis       1.00      0.29      0.45        17
#   Philonthus quisquiliarius       0.86      0.46      0.60        13
#       Gyrohypnus angustatus       0.83      0.56      0.67         9
#       Staphylinus caesareus       0.00      0.00      0.00         5
#           Quedius xanthopus       0.62      0.90      0.73        20
#        Lithocharis ochracea       0.97      0.92      0.95        39
#              Bisnius parcus       0.88      1.00      0.93         7
#        Philonthus binotatus       0.00      0.00      0.00         4
#      Quedius nigrocaeruleus       1.00      1.00      1.00         4
#       Pseudomedon obsoletus       0.71      1.00      0.83        12
#          Philonthus varians       0.57      0.62      0.59        13
#          Gyrohypnus atratus       0.70      0.70      0.70        10
#         Ontholestes murinus       0.85      1.00      0.92        11
#      Xantholinus laevigatus       1.00      0.50      0.67         6
#         Philonthus corvinus       0.64      0.88      0.74         8
#        Quedius semiobscurus       0.80      1.00      0.89         8
#   Heterothops stiglundbergi       1.00      1.00      1.00         3
#        Philonthus concinnus       0.60      0.64      0.62        14
#          Philonthus nigrita       0.85      1.00      0.92        11
#             Nudobius lentus       1.00      0.86      0.92        14
#          Philonthus debilis       0.93      0.70      0.80        20
#       Lithocharis nigriceps       0.89      1.00      0.94        16
#         Philonthus furcifer       1.00      0.50      0.67         8
#         Philonthus confinis       0.60      1.00      0.75         3
#          Bisnius cephalotes       0.79      0.86      0.82        35
#         Philonthus fumarius       0.94      1.00      0.97        16
#        Lathrobium rufipenne       0.85      1.00      0.92        22
#           Ocypus picipennis       0.71      0.91      0.80        11
#          Astenus lyonessius       0.65      0.67      0.66        30
#            Ocypus brunnipes       1.00      1.00      1.00        11
#           Rugilus erichsoni       0.91      0.94      0.92        31
#             Atrecus affinis       1.00      1.00      1.00         9
#           Bisnius nitidulus       0.96      0.93      0.95        28
#         Scopaeus laevigatus       1.00      1.00      1.00         2
#      Philonthus parvicornis       0.57      0.89      0.70         9
#          Philonthus politus       0.70      0.59      0.64        51
#             Othius angustus       0.75      0.67      0.71        18
#        Philonthus ventralis       0.83      0.45      0.59        11
#         Heterothops minutus       1.00      0.83      0.91         6
#           Philonthus micans       1.00      0.67      0.80        18
#          Quedius nitipennis       1.00      0.31      0.48        16
#     Acylophorus glaberrimus       0.92      1.00      0.96        12
#              Medon apicalis       0.73      0.92      0.81        12
#     Leptacinus formicetorum       0.80      1.00      0.89         8
#     Gyrohypnus fracticornis       0.80      0.80      0.80        15
#           Gabrius keysianus       1.00      0.25      0.40         8
#       Tetartopeus quadratus       0.94      0.97      0.96        35
#          Philonthus salinus       1.00      0.77      0.87        13
#          Philonthus albipes       0.71      0.97      0.82        30
#      Leptacinus intermedius       0.80      0.67      0.73         6
# Staphylinus dimidiaticornis       0.50      1.00      0.67         4
#           Euryporus picipes       1.00      0.62      0.77         8
#          Philonthus nitidus       0.94      1.00      0.97        32
#           Quedius boopoides       0.80      0.67      0.73         6
#                Tasgius ater       1.00      1.00      1.00         7
#        Leptacinus batychrus       0.79      0.68      0.73        22
#          Gabrius austriacus       0.67      0.33      0.44         6
#          Philonthus decorus       0.95      0.91      0.93        45
#             Quedius fumatus       0.88      0.94      0.91        16
#        Xantholinus linearis       0.69      0.75      0.72        12
#          Philonthus atratus       0.93      0.79      0.86        34
# Phacophallus parumpunctatus       0.75      1.00      0.86         6
#             Gabrius exiguus       0.50      0.67      0.57         3
#              Remus sericeus       0.92      1.00      0.96        24
#    Platydracus stercorarius       0.91      1.00      0.95        10
#                 Emus hirtus       1.00      1.00      1.00         4
#   Philonthus sanguinolentus       0.83      0.88      0.86        17
#       Neobisnius villosulus       0.88      1.00      0.93         7
#        Gabronthus thermarum       1.00      1.00      1.00         5
#            Quedius fulgidus       1.00      0.80      0.89         5
#         Philonthus ebeninus       0.71      0.83      0.77         6
#              Bisnius puella       0.78      1.00      0.88         7
#           Quedius lucidulus       0.72      0.76      0.74        17
#         Othius subuliformis       0.54      0.64      0.58        11
#        Philonthus laminatus       0.84      0.91      0.87        34
#            Quedius umbrinus       0.89      0.80      0.84        20
#        Ochthephilum collare       1.00      0.50      0.67         2
#             Ocypus fuscatus       0.67      0.75      0.71         8
#         Leptacinus pusillus       0.62      0.83      0.71         6
#          Lathrobium fovulum       0.88      0.79      0.84        29
#              Quedius brevis       1.00      0.88      0.93         8
#         Paederus littoralis       0.95      0.92      0.93        38
#             Achenium humile       1.00      1.00      1.00         8
#           Paederus fuscipes       0.93      1.00      0.97        28
#          Quedius truncicola       0.80      1.00      0.89         4
#        Quedius puncticollis       0.93      0.81      0.87        16
#             Quedius microps       1.00      0.95      0.98        21
#         Quedius longicornis       0.88      0.93      0.90        15
#       Quedius simplicifrons       0.67      0.86      0.75         7
#          Astenus pulchellus       0.64      0.92      0.75        25
#         Quedius mesomelinus       0.88      0.47      0.61        15
#      Dinothenarus pubescens       1.00      0.75      0.86         8
#        Xantholinus tricolor       0.93      1.00      0.97        14
#         Philonthus cognatus       0.93      0.94      0.94        70
#         Rugilus orbiculatus       0.96      0.93      0.95        59
#     Erichsonius cinerascens       0.97      0.92      0.94        36
#             Medon castaneus       1.00      1.00      1.00         9
#        Gabrius splendidulus       0.74      0.89      0.81        19
#     Platydracus latebricola       1.00      0.80      0.89         5
#             Rugilus rufipes       0.98      1.00      0.99        49
#       Creophilus maxillosus       1.00      0.89      0.94         9
#        Lathrobium elongatum       0.84      0.77      0.80        48
#      Philonthus micantoides       0.57      1.00      0.73         4
#    Xantholinus longiventris       0.57      0.73      0.64        11
#         Lathrobium pallidum       0.69      1.00      0.82         9
#       Sunius melanocephalus       0.86      0.78      0.82        23
#          Quedius molochinus       0.80      0.86      0.83        14
#           Gabrius trossulus       0.75      0.90      0.82        10
#      Heterothops dissimilis       1.00      0.43      0.60         7
#      Philonthus intermedius       0.47      0.53      0.50        15
#          Philonthus alpinus       0.67      0.50      0.57         4
#             Quedius picipes       0.92      0.92      0.92        12
#        Lathrobium impressum       0.93      0.96      0.95        54
#       Philonthus discoideus       0.91      1.00      0.95        20
#           Quedius nigriceps       1.00      0.89      0.94         9
#           Atrecus longiceps       1.00      1.00      1.00         5
#         Quedius curtipennis       0.50      0.57      0.53         7
#          Bisnius fimetarius       0.88      0.88      0.88        60
#          Lathrobium dilutum       0.00      0.00      0.00         2
#
#                   micro avg       0.83      0.83      0.83      3381
#                   macro avg       0.81      0.80      0.79      3381
#                weighted avg       0.85      0.83      0.83      3381
# /home/herri/.local/lib/python3.5/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
y_true = val_generator.classes
matplotlib.rcParams['figure.figsize'] = [10, 10]
plot_confusion_matrix(y_true, y_pred, np.array(labels))
# Out:
# Confusion matrix, without normalization
# [[16  0  0 ...  0  0  0]
#  [ 0 49  0 ...  0  0  0]
#  [ 0  0 25 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  4  0  0]
#  [ 0  0  0 ...  0 53  0]
#  [ 0  0  0 ...  0  0  0]]

# %%
labels = (val_generator.class_indices) # dict of label:index
labels = dict((i,l) for l,i in labels.items()) # dict of index:label

# %%
# create pd.dataframe and save predictions to .csv
filenames=[datasetDir + name for name in val_generator.filenames]
y_pred_labels = [labels[y] for y in y_pred]
y_true_labels = [labels[y] for y in y_true]
y_pred3_labels = []
for i,top3 in enumerate(y_pred3):
    l = []
    for top in top3:
        l.append((labels[top], Y_pred[i][top]))
    y_pred3_labels.append(l)

results=pd.DataFrame({"Filename":filenames,
                      "Label":y_true_labels,
                      "Prediction1":y_pred_labels,
                      "Prediction3":y_pred3_labels})
results.to_csv(results_file,index=True)
