# %%
# %config IPCompleter.greedy=True

# %%
import sys
import os
import pandas as pd
sys.path.append("../..") # relative path to module toolkit

# %%
#from keras.applications import ResNet50
#from keras.layers import Dense, GlobalAveragePooling2D
from keras.models import Model, load_model
from keras_preprocessing.image import ImageDataGenerator
from toolkit import getLabelsFromDir, plot_confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# tf.estimator package not installed.
# tf.estimator package not installed.

# %%
# setup
batch_size = 1
val_dir = "../../../images/images_species/val/"
val_images = 3381
datasetDir = "images_species/"
saved_model = 'highest_val_acc.h5'
results_file = "results.csv"

# %%
labels = getLabelsFromDir(val_dir)
val_datagen = ImageDataGenerator(rescale=1./255.)
validation_steps = int(val_images/batch_size)

# %%
model = load_model(saved_model)

# %%
val_generator = val_datagen.flow_from_directory(val_dir,
                                                    classes=labels,
                                                    class_mode="categorical",
                                                    batch_size=batch_size,
                                                    color_mode='rgb',
                                                    target_size=(224, 224),
                                                    shuffle=False,
                                                    seed=1)
# Out:
# Found 3381 images belonging to 200 classes.

# %%
Y_pred = model.predict_generator(val_generator, steps=validation_steps, verbose=1)
# Out:
# 3381/3381 [==============================] - 85s 25ms/step

# %%
y_pred = np.argmax(Y_pred, axis=1)
y_pred3 = [y[-3:] for y in np.argsort(Y_pred, axis=1)]

# %%
#print(classification_report(val_generator.classes, y_pred, target_names=labels))
print(classification_report(val_generator.classes, y_pred, target_names=labels))
# Out:
#                              precision    recall  f1-score   support
#
#             Achenium humile       0.89      1.00      0.94         8
#     Acylophorus glaberrimus       1.00      1.00      1.00        12
#  Acylophorus wagenschieberi       1.00      1.00      1.00         8
#            Astenus gracilis       0.47      0.42      0.44        19
#        Astenus immacullatus       1.00      1.00      1.00        26
#          Astenus lyonessius       0.62      0.60      0.61        30
#            Astenus procerus       1.00      0.87      0.93        15
#          Astenus pulchellus       0.77      0.96      0.86        25
#             Atrecus affinis       1.00      1.00      1.00         9
#           Atrecus longiceps       0.83      1.00      0.91         5
#          Bisnius cephalotes       0.57      0.89      0.70        35
#          Bisnius fimetarius       0.98      0.78      0.87        60
#           Bisnius nitidulus       0.89      0.89      0.89        28
#              Bisnius parcus       1.00      0.71      0.83         7
#        Bisnius pseudoparcus       0.71      1.00      0.83         5
#              Bisnius puella       1.00      1.00      1.00         7
#        Bisnius subuliformis       1.00      1.00      1.00        13
#           Cafius xantholoma       0.98      0.72      0.83        58
#       Creophilus maxillosus       1.00      0.89      0.94         9
#      Dinothenarus pubescens       1.00      1.00      1.00         8
#                 Emus hirtus       1.00      1.00      1.00         4
#     Erichsonius cinerascens       0.97      0.97      0.97        36
#           Euryporus picipes       1.00      1.00      1.00         8
#      Gabrius appendiculatus       0.60      0.75      0.67        12
#          Gabrius austriacus       0.44      0.67      0.53         6
#         Gabrius breviventer       0.46      0.71      0.56        17
#             Gabrius exiguus       0.00      0.00      0.00         3
#           Gabrius keysianus       1.00      0.75      0.86         8
#          Gabrius nigritulus       0.75      0.23      0.35        26
#           Gabrius osseticus       0.92      0.92      0.92        13
#        Gabrius splendidulus       0.78      0.95      0.86        19
#           Gabrius trossulus       1.00      0.90      0.95        10
#        Gauropterus fulgidus       0.88      1.00      0.93        14
#       Gyrohypnus angustatus       1.00      0.44      0.62         9
#          Gyrohypnus atratus       0.89      0.80      0.84        10
#     Gyrohypnus fracticornis       0.71      0.67      0.69        15
#      Gyrohypnus punctulatus       0.67      0.71      0.69        17
#       Heterothops binotatus       0.72      0.87      0.79        15
#      Heterothops dissimilis       1.00      0.43      0.60         7
#         Heterothops minutus       1.00      1.00      1.00         6
#           Heterothops niger       0.82      1.00      0.90         9
#        Heterothops praevius       1.00      0.73      0.84        11
# Heterothops quadripunctulus       0.92      0.92      0.92        12
#   Heterothops stiglundbergi       0.75      1.00      0.86         3
#        Lathrobium brunnipes       1.00      0.86      0.93        58
#          Lathrobium dilutum       0.67      1.00      0.80         2
#        Lathrobium elongatum       0.86      0.65      0.74        48
#          Lathrobium fovulum       0.96      0.86      0.91        29
#          Lathrobium geminum       0.45      0.56      0.50        18
#        Lathrobium impressum       0.98      0.98      0.98        54
#         Lathrobium pallidum       0.82      1.00      0.90         9
#        Lathrobium rufipenne       0.76      1.00      0.86        22
#        Leptacinus batychrus       0.67      0.36      0.47        22
#     Leptacinus formicetorum       0.89      1.00      0.94         8
#      Leptacinus intermedius       0.36      0.67      0.47         6
#         Leptacinus pusillus       0.38      0.83      0.53         6
#       Lithocharis nigriceps       0.89      1.00      0.94        16
#        Lithocharis ochracea       0.97      0.95      0.96        39
#     Lobrathium multipunctum       0.78      0.95      0.86        22
#              Medon apicalis       0.79      0.92      0.85        12
#              Medon brunneus       0.87      0.81      0.84        16
#             Medon castaneus       1.00      1.00      1.00         9
#              Medon ripicola       0.82      0.88      0.85        16
#         Megalinus glabratus       1.00      0.71      0.83         7
#            Bisnius sordidus       0.78      0.84      0.81        50
#        Gabronthus thermarum       0.56      1.00      0.71         5
#       Lathrobium fulvipenne       0.86      0.86      0.86        49
#    Neobisnius lathrobioides       0.97      0.97      0.97        30
#       Paederidus ruficollis       1.00      1.00      1.00        49
#          Philonthus debilis       0.82      0.90      0.86        20
#          Philonthus nitidus       1.00      1.00      1.00        32
#    Platydracus stercorarius       0.91      1.00      0.95        10
#          Quedius levicollis       0.88      0.78      0.82         9
#        Quedius semiobscurus       1.00      0.75      0.86         8
#       Neobisnius villosulus       0.86      0.86      0.86         7
#             Nudobius lentus       0.91      0.71      0.80        14
#        Ochthephilum collare       1.00      0.50      0.67         2
#    Ochthephilum fracticorne       0.94      0.89      0.92        37
#        Ocypus aeneocephalus       0.75      1.00      0.86         9
#            Ocypus brunnipes       1.00      0.91      0.95        11
#             Ocypus fuscatus       0.29      0.75      0.41         8
#               Ocypus nitens       0.81      1.00      0.90        13
#                Ocypus olens       1.00      1.00      1.00         5
#         Ocypus ophthalmicus       0.83      0.83      0.83         6
#           Ocypus picipennis       1.00      0.82      0.90        11
#         Ontholestes murinus       1.00      1.00      1.00        11
#     Ontholestes tessellatus       1.00      1.00      1.00         7
#             Othius angustus       0.87      0.72      0.79        18
#          Othius punctulatus       1.00      1.00      1.00        11
#         Othius subuliformis       0.64      0.82      0.72        11
#           Paederus fuscipes       0.67      1.00      0.80        28
#         Paederus littoralis       1.00      0.89      0.94        38
#           Paederus riparius       0.91      0.75      0.82        56
# Phacophallus parumpunctatus       0.50      0.83      0.62         6
#         Philonthus addendus       0.59      0.56      0.57        18
#          Philonthus albipes       0.83      1.00      0.91        30
#          Philonthus alpinus       0.50      0.50      0.50         4
#          Philonthus atratus       0.75      0.71      0.73        34
#        Philonthus binotatus       0.67      0.50      0.57         4
#      Philonthus carbonarius       0.90      0.62      0.73        71
#         Philonthus cognatus       1.00      0.79      0.88        70
#        Philonthus concinnus       0.54      0.93      0.68        14
#         Philonthus confinis       0.50      1.00      0.67         3
#        Philonthus corruscus       0.80      1.00      0.89         4
#         Philonthus corvinus       0.55      0.75      0.63         8
#       Philonthus cruentatus       0.53      1.00      0.70         8
#          Philonthus decorus       0.80      0.44      0.57        45
#       Philonthus discoideus       0.95      1.00      0.98        20
#         Philonthus ebeninus       0.75      1.00      0.86         6
#         Philonthus fumarius       1.00      1.00      1.00        16
#         Philonthus furcifer       0.80      0.50      0.62         8
#      Philonthus intermedius       0.52      0.93      0.67        15
#          Philonthus jurgans       0.00      0.00      0.00         8
#        Philonthus laminatus       0.95      0.53      0.68        34
#          Philonthus lepidus       0.92      1.00      0.96        12
#      Philonthus longicornis       0.73      0.69      0.71        16
#      Philonthus mannerheimi       0.29      0.82      0.43        11
#       Philonthus marginatus       0.97      1.00      0.99        33
#           Philonthus micans       0.94      0.89      0.91        18
#      Philonthus micantoides       0.75      0.75      0.75         4
#          Philonthus nigrita       0.92      1.00      0.96        11
#     Philonthus nitidicollis       0.50      0.50      0.50         2
#      Philonthus parvicornis       0.70      0.78      0.74         9
#          Philonthus politus       0.79      0.51      0.62        51
#          Philonthus punctus       0.71      0.62      0.67         8
#   Philonthus quisquiliarius       0.64      0.54      0.58        13
#      Philonthus rectangulus       0.89      1.00      0.94        16
#      Philonthus rubripennis       1.00      1.00      1.00        17
#          Philonthus rufipes       0.10      0.42      0.16        12
#          Philonthus salinus       0.81      1.00      0.90        13
#   Philonthus sanguinolentus       0.88      0.88      0.88        17
#        Philonthus splendens       0.90      0.74      0.81        35
#        Philonthus succicola       0.80      0.45      0.58        44
#      Philonthus tenuicornis       0.68      0.56      0.61        27
#          Philonthus varians       0.56      0.69      0.62        13
#        Philonthus ventralis       1.00      0.64      0.78        11
#        Platydracus fulvipes       0.88      1.00      0.93         7
#     Platydracus latebricola       0.80      0.80      0.80         5
#     Pseudomedon obscurellus       0.96      0.86      0.91        29
#       Pseudomedon obsoletus       0.75      1.00      0.86        12
#           Quedius auricomus       1.00      1.00      1.00        12
#           Quedius boopoides       0.29      0.33      0.31         6
#               Quedius boops       0.50      0.71      0.59         7
#         Quedius brevicornis       0.81      1.00      0.90        13
#              Quedius brevis       1.00      0.88      0.93         8
#             Quedius cinctus       0.92      0.86      0.89        14
#            Quedius cruentus       1.00      0.84      0.91        19
#         Quedius curtipennis       1.00      0.43      0.60         7
#            Quedius fulgidus       1.00      1.00      1.00         5
#         Quedius fuliginosus       0.69      0.79      0.73        14
#         Quedius fulvicollis       0.40      1.00      0.57         2
#             Quedius fumatus       0.93      0.81      0.87        16
#          Quedius infuscatus       0.80      1.00      0.89         4
#           Quedius lateralis       0.85      0.92      0.88        12
#         Quedius longicornis       0.94      1.00      0.97        15
#           Quedius lucidulus       0.75      0.71      0.73        17
#          Quedius maurorufus       0.78      0.82      0.80        17
#              Quedius maurus       0.62      0.80      0.70        10
#         Quedius mesomelinus       0.67      0.40      0.50        15
#             Quedius microps       0.91      1.00      0.95        21
#          Quedius molochinus       1.00      0.86      0.92        14
#           Quedius nigriceps       0.90      1.00      0.95         9
#      Quedius nigrocaeruleus       0.80      1.00      0.89         4
#          Quedius nitipennis       0.67      0.25      0.36        16
#          Quedius persimilis       0.71      0.83      0.77        12
#             Quedius picipes       1.00      1.00      1.00        12
#        Quedius puncticollis       1.00      0.75      0.86        16
#         Quedius scintillans       0.64      0.78      0.70        18
#              Quedius scitus       1.00      1.00      1.00         9
#          Quedius semiaeneus       0.75      1.00      0.86         9
#       Quedius simplicifrons       0.78      1.00      0.88         7
#           Quedius suturalis       0.84      1.00      0.91        16
#          Quedius truncicola       0.50      1.00      0.67         4
#            Quedius umbrinus       0.80      0.80      0.80        20
#           Quedius xanthopus       0.68      0.85      0.76        20
#              Remus sericeus       0.96      0.96      0.96        24
#           Rugilus erichsoni       0.86      0.77      0.81        31
#         Rugilus orbiculatus       0.85      0.88      0.87        59
#             Rugilus rufipes       0.96      1.00      0.98        49
#         Scopaeus laevigatus       1.00      1.00      1.00         2
#            Scopaeus minutus       0.71      0.89      0.79        19
#        Scopaeus sulcicollis       0.82      0.53      0.64        17
#       Staphylinus caesareus       1.00      0.20      0.33         5
# Staphylinus dimidiaticornis       0.50      1.00      0.67         4
#   Staphylinus erythropterus       1.00      1.00      1.00         8
#              Sunius bicolor       0.77      0.94      0.85        18
#       Sunius melanocephalus       0.95      0.83      0.88        23
#                Tasgius ater       1.00      0.71      0.83         7
#          Tasgius globulifer       0.80      0.80      0.80         5
#          Tasgius melanarius       0.90      0.82      0.86        11
#           Tasgius morsitans       1.00      1.00      1.00         9
#       Tetartopeus quadratus       0.89      0.97      0.93        35
#      Tetartopeus terminatus       0.91      0.91      0.91        45
#          Velleius dilatatus       0.83      1.00      0.91         5
#         Xantholinus dvoraki       0.67      0.86      0.75         7
#        Xantholinus gallicus       0.00      0.00      0.00         2
#      Xantholinus laevigatus       0.56      0.83      0.67         6
#        Xantholinus linearis       0.60      0.75      0.67        12
#    Xantholinus longiventris       0.80      0.73      0.76        11
#        Xantholinus tricolor       0.87      0.93      0.90        14
#
#                   micro avg       0.82      0.82      0.82      3381
#                   macro avg       0.80      0.82      0.79      3381
#                weighted avg       0.84      0.82      0.82      3381
# /usr/local/lib/python2.7/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
y_true = val_generator.classes
matplotlib.rcParams['figure.figsize'] = [10, 10]
plot_confusion_matrix(y_true, y_pred, np.array(labels))
# Out:
# Confusion matrix, without normalization
# [[ 8  0  0 ...,  0  0  0]
#  [ 0 12  0 ...,  0  0  0]
#  [ 0  0  8 ...,  0  0  0]
#  ...,
#  [ 0  0  0 ...,  9  1  0]
#  [ 0  0  0 ...,  1  8  0]
#  [ 0  0  0 ...,  0  0 13]]

# %%
labels = (val_generator.class_indices) # dict of label:index
labels = dict((i,l) for l,i in labels.items()) # dict of index:label

# %%
# create pd.dataframe and save predictions to .csv
filenames=[datasetDir + name for name in val_generator.filenames]
y_pred_labels = [labels[y] for y in y_pred]
y_true_labels = [labels[y] for y in y_true]
y_pred3_labels = []
for i,top3 in enumerate(y_pred3):
    l = []
    for top in top3:
        l.append((labels[top], Y_pred[i][top]))
    y_pred3_labels.append(l)

results=pd.DataFrame({"Filename":filenames,
                      "Label":y_true_labels,
                      "Prediction1":y_pred_labels,
                      "Prediction3":y_pred3_labels})
results.to_csv(results_file,index=True)
