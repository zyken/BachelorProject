# %%
# %config IPCompleter.greedy=True

# %%
import sys
import os
import pandas as pd
sys.path.append("../..") # relative path to module toolkit

# %%
#from keras.applications import ResNet50
#from keras.layers import Dense, GlobalAveragePooling2D
from keras.models import Model, load_model
from keras_preprocessing.image import ImageDataGenerator
from toolkit import getLabelsFromDir, plot_confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# setup
batch_size = 1
val_dir = "../../../images/images_species/val/"
val_images = 3381
datasetDir = "images_species/"
saved_model = 'highest_val_acc.h5'
results_file = "results.csv"

# %%
labels = getLabelsFromDir(val_dir)
val_datagen = ImageDataGenerator(rescale=1./255.)
validation_steps = int(val_images/batch_size)

# %%
model = load_model(saved_model)

# %%
val_generator = val_datagen.flow_from_directory(val_dir,
                                                    classes=labels,
                                                    class_mode="categorical",
                                                    batch_size=batch_size,
                                                    color_mode='rgb',
                                                    target_size=(224, 224),
                                                    shuffle=False,
                                                    seed=1)
# Out:
# Found 3381 images belonging to 200 classes.

# %%
Y_pred = model.predict_generator(val_generator, steps=validation_steps, verbose=1)
# Out:
# 3381/3381 [==============================] - 51s 15ms/step

# %%
y_pred = np.argmax(Y_pred, axis=1)
y_pred3 = [y[-3:] for y in np.argsort(Y_pred, axis=1)]

# %%
print(classification_report(val_generator.classes, y_pred, target_names=labels))
# Out:
#                              precision    recall  f1-score   support
#
#      Philonthus tenuicornis       0.46      0.44      0.45        27
#       Paederidus ruficollis       0.94      1.00      0.97        49
#        Philonthus splendens       0.94      0.46      0.62        35
#     Pseudomedon obscurellus       0.97      0.97      0.97        29
#   Staphylinus erythropterus       0.89      1.00      0.94         8
#     Lobrathium multipunctum       0.68      0.86      0.76        22
#     Philonthus nitidicollis       0.00      0.00      0.00         2
#         Xantholinus dvoraki       0.67      0.57      0.62         7
#          Lathrobium geminum       0.25      0.11      0.15        18
#           Paederus riparius       0.98      0.82      0.89        56
#        Heterothops praevius       0.60      0.55      0.57        11
#           Gabrius osseticus       1.00      0.38      0.56        13
#      Philonthus carbonarius       0.61      0.65      0.63        71
#          Quedius semiaeneus       0.64      1.00      0.78         9
#           Cafius xantholoma       0.80      0.83      0.81        58
#          Othius punctulatus       0.77      0.91      0.83        11
#       Heterothops binotatus       0.69      0.60      0.64        15
#        Philonthus succicola       0.68      0.61      0.64        44
#      Philonthus rectangulus       0.80      1.00      0.89        16
#         Ocypus ophthalmicus       0.00      0.00      0.00         6
#          Quedius maurorufus       0.52      0.65      0.58        17
#           Quedius suturalis       0.72      0.81      0.76        16
#     Ontholestes tessellatus       0.78      1.00      0.88         7
#        Bisnius subuliformis       0.81      1.00      0.90        13
#          Philonthus lepidus       1.00      0.92      0.96        12
# Heterothops quadripunctulus       0.64      0.58      0.61        12
#         Philonthus addendus       0.55      0.33      0.41        18
#           Quedius auricomus       1.00      1.00      1.00        12
#          Philonthus punctus       0.38      0.62      0.48         8
#          Quedius levicollis       0.88      0.78      0.82         9
#                Ocypus olens       0.80      0.80      0.80         5
#        Ocypus aeneocephalus       0.89      0.89      0.89         9
#    Ochthephilum fracticorne       0.81      0.81      0.81        37
#              Quedius scitus       1.00      0.67      0.80         9
#      Philonthus mannerheimi       0.44      0.64      0.52        11
#  Acylophorus wagenschieberi       1.00      1.00      1.00         8
#        Astenus immacullatus       0.90      1.00      0.95        26
#         Quedius brevicornis       0.89      0.62      0.73        13
#         Quedius fuliginosus       0.67      0.86      0.75        14
#      Tetartopeus terminatus       0.80      0.91      0.85        45
#        Platydracus fulvipes       1.00      0.86      0.92         7
#       Philonthus cruentatus       0.27      1.00      0.42         8
#         Quedius scintillans       0.62      0.44      0.52        18
#         Megalinus glabratus       1.00      0.57      0.73         7
#           Heterothops niger       0.44      0.78      0.56         9
#           Quedius lateralis       0.61      0.92      0.73        12
#        Philonthus corruscus       1.00      0.75      0.86         4
#           Tasgius morsitans       0.75      1.00      0.86         9
#              Medon ripicola       0.61      0.69      0.65        16
#      Gyrohypnus punctulatus       0.50      0.47      0.48        17
#             Quedius cinctus       0.77      0.71      0.74        14
#      Philonthus longicornis       0.50      0.12      0.20        16
#            Astenus gracilis       0.39      0.63      0.48        19
#        Lathrobium brunnipes       0.93      0.74      0.83        58
#        Bisnius pseudoparcus       0.50      0.60      0.55         5
#          Quedius infuscatus       1.00      0.75      0.86         4
#              Quedius maurus       0.57      0.40      0.47        10
#          Quedius persimilis       0.60      1.00      0.75        12
#         Gabrius breviventer       0.43      0.59      0.50        17
#            Scopaeus minutus       0.79      1.00      0.88        19
#            Bisnius sordidus       0.60      0.74      0.66        50
#               Ocypus nitens       0.50      0.85      0.63        13
#          Tasgius melanarius       0.67      0.73      0.70        11
#        Gauropterus fulgidus       0.81      0.93      0.87        14
#        Xantholinus gallicus       0.67      1.00      0.80         2
#          Gabrius nigritulus       0.27      0.12      0.16        26
#       Philonthus marginatus       0.87      1.00      0.93        33
#      Philonthus rubripennis       1.00      1.00      1.00        17
#       Lathrobium fulvipenne       0.66      0.86      0.74        49
#              Sunius bicolor       0.93      0.72      0.81        18
#          Tasgius globulifer       0.75      0.60      0.67         5
#            Astenus procerus       0.70      0.47      0.56        15
#      Gabrius appendiculatus       0.44      0.67      0.53        12
#          Philonthus rufipes       0.30      0.50      0.37        12
#               Quedius boops       0.57      0.57      0.57         7
#            Quedius cruentus       1.00      0.74      0.85        19
#          Velleius dilatatus       1.00      0.80      0.89         5
#    Neobisnius lathrobioides       0.96      0.83      0.89        30
#         Quedius fulvicollis       0.67      1.00      0.80         2
#              Medon brunneus       0.79      0.69      0.73        16
#          Philonthus jurgans       0.00      0.00      0.00         8
#        Scopaeus sulcicollis       1.00      0.59      0.74        17
#   Philonthus quisquiliarius       1.00      0.38      0.56        13
#       Gyrohypnus angustatus       0.58      0.78      0.67         9
#       Staphylinus caesareus       0.83      1.00      0.91         5
#           Quedius xanthopus       0.68      0.65      0.67        20
#        Lithocharis ochracea       0.95      0.92      0.94        39
#              Bisnius parcus       1.00      0.57      0.73         7
#        Philonthus binotatus       0.67      0.50      0.57         4
#      Quedius nigrocaeruleus       0.67      1.00      0.80         4
#       Pseudomedon obsoletus       0.67      1.00      0.80        12
#          Philonthus varians       0.33      0.31      0.32        13
#          Gyrohypnus atratus       1.00      0.60      0.75        10
#         Ontholestes murinus       1.00      1.00      1.00        11
#      Xantholinus laevigatus       0.71      0.83      0.77         6
#         Philonthus corvinus       0.80      0.50      0.62         8
#        Quedius semiobscurus       0.70      0.88      0.78         8
#   Heterothops stiglundbergi       0.75      1.00      0.86         3
#        Philonthus concinnus       0.64      0.50      0.56        14
#          Philonthus nigrita       1.00      1.00      1.00        11
#             Nudobius lentus       0.92      0.79      0.85        14
#          Philonthus debilis       0.67      0.90      0.77        20
#       Lithocharis nigriceps       1.00      0.88      0.93        16
#         Philonthus furcifer       1.00      0.62      0.77         8
#         Philonthus confinis       0.50      1.00      0.67         3
#          Bisnius cephalotes       0.71      0.49      0.58        35
#         Philonthus fumarius       0.88      0.94      0.91        16
#        Lathrobium rufipenne       0.67      0.91      0.77        22
#           Ocypus picipennis       0.78      0.64      0.70        11
#          Astenus lyonessius       0.67      0.47      0.55        30
#            Ocypus brunnipes       0.85      1.00      0.92        11
#           Rugilus erichsoni       0.95      0.58      0.72        31
#             Atrecus affinis       0.90      1.00      0.95         9
#           Bisnius nitidulus       0.84      0.57      0.68        28
#         Scopaeus laevigatus       1.00      1.00      1.00         2
#      Philonthus parvicornis       0.41      0.78      0.54         9
#          Philonthus politus       0.45      0.37      0.41        51
#             Othius angustus       0.85      0.61      0.71        18
#        Philonthus ventralis       0.64      0.64      0.64        11
#         Heterothops minutus       1.00      0.83      0.91         6
#           Philonthus micans       0.80      0.89      0.84        18
#          Quedius nitipennis       1.00      0.25      0.40        16
#     Acylophorus glaberrimus       0.86      1.00      0.92        12
#              Medon apicalis       0.53      0.67      0.59        12
#     Leptacinus formicetorum       0.67      1.00      0.80         8
#     Gyrohypnus fracticornis       0.60      0.60      0.60        15
#           Gabrius keysianus       0.86      0.75      0.80         8
#       Tetartopeus quadratus       0.96      0.69      0.80        35
#          Philonthus salinus       0.93      1.00      0.96        13
#          Philonthus albipes       0.57      0.80      0.67        30
#      Leptacinus intermedius       0.60      0.50      0.55         6
# Staphylinus dimidiaticornis       1.00      1.00      1.00         4
#           Euryporus picipes       1.00      0.75      0.86         8
#          Philonthus nitidus       0.94      0.91      0.92        32
#           Quedius boopoides       0.75      0.50      0.60         6
#                Tasgius ater       0.86      0.86      0.86         7
#        Leptacinus batychrus       0.64      0.64      0.64        22
#          Gabrius austriacus       0.29      0.67      0.40         6
#          Philonthus decorus       0.91      0.89      0.90        45
#             Quedius fumatus       0.72      0.81      0.76        16
#        Xantholinus linearis       0.73      0.67      0.70        12
#          Philonthus atratus       0.75      0.53      0.62        34
# Phacophallus parumpunctatus       0.57      0.67      0.62         6
#             Gabrius exiguus       0.00      0.00      0.00         3
#              Remus sericeus       0.81      0.88      0.84        24
#    Platydracus stercorarius       1.00      1.00      1.00        10
#                 Emus hirtus       1.00      1.00      1.00         4
#   Philonthus sanguinolentus       0.92      0.71      0.80        17
#       Neobisnius villosulus       0.67      0.57      0.62         7
#        Gabronthus thermarum       0.56      1.00      0.71         5
#            Quedius fulgidus       1.00      0.40      0.57         5
#         Philonthus ebeninus       1.00      0.67      0.80         6
#              Bisnius puella       0.88      1.00      0.93         7
#           Quedius lucidulus       0.53      0.94      0.68        17
#         Othius subuliformis       0.56      0.91      0.69        11
#        Philonthus laminatus       0.70      0.56      0.62        34
#            Quedius umbrinus       0.55      0.30      0.39        20
#        Ochthephilum collare       1.00      0.50      0.67         2
#             Ocypus fuscatus       0.56      0.62      0.59         8
#         Leptacinus pusillus       0.50      0.50      0.50         6
#          Lathrobium fovulum       0.77      0.83      0.80        29
#              Quedius brevis       0.67      1.00      0.80         8
#         Paederus littoralis       0.84      1.00      0.92        38
#             Achenium humile       0.83      0.62      0.71         8
#           Paederus fuscipes       0.93      1.00      0.97        28
#          Quedius truncicola       0.80      1.00      0.89         4
#        Quedius puncticollis       0.50      0.81      0.62        16
#             Quedius microps       0.83      0.90      0.86        21
#         Quedius longicornis       0.88      0.93      0.90        15
#       Quedius simplicifrons       0.58      1.00      0.74         7
#          Astenus pulchellus       0.69      0.80      0.74        25
#         Quedius mesomelinus       0.67      0.40      0.50        15
#      Dinothenarus pubescens       0.89      1.00      0.94         8
#        Xantholinus tricolor       0.76      0.93      0.84        14
#         Philonthus cognatus       0.85      0.83      0.84        70
#         Rugilus orbiculatus       0.79      0.88      0.83        59
#     Erichsonius cinerascens       0.92      0.94      0.93        36
#             Medon castaneus       0.90      1.00      0.95         9
#        Gabrius splendidulus       0.82      0.95      0.88        19
#     Platydracus latebricola       0.80      0.80      0.80         5
#             Rugilus rufipes       0.94      0.96      0.95        49
#       Creophilus maxillosus       1.00      1.00      1.00         9
#        Lathrobium elongatum       0.74      0.48      0.58        48
#      Philonthus micantoides       0.67      1.00      0.80         4
#    Xantholinus longiventris       0.89      0.73      0.80        11
#         Lathrobium pallidum       0.75      1.00      0.86         9
#       Sunius melanocephalus       0.96      0.96      0.96        23
#          Quedius molochinus       1.00      0.43      0.60        14
#           Gabrius trossulus       0.77      1.00      0.87        10
#      Heterothops dissimilis       0.45      0.71      0.56         7
#      Philonthus intermedius       0.41      0.87      0.55        15
#          Philonthus alpinus       0.00      0.00      0.00         4
#             Quedius picipes       0.63      1.00      0.77        12
#        Lathrobium impressum       0.96      0.87      0.91        54
#       Philonthus discoideus       0.94      0.75      0.83        20
#           Quedius nigriceps       1.00      1.00      1.00         9
#           Atrecus longiceps       1.00      1.00      1.00         5
#         Quedius curtipennis       0.75      0.43      0.55         7
#          Bisnius fimetarius       0.86      0.60      0.71        60
#          Lathrobium dilutum       1.00      0.50      0.67         2
#
#                   micro avg       0.74      0.74      0.74      3381
#                   macro avg       0.74      0.74      0.72      3381
#                weighted avg       0.76      0.74      0.74      3381
# /home/herri/.local/lib/python3.5/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
y_true = val_generator.classes
matplotlib.rcParams['figure.figsize'] = [10, 10]
plot_confusion_matrix(y_true, y_pred, np.array(labels))
# Out:
# Confusion matrix, without normalization
# [[12  0  0 ...  0  0  0]
#  [ 0 49  0 ...  0  0  0]
#  [ 2  0 16 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  3  0  0]
#  [ 0  0  0 ...  0 36  0]
#  [ 0  0  0 ...  0  0  1]]

# %%
labels = (val_generator.class_indices) # dict of label:index
labels = dict((i,l) for l,i in labels.items()) # dict of index:label

# %%
# create pd.dataframe and save predictions to .csv
filenames=[datasetDir + name for name in val_generator.filenames]
y_pred_labels = [labels[y] for y in y_pred]
y_true_labels = [labels[y] for y in y_true]
y_pred3_labels = []
for i,top3 in enumerate(y_pred3):
    l = []
    for top in top3:
        l.append((labels[top], Y_pred[i][top]))
    y_pred3_labels.append(l)

results=pd.DataFrame({"Filename":filenames,
                      "Label":y_true_labels,
                      "Prediction1":y_pred_labels,
                      "Prediction3":y_pred3_labels})
results.to_csv(results_file,index=True)
