# %%
# %config IPCompleter.greedy=True

# %%
import sys
import os
import pandas as pd
sys.path.append("../..") # relative path to module toolkit

# %%
#from keras.applications import ResNet50
#from keras.layers import Dense, GlobalAveragePooling2D
from keras.models import Model, load_model
from keras_preprocessing.image import ImageDataGenerator
from toolkit import getLabelsFromDir, plot_confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# setup
batch_size = 1
val_dir = "../../../images/images_species/val/"
val_images = 3381
datasetDir = "images_species/"
saved_model = 'resNet50pretrained_highest_val_acc.h5'
results_file = "results.csv"

# %%
labels = getLabelsFromDir(val_dir)
val_datagen = ImageDataGenerator(rescale=1./255.)
validation_steps = int(val_images/batch_size)

# %%
model = load_model(saved_model)

# %%
val_generator = val_datagen.flow_from_directory(val_dir,
                                                    classes=labels,
                                                    class_mode="categorical",
                                                    batch_size=batch_size,
                                                    color_mode='rgb',
                                                    target_size=(416, 416),
                                                    shuffle=False,
                                                    seed=1)
# Out:
# Found 3381 images belonging to 200 classes.

# %%
Y_pred = model.predict_generator(val_generator, steps=validation_steps, verbose=1)
# Out:
# 3381/3381 [==============================] - 96s 28ms/step

# %%
y_pred = np.argmax(Y_pred, axis=1)
y_pred3 = [y[-3:] for y in np.argsort(Y_pred, axis=1)]

# %%
def classification_report_csv(report):
    report_data = []
    lines = report.split('\n')
    for line in lines[2:-3]:
        row = {}
        if line == '':
            continue
        row_data = line.split(' ')
        row_data = [data for data in row_data if data]
        row['class'] = row_data[0] + " " + row_data[1]
        row['precision'] = float(row_data[2])
        row['recall'] = float(row_data[3])
        row['f1_score'] = float(row_data[4])
        row['support'] = float(row_data[5])
        report_data.append(row)
    dataframe = pd.DataFrame.from_dict(report_data)
    dataframe.to_csv('classification_report2.csv', index = False)

# %%
report = classification_report(val_generator.classes, y_pred, target_names=labels)
classification_report_csv(report)
print(report)
# Out:
#                              precision    recall  f1-score   support
#
#      Philonthus tenuicornis       0.61      0.85      0.71        27
#       Paederidus ruficollis       0.98      1.00      0.99        49
#        Philonthus splendens       0.94      0.94      0.94        35
#     Pseudomedon obscurellus       0.94      1.00      0.97        29
#   Staphylinus erythropterus       1.00      1.00      1.00         8
#     Lobrathium multipunctum       0.81      1.00      0.90        22
#     Philonthus nitidicollis       0.50      0.50      0.50         2
#         Xantholinus dvoraki       0.78      1.00      0.88         7
#          Lathrobium geminum       0.79      0.61      0.69        18
#           Paederus riparius       0.96      0.96      0.96        56
#        Heterothops praevius       0.83      0.91      0.87        11
#           Gabrius osseticus       0.92      0.92      0.92        13
#      Philonthus carbonarius       0.95      0.76      0.84        71
#          Quedius semiaeneus       0.90      1.00      0.95         9
#           Cafius xantholoma       1.00      0.98      0.99        58
#          Othius punctulatus       1.00      1.00      1.00        11
#       Heterothops binotatus       0.62      0.87      0.72        15
#        Philonthus succicola       0.74      0.73      0.74        44
#      Philonthus rectangulus       1.00      0.94      0.97        16
#         Ocypus ophthalmicus       1.00      1.00      1.00         6
#          Quedius maurorufus       0.94      0.94      0.94        17
#           Quedius suturalis       0.89      1.00      0.94        16
#     Ontholestes tessellatus       0.78      1.00      0.88         7
#        Bisnius subuliformis       0.93      1.00      0.96        13
#          Philonthus lepidus       1.00      1.00      1.00        12
# Heterothops quadripunctulus       1.00      1.00      1.00        12
#         Philonthus addendus       0.80      0.67      0.73        18
#           Quedius auricomus       1.00      1.00      1.00        12
#          Philonthus punctus       0.78      0.88      0.82         8
#          Quedius levicollis       0.83      0.56      0.67         9
#                Ocypus olens       1.00      1.00      1.00         5
#        Ocypus aeneocephalus       1.00      1.00      1.00         9
#    Ochthephilum fracticorne       0.97      0.97      0.97        37
#              Quedius scitus       0.82      1.00      0.90         9
#      Philonthus mannerheimi       0.59      0.91      0.71        11
#  Acylophorus wagenschieberi       1.00      1.00      1.00         8
#        Astenus immacullatus       0.96      1.00      0.98        26
#         Quedius brevicornis       1.00      1.00      1.00        13
#         Quedius fuliginosus       0.92      0.86      0.89        14
#      Tetartopeus terminatus       0.98      0.93      0.95        45
#        Platydracus fulvipes       1.00      1.00      1.00         7
#       Philonthus cruentatus       0.67      1.00      0.80         8
#         Quedius scintillans       0.87      0.72      0.79        18
#         Megalinus glabratus       1.00      1.00      1.00         7
#           Heterothops niger       1.00      1.00      1.00         9
#           Quedius lateralis       1.00      0.92      0.96        12
#        Philonthus corruscus       1.00      1.00      1.00         4
#           Tasgius morsitans       1.00      1.00      1.00         9
#              Medon ripicola       0.94      0.94      0.94        16
#      Gyrohypnus punctulatus       0.72      0.76      0.74        17
#             Quedius cinctus       0.93      0.93      0.93        14
#      Philonthus longicornis       1.00      0.56      0.72        16
#            Astenus gracilis       0.39      0.47      0.43        19
#        Lathrobium brunnipes       0.95      0.97      0.96        58
#        Bisnius pseudoparcus       0.62      1.00      0.77         5
#          Quedius infuscatus       1.00      0.75      0.86         4
#              Quedius maurus       0.75      0.90      0.82        10
#          Quedius persimilis       0.75      0.75      0.75        12
#         Gabrius breviventer       0.48      0.82      0.61        17
#            Scopaeus minutus       0.79      1.00      0.88        19
#            Bisnius sordidus       0.92      0.94      0.93        50
#               Ocypus nitens       0.75      0.92      0.83        13
#          Tasgius melanarius       0.86      0.55      0.67        11
#        Gauropterus fulgidus       1.00      1.00      1.00        14
#        Xantholinus gallicus       1.00      0.50      0.67         2
#          Gabrius nigritulus       1.00      0.12      0.21        26
#       Philonthus marginatus       1.00      1.00      1.00        33
#      Philonthus rubripennis       1.00      1.00      1.00        17
#       Lathrobium fulvipenne       0.92      0.90      0.91        49
#              Sunius bicolor       0.94      0.89      0.91        18
#          Tasgius globulifer       0.62      1.00      0.77         5
#            Astenus procerus       1.00      0.87      0.93        15
#      Gabrius appendiculatus       0.79      0.92      0.85        12
#          Philonthus rufipes       0.88      0.58      0.70        12
#               Quedius boops       0.70      1.00      0.82         7
#            Quedius cruentus       1.00      0.95      0.97        19
#          Velleius dilatatus       1.00      1.00      1.00         5
#    Neobisnius lathrobioides       1.00      1.00      1.00        30
#         Quedius fulvicollis       1.00      1.00      1.00         2
#              Medon brunneus       0.94      1.00      0.97        16
#          Philonthus jurgans       0.11      0.12      0.12         8
#        Scopaeus sulcicollis       1.00      0.71      0.83        17
#   Philonthus quisquiliarius       0.72      1.00      0.84        13
#       Gyrohypnus angustatus       0.75      0.33      0.46         9
#       Staphylinus caesareus       1.00      1.00      1.00         5
#           Quedius xanthopus       0.91      1.00      0.95        20
#        Lithocharis ochracea       1.00      0.97      0.99        39
#              Bisnius parcus       0.75      0.86      0.80         7
#        Philonthus binotatus       0.50      0.25      0.33         4
#      Quedius nigrocaeruleus       0.75      0.75      0.75         4
#       Pseudomedon obsoletus       1.00      0.92      0.96        12
#          Philonthus varians       0.75      0.92      0.83        13
#          Gyrohypnus atratus       0.91      1.00      0.95        10
#         Ontholestes murinus       0.79      1.00      0.88        11
#      Xantholinus laevigatus       1.00      0.50      0.67         6
#         Philonthus corvinus       0.89      1.00      0.94         8
#        Quedius semiobscurus       1.00      1.00      1.00         8
#   Heterothops stiglundbergi       1.00      0.67      0.80         3
#        Philonthus concinnus       0.82      1.00      0.90        14
#          Philonthus nigrita       1.00      1.00      1.00        11
#             Nudobius lentus       1.00      0.93      0.96        14
#          Philonthus debilis       0.83      0.95      0.88        20
#       Lithocharis nigriceps       0.94      1.00      0.97        16
#         Philonthus furcifer       1.00      0.50      0.67         8
#         Philonthus confinis       0.38      1.00      0.55         3
#          Bisnius cephalotes       0.77      0.94      0.85        35
#         Philonthus fumarius       1.00      1.00      1.00        16
#        Lathrobium rufipenne       0.88      1.00      0.94        22
#           Ocypus picipennis       1.00      1.00      1.00        11
#          Astenus lyonessius       0.70      0.53      0.60        30
#            Ocypus brunnipes       1.00      1.00      1.00        11
#           Rugilus erichsoni       0.94      0.94      0.94        31
#             Atrecus affinis       1.00      1.00      1.00         9
#           Bisnius nitidulus       1.00      1.00      1.00        28
#         Scopaeus laevigatus       1.00      1.00      1.00         2
#      Philonthus parvicornis       0.89      0.89      0.89         9
#          Philonthus politus       0.87      0.65      0.74        51
#             Othius angustus       0.88      0.78      0.82        18
#        Philonthus ventralis       0.88      0.64      0.74        11
#         Heterothops minutus       1.00      0.83      0.91         6
#           Philonthus micans       1.00      0.83      0.91        18
#          Quedius nitipennis       1.00      0.69      0.81        16
#     Acylophorus glaberrimus       1.00      1.00      1.00        12
#              Medon apicalis       1.00      0.92      0.96        12
#     Leptacinus formicetorum       0.80      1.00      0.89         8
#     Gyrohypnus fracticornis       0.69      0.73      0.71        15
#           Gabrius keysianus       1.00      0.88      0.93         8
#       Tetartopeus quadratus       0.92      1.00      0.96        35
#          Philonthus salinus       1.00      1.00      1.00        13
#          Philonthus albipes       0.86      1.00      0.92        30
#      Leptacinus intermedius       0.56      0.83      0.67         6
# Staphylinus dimidiaticornis       1.00      1.00      1.00         4
#           Euryporus picipes       1.00      1.00      1.00         8
#          Philonthus nitidus       1.00      1.00      1.00        32
#           Quedius boopoides       0.57      0.67      0.62         6
#                Tasgius ater       1.00      1.00      1.00         7
#        Leptacinus batychrus       0.88      0.68      0.77        22
#          Gabrius austriacus       1.00      0.67      0.80         6
#          Philonthus decorus       1.00      0.82      0.90        45
#             Quedius fumatus       1.00      1.00      1.00        16
#        Xantholinus linearis       0.82      0.75      0.78        12
#          Philonthus atratus       1.00      0.82      0.90        34
# Phacophallus parumpunctatus       0.60      1.00      0.75         6
#             Gabrius exiguus       1.00      0.67      0.80         3
#              Remus sericeus       1.00      1.00      1.00        24
#    Platydracus stercorarius       1.00      1.00      1.00        10
#                 Emus hirtus       1.00      1.00      1.00         4
#   Philonthus sanguinolentus       1.00      1.00      1.00        17
#       Neobisnius villosulus       1.00      1.00      1.00         7
#        Gabronthus thermarum       1.00      1.00      1.00         5
#            Quedius fulgidus       1.00      1.00      1.00         5
#         Philonthus ebeninus       1.00      0.83      0.91         6
#              Bisnius puella       0.64      1.00      0.78         7
#           Quedius lucidulus       0.75      0.88      0.81        17
#         Othius subuliformis       0.75      0.82      0.78        11
#        Philonthus laminatus       1.00      0.74      0.85        34
#            Quedius umbrinus       1.00      0.90      0.95        20
#        Ochthephilum collare       0.50      0.50      0.50         2
#             Ocypus fuscatus       0.38      0.75      0.50         8
#         Leptacinus pusillus       0.86      1.00      0.92         6
#          Lathrobium fovulum       0.96      0.90      0.93        29
#              Quedius brevis       1.00      0.88      0.93         8
#         Paederus littoralis       1.00      0.92      0.96        38
#             Achenium humile       1.00      1.00      1.00         8
#           Paederus fuscipes       0.93      1.00      0.97        28
#          Quedius truncicola       1.00      1.00      1.00         4
#        Quedius puncticollis       1.00      1.00      1.00        16
#             Quedius microps       0.95      1.00      0.98        21
#         Quedius longicornis       1.00      1.00      1.00        15
#       Quedius simplicifrons       0.54      1.00      0.70         7
#          Astenus pulchellus       0.80      0.96      0.87        25
#         Quedius mesomelinus       1.00      0.80      0.89        15
#      Dinothenarus pubescens       0.86      0.75      0.80         8
#        Xantholinus tricolor       0.82      1.00      0.90        14
#         Philonthus cognatus       0.98      0.91      0.95        70
#         Rugilus orbiculatus       0.96      0.92      0.94        59
#     Erichsonius cinerascens       1.00      1.00      1.00        36
#             Medon castaneus       1.00      1.00      1.00         9
#        Gabrius splendidulus       0.82      0.95      0.88        19
#     Platydracus latebricola       1.00      1.00      1.00         5
#             Rugilus rufipes       0.98      1.00      0.99        49
#       Creophilus maxillosus       1.00      0.89      0.94         9
#        Lathrobium elongatum       0.91      0.83      0.87        48
#      Philonthus micantoides       0.44      1.00      0.62         4
#    Xantholinus longiventris       0.80      0.73      0.76        11
#         Lathrobium pallidum       0.90      1.00      0.95         9
#       Sunius melanocephalus       0.92      0.96      0.94        23
#          Quedius molochinus       0.93      0.93      0.93        14
#           Gabrius trossulus       0.59      1.00      0.74        10
#      Heterothops dissimilis       1.00      0.14      0.25         7
#      Philonthus intermedius       0.64      0.93      0.76        15
#          Philonthus alpinus       1.00      0.50      0.67         4
#             Quedius picipes       0.92      1.00      0.96        12
#        Lathrobium impressum       0.98      0.98      0.98        54
#       Philonthus discoideus       0.91      1.00      0.95        20
#           Quedius nigriceps       1.00      1.00      1.00         9
#           Atrecus longiceps       1.00      1.00      1.00         5
#         Quedius curtipennis       1.00      0.71      0.83         7
#          Bisnius fimetarius       0.95      0.88      0.91        60
#          Lathrobium dilutum       0.67      1.00      0.80         2
#
#                   micro avg       0.89      0.89      0.89      3381
#                   macro avg       0.88      0.88      0.87      3381
#                weighted avg       0.91      0.89      0.89      3381

# %%
y_true = val_generator.classes
matplotlib.rcParams['figure.figsize'] = [10, 10]
plot_confusion_matrix(y_true, y_pred, np.array(labels))
# Out:
# Confusion matrix, without normalization
# [[23  0  0 ...  0  0  0]
#  [ 0 49  0 ...  0  0  0]
#  [ 0  0 33 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  5  0  0]
#  [ 0  0  0 ...  0 53  0]
#  [ 0  0  0 ...  0  0  2]]
# (<Figure size 720x720 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7ff07227e160>)

# %%
labels = (val_generator.class_indices) # dict of label:index
labels = dict((i,l) for l,i in labels.items()) # dict of index:label

# %%
# create pd.dataframe and save predictions to .csv
#filenames=[datasetDir + name for name in val_generator.filenames]
#y_pred_labels = [labels[y] for y in y_pred]
#y_true_labels = [labels[y] for y in y_true]
#y_pred3_labels = []
#for i,top3 in enumerate(y_pred3):
#    l = []
#    for top in top3:
#        l.append((labels[top], Y_pred[i][top]))
#    y_pred3_labels.append(l)
#
#results=pd.DataFrame({"Filename":filenames,
#                      "Label":y_true_labels,
#                      "Prediction1":y_pred_labels,
#                      "Prediction3":y_pred3_labels})
#results.to_csv(results_file,index=True)

# create pd.dataframe and save predictions to .csv
filenames=[datasetDir + name for name in val_generator.filenames]
y_pred_labels = [labels[y] for y in y_pred]
y_true_labels = [labels[y] for y in y_true]
y_pred3_labels_prob = []

for i,top3 in enumerate(y_pred3):
    l = []
    for top in top3:
        l.append(labels[top])
        l.append(Y_pred[i][top])
    y_pred3_labels_prob.append(l)
y_pred3_labels_prob = np.array(y_pred3_labels_prob)

results=pd.DataFrame({"Filename":filenames,
                      "Label":y_true_labels,
                      "Prediction1":y_pred_labels,
                      "Prediction3a":y_pred3_labels_prob[:,0],
                      "Prediction3a_prob":y_pred3_labels_prob[:,1],
                      "Prediction3b":y_pred3_labels_prob[:,2],
                      "Prediction3b_prob":y_pred3_labels_prob[:,3],
                      "Prediction3c":y_pred3_labels_prob[:,4],
                      "Prediction3c_prob":y_pred3_labels_prob[:,5],
                     })
results.to_csv(results_file,index=True)
