# %% [markdown]
# # Analysis of results

# %%
# %config IPCompleter.greedy=True
import pandas as pd
from subprocess import call

# %%
results = pd.read_csv('results.csv')

# %%
call(["mkdir", "misclassed_img"])
# Out:
# 0

# %%
misclassified = results.loc[results["Label"] != results["Prediction1"]]
del misclassified["Unnamed: 0"]
misclassified.to_csv("misclassified.csv")

# %%
misclassified
# Out:
#                                                Filename  \
# 14    images_species/Philonthus tenuicornis/Philonth...
# 21    images_species/Philonthus tenuicornis/Philonth...
# 24    images_species/Philonthus tenuicornis/Philonth...
# 26    images_species/Philonthus tenuicornis/Philonth...
# 98    images_species/Philonthus splendens/Philonthus...
# 110   images_species/Philonthus splendens/Philonthus...
# 170   images_species/Philonthus nitidicollis/Philont...
# 181   images_species/Lathrobium geminum/Lathrobium g...
# 183   images_species/Lathrobium geminum/Lathrobium g...
# 184   images_species/Lathrobium geminum/Lathrobium g...
# 187   images_species/Lathrobium geminum/Lathrobium g...
# 189   images_species/Lathrobium geminum/Lathrobium g...
# 190   images_species/Lathrobium geminum/Lathrobium g...
# 191   images_species/Lathrobium geminum/Lathrobium g...
# 211   images_species/Paederus riparius/Paederus ripa...
# 213   images_species/Paederus riparius/Paederus ripa...
# 260   images_species/Heterothops praevius/Heterothop...
# 271   images_species/Gabrius osseticus/Gabrius osset...
# 295   images_species/Philonthus carbonarius/Philonth...
# 297   images_species/Philonthus carbonarius/Philonth...
# 303   images_species/Philonthus carbonarius/Philonth...
# 304   images_species/Philonthus carbonarius/Philonth...
# 305   images_species/Philonthus carbonarius/Philonth...
# 306   images_species/Philonthus carbonarius/Philonth...
# 307   images_species/Philonthus carbonarius/Philonth...
# 308   images_species/Philonthus carbonarius/Philonth...
# 315   images_species/Philonthus carbonarius/Philonth...
# 323   images_species/Philonthus carbonarius/Philonth...
# 324   images_species/Philonthus carbonarius/Philonth...
# 325   images_species/Philonthus carbonarius/Philonth...
# ...                                                 ...
# 3074  images_species/Lathrobium elongatum/Lathrobium...
# 3078  images_species/Lathrobium elongatum/Lathrobium...
# 3081  images_species/Lathrobium elongatum/Lathrobium...
# 3082  images_species/Lathrobium elongatum/Lathrobium...
# 3093  images_species/Lathrobium elongatum/Lathrobium...
# 3103  images_species/Lathrobium elongatum/Lathrobium...
# 3119  images_species/Xantholinus longiventris/Xantho...
# 3122  images_species/Xantholinus longiventris/Xantho...
# 3124  images_species/Xantholinus longiventris/Xantho...
# 3141  images_species/Sunius melanocephalus/Sunius me...
# 3162  images_species/Quedius molochinus/Quedius molo...
# 3186  images_species/Heterothops dissimilis/Heteroth...
# 3187  images_species/Heterothops dissimilis/Heteroth...
# 3188  images_species/Heterothops dissimilis/Heteroth...
# 3190  images_species/Heterothops dissimilis/Heteroth...
# 3191  images_species/Heterothops dissimilis/Heteroth...
# 3192  images_species/Heterothops dissimilis/Heteroth...
# 3205  images_species/Philonthus intermedius/Philonth...
# 3209  images_species/Philonthus alpinus/Philonthus a...
# 3210  images_species/Philonthus alpinus/Philonthus a...
# 3264  images_species/Lathrobium impressum/Lathrobium...
# 3314  images_species/Quedius curtipennis/Quedius cur...
# 3315  images_species/Quedius curtipennis/Quedius cur...
# 3322  images_species/Bisnius fimetarius/Bisnius fime...
# 3356  images_species/Bisnius fimetarius/Bisnius fime...
# 3363  images_species/Bisnius fimetarius/Bisnius fime...
# 3370  images_species/Bisnius fimetarius/Bisnius fime...
# 3374  images_species/Bisnius fimetarius/Bisnius fime...
# 3377  images_species/Bisnius fimetarius/Bisnius fime...
# 3378  images_species/Bisnius fimetarius/Bisnius fime...
#
#                          Label                Prediction1  \
# 14      Philonthus tenuicornis        Philonthus addendus
# 21      Philonthus tenuicornis       Philonthus succicola
# 24      Philonthus tenuicornis       Philonthus succicola
# 26      Philonthus tenuicornis        Philonthus cognatus
# 98        Philonthus splendens            Ocypus fuscatus
# 110       Philonthus splendens            Ocypus fuscatus
# 170    Philonthus nitidicollis         Philonthus varians
# 181         Lathrobium geminum       Lathrobium brunnipes
# 183         Lathrobium geminum       Lathrobium elongatum
# 184         Lathrobium geminum       Lathrobium elongatum
# 187         Lathrobium geminum      Lathrobium fulvipenne
# 189         Lathrobium geminum       Lathrobium brunnipes
# 190         Lathrobium geminum      Lathrobium fulvipenne
# 191         Lathrobium geminum       Lathrobium elongatum
# 211          Paederus riparius          Paederus fuscipes
# 213          Paederus riparius          Paederus fuscipes
# 260       Heterothops praevius      Heterothops binotatus
# 271          Gabrius osseticus     Philonthus micantoides
# 295     Philonthus carbonarius         Bisnius fimetarius
# 297     Philonthus carbonarius      Philonthus cruentatus
# 303     Philonthus carbonarius         Philonthus albipes
# 304     Philonthus carbonarius           Bisnius sordidus
# 305     Philonthus carbonarius         Bisnius fimetarius
# 306     Philonthus carbonarius        Ontholestes murinus
# 307     Philonthus carbonarius       Philonthus concinnus
# 308     Philonthus carbonarius         Philonthus varians
# 315     Philonthus carbonarius         Philonthus varians
# 323     Philonthus carbonarius    Philonthus nitidicollis
# 324     Philonthus carbonarius  Philonthus quisquiliarius
# 325     Philonthus carbonarius     Philonthus mannerheimi
# ...                        ...                        ...
# 3074      Lathrobium elongatum    Lobrathium multipunctum
# 3078      Lathrobium elongatum         Lathrobium geminum
# 3081      Lathrobium elongatum       Lathrobium brunnipes
# 3082      Lathrobium elongatum       Lathrobium rufipenne
# 3093      Lathrobium elongatum       Lathrobium rufipenne
# 3103      Lathrobium elongatum      Lathrobium fulvipenne
# 3119  Xantholinus longiventris       Xantholinus linearis
# 3122  Xantholinus longiventris       Xantholinus linearis
# 3124  Xantholinus longiventris            Rugilus rufipes
# 3141     Sunius melanocephalus             Sunius bicolor
# 3162        Quedius molochinus            Quedius picipes
# 3186    Heterothops dissimilis      Heterothops binotatus
# 3187    Heterothops dissimilis      Heterothops binotatus
# 3188    Heterothops dissimilis      Heterothops binotatus
# 3190    Heterothops dissimilis      Heterothops binotatus
# 3191    Heterothops dissimilis      Heterothops binotatus
# 3192    Heterothops dissimilis      Heterothops binotatus
# 3205    Philonthus intermedius       Philonthus splendens
# 3209        Philonthus alpinus         Philonthus albipes
# 3210        Philonthus alpinus         Philonthus albipes
# 3264      Lathrobium impressum         Lathrobium fovulum
# 3314       Quedius curtipennis      Quedius simplicifrons
# 3315       Quedius curtipennis        Quedius fuliginosus
# 3322        Bisnius fimetarius             Bisnius puella
# 3356        Bisnius fimetarius         Bisnius cephalotes
# 3363        Bisnius fimetarius         Bisnius cephalotes
# 3370        Bisnius fimetarius  Philonthus quisquiliarius
# 3374        Bisnius fimetarius         Philonthus albipes
# 3377        Bisnius fimetarius         Bisnius cephalotes
# 3378        Bisnius fimetarius       Bisnius subuliformis
#
#                                             Prediction3
# 14    [('Philonthus politus', 0.0004480213), ('Philo...
# 21    [('Philonthus politus', 0.0031824687), ('Philo...
# 24    [('Philonthus politus', 0.00059488544), ('Phil...
# 26    [('Philonthus tenuicornis', 0.055816505), ('Ph...
# 98    [('Philonthus nitidus', 0.16886874), ('Philont...
# 110   [('Philonthus intermedius', 0.0858535), ('Phil...
# 170   [('Philonthus confinis', 0.017808542), ('Philo...
# 181   [('Lathrobium geminum', 0.06393067), ('Acheniu...
# 183   [('Lathrobium brunnipes', 0.0005637099), ('Lat...
# 184   [('Lathrobium geminum', 0.00023359522), ('Lath...
# 187   [('Lobrathium multipunctum', 0.0007002033), ('...
# 189   [('Lathrobium geminum', 0.0018479812), ('Lathr...
# 190   [('Philonthus lepidus', 2.0881359e-07), ('Lobr...
# 191   [('Lathrobium fulvipenne', 0.03852416), ('Lath...
# 211   [('Paederus littoralis', 0.00047978884), ('Pae...
# 213   [('Ocypus fuscatus', 0.002069202), ('Paederus ...
# 260   [('Heterothops dissimilis', 4.8416117e-05), ('...
# 271   [('Bisnius fimetarius', 0.18748167), ('Gabrius...
# 295   [('Philonthus atratus', 0.037186347), ('Philon...
# 297   [('Astenus lyonessius', 9.847185e-05), ('Philo...
# 303   [('Philonthus longicornis', 5.3802105e-05), ('...
# 304   [('Xantholinus longiventris', 2.0246942e-05), ...
# 305   [('Philonthus albipes', 8.886481e-07), ('Philo...
# 306   [('Philonthus carbonarius', 0.012072194), ('On...
# 307   [('Philonthus atratus', 0.001811413), ('Philon...
# 308   [('Philonthus carbonarius', 0.059880503), ('Ph...
# 315   [('Philonthus lepidus', 0.05700109), ('Heterot...
# 323   [('Philonthus carbonarius', 0.007958426), ('Ph...
# 324   [('Philonthus furcifer', 0.017511358), ('Bisni...
# 325   [('Philonthus albipes', 0.029337855), ('Philon...
# ...                                                 ...
# 3074  [('Lathrobium fulvipenne', 0.0011534782), ('La...
# 3078  [('Lathrobium elongatum', 0.10125505), ('Lathr...
# 3081  [('Lathrobium geminum', 0.005474405), ('Lathro...
# 3082  [('Astenus gracilis', 3.3513184e-05), ('Lathro...
# 3093  [('Astenus gracilis', 3.733543e-05), ('Lathrob...
# 3103  [('Lathrobium rufipenne', 0.0013990311), ('Lat...
# 3119  [('Gyrohypnus punctulatus', 0.00019927576), ('...
# 3122  [('Xantholinus laevigatus', 0.1253399), ('Xant...
# 3124  [('Lathrobium fulvipenne', 0.029165143), ('Rug...
# 3141  [('Medon brunneus', 9.681143e-05), ('Sunius me...
# 3162  [('Quedius simplicifrons', 0.0002278905), ('Qu...
# 3186  [('Heterothops praevius', 1.4236924e-05), ('He...
# 3187  [('Heterothops quadripunctulus', 4.602508e-06)...
# 3188  [('Heterothops quadripunctulus', 0.012971617),...
# 3190  [('Heterothops praevius', 2.9018695e-06), ('He...
# 3191  [('Heterothops praevius', 1.7083257e-06), ('He...
# 3192  [('Heterothops quadripunctulus', 3.0978143e-05...
# 3205  [('Philonthus addendus', 6.1238466e-06), ('Phi...
# 3209  [('Philonthus micantoides', 0.02459305), ('Phi...
# 3210  [('Philonthus micantoides', 6.5343247e-06), ('...
# 3264  [('Lathrobium impressum', 0.00036431535), ('La...
# 3314  [('Quedius nigrocaeruleus', 0.2103392), ('Qued...
# 3315  [('Euryporus picipes', 1.1496016e-05), ('Quedi...
# 3322  [('Philonthus corvinus', 0.01622984), ('Bisniu...
# 3356  [('Philonthus quisquiliarius', 0.021762598), (...
# 3363  [('Gyrohypnus atratus', 7.5703974e-06), ('Bisn...
# 3370  [('Bisnius sordidus', 0.0052979263), ('Bisnius...
# 3374  [('Heterothops praevius', 2.492033e-07), ('Het...
# 3377  [('Bisnius sordidus', 0.0010052208), ('Bisnius...
# 3378  [('Quedius cruentus', 0.0017713368), ('Bisnius...
#
# [361 rows x 4 columns]

# %% [markdown]
# ### Copy images of misclassified bettles to folder "misclassed_img"

# %%
for name in misclassified["Filename"]:
    im_name = name.split("/")[-1]  
    call(["cp", "../../../images/labeled_val/"+im_name, "./misclassed_img/"])

# %% [markdown]
# ### number of misclasses pr. species

# %%
misclassified['Label'].value_counts()
# Out:
# Gabrius nigritulus           23
# Philonthus politus           18
# Philonthus carbonarius       17
# Astenus lyonessius           14
# Philonthus succicola         12
# Astenus gracilis             10
# Philonthus laminatus          9
# Philonthus decorus            8
# Lathrobium elongatum          8
# Bisnius fimetarius            7
# Leptacinus batychrus          7
# Lathrobium geminum            7
# Philonthus jurgans            7
# Philonthus longicornis        7
# Gyrohypnus angustatus         6
# Heterothops dissimilis        6
# Philonthus atratus            6
# Philonthus addendus           6
# Philonthus cognatus           6
# Scopaeus sulcicollis          5
# Tasgius melanarius            5
# Rugilus orbiculatus           5
# Lathrobium fulvipenne         5
# Philonthus rufipes            5
# Quedius nitipennis            5
# Quedius scintillans           5
# Gyrohypnus fracticornis       4
# Othius angustus               4
# Quedius levicollis            4
# Philonthus ventralis          4
#                              ..
# Heterothops stiglundbergi     1
# Quedius brevis                1
# Bisnius parcus                1
# Leptacinus intermedius        1
# Philonthus ebeninus           1
# Philonthus varians            1
# Quedius infuscatus            1
# Gabrius appendiculatus        1
# Pseudomedon obsoletus         1
# Quedius nigrocaeruleus        1
# Quedius cruentus              1
# Ochthephilum fracticorne      1
# Gabrius keysianus             1
# Quedius maurus                1
# Philonthus rectangulus        1
# Philonthus mannerheimi        1
# Creophilus maxillosus         1
# Quedius molochinus            1
# Medon ripicola                1
# Nudobius lentus               1
# Philonthus nitidicollis       1
# Xantholinus gallicus          1
# Heterothops minutus           1
# Philonthus parvicornis        1
# Philonthus debilis            1
# Philonthus intermedius        1
# Heterothops praevius          1
# Gabrius exiguus               1
# Cafius xantholoma             1
# Sunius melanocephalus         1
# Name: Label, Length: 105, dtype: int64

# %% [markdown]
# ### Gabrius nigritulus: 23 misclasses

# %%
gab_ni = misclassified.loc[misclassified['Label'] == "Gabrius nigritulus"]
gab_ni['Prediction1'].value_counts()
# Out:
# Gabrius breviventer       12
# Gabrius trossulus          5
# Gabrius splendidulus       4
# Leptacinus intermedius     1
# Gabrius appendiculatus     1
# Name: Prediction1, dtype: int64

# %% [markdown]
# ### Philonthus politus: 18 misclasses

# %%
phi_po = misclassified.loc[misclassified['Label'] == "Philonthus politus"]
phi_po['Prediction1'].value_counts()
# Out:
# Philonthus succicola      7
# Bisnius cephalotes        5
# Ocypus fuscatus           2
# Philonthus tenuicornis    2
# Philonthus addendus       2
# Name: Prediction1, dtype: int64

# %% [markdown]
# ### Philonthus carbonarius: 17 misclasses

# %%
phi_ca = misclassified.loc[misclassified['Label'] == "Philonthus carbonarius"]
phi_ca['Prediction1'].value_counts()
# Out:
# Philonthus cruentatus        2
# Philonthus varians           2
# Philonthus quisquiliarius    2
# Bisnius fimetarius           2
# Philonthus concinnus         1
# Philonthus mannerheimi       1
# Philonthus nitidicollis      1
# Philonthus discoideus        1
# Philonthus tenuicornis       1
# Philonthus ventralis         1
# Bisnius sordidus             1
# Philonthus albipes           1
# Ontholestes murinus          1
# Name: Prediction1, dtype: int64

# %% [markdown]
# ### Astenus lyonessius: 14 misclasses

# %%
ast_ly = misclassified.loc[misclassified['Label'] == "Astenus lyonessius"]
ast_ly['Prediction1'].value_counts()
# Out:
# Astenus gracilis      13
# Astenus pulchellus     1
# Name: Prediction1, dtype: int64

# %% [markdown]
# ### Philonthus succicola: 12 misclasses

# %%
phi_suc = misclassified.loc[misclassified['Label'] == "Philonthus succicola"]
phi_suc['Prediction1'].value_counts()
# Out:
# Philonthus tenuicornis    7
# Philonthus politus        3
# Philonthus intermedius    1
# Philonthus mannerheimi    1
# Name: Prediction1, dtype: int64

# %% [markdown]
# ### Lathrobium elongatum: 8 misclasses

# %%
lath_el = misclassified.loc[misclassified['Label'] == "Lathrobium elongatum"]
lath_el['Prediction1'].value_counts()
# Out:
# Lathrobium geminum         2
# Lathrobium fulvipenne      2
# Lathrobium rufipenne       2
# Lathrobium brunnipes       1
# Lobrathium multipunctum    1
# Name: Prediction1, dtype: int64
