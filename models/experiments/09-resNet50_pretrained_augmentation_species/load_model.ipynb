# %%
# %config IPCompleter.greedy=True

# %%
import sys
import os
import pandas as pd
sys.path.append("../..") # relative path to module toolkit

# %%
#from keras.applications import ResNet50
#from keras.layers import Dense, GlobalAveragePooling2D
from keras.models import Model, load_model
from keras_preprocessing.image import ImageDataGenerator
from toolkit import getLabelsFromDir, plot_confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# setup
batch_size = 1
val_dir = "../../../images/images_species/val/"
val_images = 3381
datasetDir = "images_species/"
saved_model = 'highest_val_acc.h5'
results_file = "results.csv"

# %%
labels = getLabelsFromDir(val_dir)
val_datagen = ImageDataGenerator(rescale=1./255.)
validation_steps = int(val_images/batch_size)

# %%
model = load_model(saved_model)

# %%
val_generator = val_datagen.flow_from_directory(val_dir,
                                                    classes=labels,
                                                    class_mode="categorical",
                                                    batch_size=batch_size,
                                                    color_mode='rgb',
                                                    target_size=(224, 224),
                                                    shuffle=False,
                                                    seed=1)
# Out:
# Found 3381 images belonging to 200 classes.

# %%
Y_pred = model.predict_generator(val_generator, steps=validation_steps, verbose=1)
# Out:
# 3381/3381 [==============================] - 50s 15ms/step

# %%
y_pred = np.argmax(Y_pred, axis=1)
y_pred3 = [y[-3:] for y in np.argsort(Y_pred, axis=1)]

# %%
#print(classification_report(val_generator.classes, y_pred, target_names=labels))
print(classification_report(val_generator.classes, y_pred, target_names=labels))
# Out:
#                              precision    recall  f1-score   support
#
#      Philonthus tenuicornis       0.42      0.81      0.55        27
#       Paederidus ruficollis       1.00      1.00      1.00        49
#        Philonthus splendens       0.94      0.91      0.93        35
#     Pseudomedon obscurellus       1.00      0.90      0.95        29
#   Staphylinus erythropterus       1.00      0.88      0.93         8
#     Lobrathium multipunctum       0.88      1.00      0.94        22
#     Philonthus nitidicollis       1.00      0.50      0.67         2
#         Xantholinus dvoraki       0.56      0.71      0.63         7
#          Lathrobium geminum       0.81      0.72      0.76        18
#           Paederus riparius       1.00      0.91      0.95        56
#        Heterothops praevius       0.50      1.00      0.67        11
#           Gabrius osseticus       1.00      0.62      0.76        13
#      Philonthus carbonarius       0.96      0.76      0.85        71
#          Quedius semiaeneus       0.57      0.89      0.70         9
#           Cafius xantholoma       1.00      0.97      0.98        58
#          Othius punctulatus       1.00      1.00      1.00        11
#       Heterothops binotatus       0.42      0.53      0.47        15
#        Philonthus succicola       0.78      0.66      0.72        44
#      Philonthus rectangulus       0.94      1.00      0.97        16
#         Ocypus ophthalmicus       0.80      0.67      0.73         6
#          Quedius maurorufus       0.87      0.76      0.81        17
#           Quedius suturalis       0.88      0.88      0.88        16
#     Ontholestes tessellatus       1.00      1.00      1.00         7
#        Bisnius subuliformis       0.92      0.92      0.92        13
#          Philonthus lepidus       1.00      1.00      1.00        12
# Heterothops quadripunctulus       1.00      0.67      0.80        12
#         Philonthus addendus       0.74      0.78      0.76        18
#           Quedius auricomus       1.00      1.00      1.00        12
#          Philonthus punctus       0.78      0.88      0.82         8
#          Quedius levicollis       0.71      0.56      0.63         9
#                Ocypus olens       0.50      1.00      0.67         5
#        Ocypus aeneocephalus       0.90      1.00      0.95         9
#    Ochthephilum fracticorne       0.95      0.95      0.95        37
#              Quedius scitus       0.64      1.00      0.78         9
#      Philonthus mannerheimi       0.59      0.91      0.71        11
#  Acylophorus wagenschieberi       1.00      1.00      1.00         8
#        Astenus immacullatus       0.96      1.00      0.98        26
#         Quedius brevicornis       0.85      0.85      0.85        13
#         Quedius fuliginosus       0.77      0.71      0.74        14
#      Tetartopeus terminatus       0.96      0.98      0.97        45
#        Platydracus fulvipes       0.86      0.86      0.86         7
#       Philonthus cruentatus       0.80      1.00      0.89         8
#         Quedius scintillans       0.79      0.83      0.81        18
#         Megalinus glabratus       1.00      1.00      1.00         7
#           Heterothops niger       1.00      0.89      0.94         9
#           Quedius lateralis       0.85      0.92      0.88        12
#        Philonthus corruscus       1.00      1.00      1.00         4
#           Tasgius morsitans       0.82      1.00      0.90         9
#              Medon ripicola       0.93      0.81      0.87        16
#      Gyrohypnus punctulatus       0.65      0.65      0.65        17
#             Quedius cinctus       0.87      0.93      0.90        14
#      Philonthus longicornis       0.86      0.38      0.52        16
#            Astenus gracilis       0.50      0.37      0.42        19
#        Lathrobium brunnipes       0.98      0.95      0.96        58
#        Bisnius pseudoparcus       1.00      1.00      1.00         5
#          Quedius infuscatus       1.00      1.00      1.00         4
#              Quedius maurus       0.73      0.80      0.76        10
#          Quedius persimilis       0.71      0.83      0.77        12
#         Gabrius breviventer       0.86      0.35      0.50        17
#            Scopaeus minutus       0.83      1.00      0.90        19
#            Bisnius sordidus       0.93      0.84      0.88        50
#               Ocypus nitens       0.82      0.69      0.75        13
#          Tasgius melanarius       0.88      0.64      0.74        11
#        Gauropterus fulgidus       1.00      1.00      1.00        14
#        Xantholinus gallicus       0.40      1.00      0.57         2
#          Gabrius nigritulus       1.00      0.08      0.14        26
#       Philonthus marginatus       0.97      1.00      0.99        33
#      Philonthus rubripennis       0.85      1.00      0.92        17
#       Lathrobium fulvipenne       0.92      0.94      0.93        49
#              Sunius bicolor       0.82      1.00      0.90        18
#          Tasgius globulifer       0.50      1.00      0.67         5
#            Astenus procerus       1.00      1.00      1.00        15
#      Gabrius appendiculatus       0.67      0.67      0.67        12
#          Philonthus rufipes       0.78      0.58      0.67        12
#               Quedius boops       0.57      0.57      0.57         7
#            Quedius cruentus       0.89      0.84      0.86        19
#          Velleius dilatatus       1.00      1.00      1.00         5
#    Neobisnius lathrobioides       1.00      1.00      1.00        30
#         Quedius fulvicollis       0.67      1.00      0.80         2
#              Medon brunneus       0.76      1.00      0.86        16
#          Philonthus jurgans       0.18      0.38      0.24         8
#        Scopaeus sulcicollis       1.00      0.88      0.94        17
#   Philonthus quisquiliarius       0.85      0.85      0.85        13
#       Gyrohypnus angustatus       0.78      0.78      0.78         9
#       Staphylinus caesareus       0.75      0.60      0.67         5
#           Quedius xanthopus       0.82      0.90      0.86        20
#        Lithocharis ochracea       0.97      0.97      0.97        39
#              Bisnius parcus       0.70      1.00      0.82         7
#        Philonthus binotatus       0.67      0.50      0.57         4
#      Quedius nigrocaeruleus       0.57      1.00      0.73         4
#       Pseudomedon obsoletus       0.80      1.00      0.89        12
#          Philonthus varians       0.77      0.77      0.77        13
#          Gyrohypnus atratus       0.91      1.00      0.95        10
#         Ontholestes murinus       0.91      0.91      0.91        11
#      Xantholinus laevigatus       1.00      0.17      0.29         6
#         Philonthus corvinus       0.78      0.88      0.82         8
#        Quedius semiobscurus       0.73      1.00      0.84         8
#   Heterothops stiglundbergi       1.00      0.67      0.80         3
#        Philonthus concinnus       0.81      0.93      0.87        14
#          Philonthus nigrita       0.91      0.91      0.91        11
#             Nudobius lentus       1.00      0.93      0.96        14
#          Philonthus debilis       0.80      1.00      0.89        20
#       Lithocharis nigriceps       0.94      0.94      0.94        16
#         Philonthus furcifer       1.00      0.50      0.67         8
#         Philonthus confinis       0.50      1.00      0.67         3
#          Bisnius cephalotes       0.67      0.86      0.75        35
#         Philonthus fumarius       1.00      1.00      1.00        16
#        Lathrobium rufipenne       0.85      1.00      0.92        22
#           Ocypus picipennis       1.00      0.91      0.95        11
#          Astenus lyonessius       0.69      0.60      0.64        30
#            Ocypus brunnipes       1.00      1.00      1.00        11
#           Rugilus erichsoni       0.93      0.87      0.90        31
#             Atrecus affinis       0.90      1.00      0.95         9
#           Bisnius nitidulus       1.00      0.93      0.96        28
#         Scopaeus laevigatus       1.00      1.00      1.00         2
#      Philonthus parvicornis       1.00      0.56      0.71         9
#          Philonthus politus       1.00      0.39      0.56        51
#             Othius angustus       0.81      0.72      0.76        18
#        Philonthus ventralis       0.58      0.64      0.61        11
#         Heterothops minutus       1.00      0.83      0.91         6
#           Philonthus micans       0.94      0.94      0.94        18
#          Quedius nitipennis       1.00      0.38      0.55        16
#     Acylophorus glaberrimus       1.00      1.00      1.00        12
#              Medon apicalis       1.00      0.92      0.96        12
#     Leptacinus formicetorum       0.80      1.00      0.89         8
#     Gyrohypnus fracticornis       0.75      0.60      0.67        15
#           Gabrius keysianus       1.00      0.62      0.77         8
#       Tetartopeus quadratus       0.97      0.97      0.97        35
#          Philonthus salinus       1.00      0.85      0.92        13
#          Philonthus albipes       0.81      0.83      0.82        30
#      Leptacinus intermedius       0.35      1.00      0.52         6
# Staphylinus dimidiaticornis       0.67      1.00      0.80         4
#           Euryporus picipes       0.80      1.00      0.89         8
#          Philonthus nitidus       1.00      1.00      1.00        32
#           Quedius boopoides       0.56      0.83      0.67         6
#                Tasgius ater       1.00      1.00      1.00         7
#        Leptacinus batychrus       0.78      0.32      0.45        22
#          Gabrius austriacus       0.14      1.00      0.25         6
#          Philonthus decorus       0.90      0.80      0.85        45
#             Quedius fumatus       0.94      1.00      0.97        16
#        Xantholinus linearis       0.79      0.92      0.85        12
#          Philonthus atratus       0.88      0.85      0.87        34
# Phacophallus parumpunctatus       1.00      0.83      0.91         6
#             Gabrius exiguus       0.00      0.00      0.00         3
#              Remus sericeus       1.00      1.00      1.00        24
#    Platydracus stercorarius       1.00      1.00      1.00        10
#                 Emus hirtus       1.00      1.00      1.00         4
#   Philonthus sanguinolentus       0.94      1.00      0.97        17
#       Neobisnius villosulus       0.86      0.86      0.86         7
#        Gabronthus thermarum       0.56      1.00      0.71         5
#            Quedius fulgidus       1.00      0.80      0.89         5
#         Philonthus ebeninus       0.86      1.00      0.92         6
#              Bisnius puella       0.88      1.00      0.93         7
#           Quedius lucidulus       0.81      0.76      0.79        17
#         Othius subuliformis       0.67      0.91      0.77        11
#        Philonthus laminatus       0.96      0.79      0.87        34
#            Quedius umbrinus       0.95      0.95      0.95        20
#        Ochthephilum collare       0.50      0.50      0.50         2
#             Ocypus fuscatus       0.32      0.75      0.44         8
#         Leptacinus pusillus       0.60      1.00      0.75         6
#          Lathrobium fovulum       0.96      0.83      0.89        29
#              Quedius brevis       1.00      0.62      0.77         8
#         Paederus littoralis       0.95      1.00      0.97        38
#             Achenium humile       1.00      1.00      1.00         8
#           Paederus fuscipes       0.93      1.00      0.97        28
#          Quedius truncicola       0.33      1.00      0.50         4
#        Quedius puncticollis       0.93      0.81      0.87        16
#             Quedius microps       0.95      1.00      0.98        21
#         Quedius longicornis       0.94      1.00      0.97        15
#       Quedius simplicifrons       0.58      1.00      0.74         7
#          Astenus pulchellus       0.73      0.96      0.83        25
#         Quedius mesomelinus       1.00      0.33      0.50        15
#      Dinothenarus pubescens       1.00      1.00      1.00         8
#        Xantholinus tricolor       0.93      0.93      0.93        14
#         Philonthus cognatus       0.98      0.86      0.92        70
#         Rugilus orbiculatus       0.92      0.92      0.92        59
#     Erichsonius cinerascens       1.00      1.00      1.00        36
#             Medon castaneus       1.00      1.00      1.00         9
#        Gabrius splendidulus       0.78      0.95      0.86        19
#     Platydracus latebricola       1.00      1.00      1.00         5
#             Rugilus rufipes       0.98      1.00      0.99        49
#       Creophilus maxillosus       1.00      1.00      1.00         9
#        Lathrobium elongatum       0.93      0.83      0.88        48
#      Philonthus micantoides       0.43      0.75      0.55         4
#    Xantholinus longiventris       1.00      0.64      0.78        11
#         Lathrobium pallidum       0.69      1.00      0.82         9
#       Sunius melanocephalus       0.95      0.78      0.86        23
#          Quedius molochinus       1.00      0.57      0.73        14
#           Gabrius trossulus       1.00      0.80      0.89        10
#      Heterothops dissimilis       1.00      0.29      0.44         7
#      Philonthus intermedius       0.74      0.93      0.82        15
#          Philonthus alpinus       0.67      0.50      0.57         4
#             Quedius picipes       0.92      1.00      0.96        12
#        Lathrobium impressum       0.98      0.93      0.95        54
#       Philonthus discoideus       1.00      1.00      1.00        20
#           Quedius nigriceps       1.00      1.00      1.00         9
#           Atrecus longiceps       0.71      1.00      0.83         5
#         Quedius curtipennis       0.62      0.71      0.67         7
#          Bisnius fimetarius       0.94      0.85      0.89        60
#          Lathrobium dilutum       1.00      1.00      1.00         2
#
#                   micro avg       0.85      0.85      0.85      3381
#                   macro avg       0.84      0.85      0.82      3381
#                weighted avg       0.89      0.85      0.85      3381

# %%
y_true = val_generator.classes
matplotlib.rcParams['figure.figsize'] = [10, 10]
plot_confusion_matrix(y_true, y_pred, np.array(labels))
# Out:
# Confusion matrix, without normalization
# [[22  0  0 ...  0  0  0]
#  [ 0 49  0 ...  0  0  0]
#  [ 1  0 32 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  5  0  0]
#  [ 0  0  0 ...  0 51  0]
#  [ 0  0  0 ...  0  0  2]]
# (<Figure size 720x720 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7faa78fc8128>)

# %%
labels = (val_generator.class_indices) # dict of label:index
labels = dict((i,l) for l,i in labels.items()) # dict of index:label

# %%
# create pd.dataframe and save predictions to .csv
filenames=[datasetDir + name for name in val_generator.filenames]
y_pred_labels = [labels[y] for y in y_pred]
y_true_labels = [labels[y] for y in y_true]
y_pred3_labels = []
for i,top3 in enumerate(y_pred3):
    l = []
    for top in top3:
        l.append((labels[top], Y_pred[i][top]))
    y_pred3_labels.append(l)

results=pd.DataFrame({"Filename":filenames,
                      "Label":y_true_labels,
                      "Prediction1":y_pred_labels,
                      "Prediction3":y_pred3_labels})
results.to_csv(results_file,index=True)
