# %%
# %config IPCompleter.greedy=True

# %%
import sys
import os
import pandas as pd
sys.path.append("../..") # relative path to module toolkit

# %%
#from keras.applications import ResNet50
#from keras.layers import Dense, GlobalAveragePooling2D
from keras.models import Model, load_model
from keras_preprocessing.image import ImageDataGenerator
from toolkit import getLabelsFromDir, plot_confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# tf.estimator package not installed.
# tf.estimator package not installed.

# %%
# setup
batch_size = 1
val_dir = "../../../images/images_species/val/"
val_images = 3381
datasetDir = "images_species/"
saved_model = 'highest_val_acc.h5'
results_file = "results.csv"

# %%
labels = getLabelsFromDir(val_dir)
val_datagen = ImageDataGenerator(rescale=1./255.)
validation_steps = int(val_images/batch_size)

# %%
model = load_model(saved_model)

# %%
val_generator = val_datagen.flow_from_directory(val_dir,
                                                    classes=labels,
                                                    class_mode="categorical",
                                                    batch_size=batch_size,
                                                    color_mode='rgb',
                                                    target_size=(224, 224),
                                                    shuffle=False,
                                                    seed=1)
# Out:
# Found 3381 images belonging to 200 classes.

# %%
Y_pred = model.predict_generator(val_generator, steps=validation_steps, verbose=1)
# Out:
# 3381/3381 [==============================] - 88s 26ms/step

# %%
y_pred = np.argmax(Y_pred, axis=1)
y_pred3 = [y[-3:] for y in np.argsort(Y_pred, axis=1)]

# %%
#print(classification_report(val_generator.classes, y_pred, target_names=labels))
print(classification_report(val_generator.classes, y_pred, target_names=labels))
# Out:
#                              precision    recall  f1-score   support
#
#             Achenium humile       1.00      1.00      1.00         8
#     Acylophorus glaberrimus       0.92      1.00      0.96        12
#  Acylophorus wagenschieberi       1.00      1.00      1.00         8
#            Astenus gracilis       0.57      0.63      0.60        19
#        Astenus immacullatus       1.00      1.00      1.00        26
#          Astenus lyonessius       0.73      0.53      0.62        30
#            Astenus procerus       1.00      0.93      0.97        15
#          Astenus pulchellus       0.72      0.92      0.81        25
#             Atrecus affinis       1.00      1.00      1.00         9
#           Atrecus longiceps       1.00      1.00      1.00         5
#          Bisnius cephalotes       0.74      0.91      0.82        35
#          Bisnius fimetarius       0.86      0.83      0.85        60
#           Bisnius nitidulus       1.00      0.96      0.98        28
#              Bisnius parcus       1.00      0.71      0.83         7
#        Bisnius pseudoparcus       0.60      0.60      0.60         5
#              Bisnius puella       1.00      1.00      1.00         7
#        Bisnius subuliformis       0.93      1.00      0.96        13
#           Cafius xantholoma       0.98      0.98      0.98        58
#       Creophilus maxillosus       1.00      1.00      1.00         9
#      Dinothenarus pubescens       1.00      0.88      0.93         8
#                 Emus hirtus       1.00      1.00      1.00         4
#     Erichsonius cinerascens       0.92      1.00      0.96        36
#           Euryporus picipes       0.78      0.88      0.82         8
#      Gabrius appendiculatus       0.69      0.92      0.79        12
#          Gabrius austriacus       0.33      0.33      0.33         6
#         Gabrius breviventer       0.50      0.71      0.59        17
#             Gabrius exiguus       0.00      0.00      0.00         3
#           Gabrius keysianus       1.00      0.88      0.93         8
#          Gabrius nigritulus       0.88      0.27      0.41        26
#           Gabrius osseticus       1.00      1.00      1.00        13
#        Gabrius splendidulus       0.77      0.89      0.83        19
#           Gabrius trossulus       0.75      0.90      0.82        10
#        Gauropterus fulgidus       0.93      1.00      0.97        14
#       Gyrohypnus angustatus       1.00      0.78      0.88         9
#          Gyrohypnus atratus       1.00      0.80      0.89        10
#     Gyrohypnus fracticornis       0.69      0.73      0.71        15
#      Gyrohypnus punctulatus       0.60      0.53      0.56        17
#       Heterothops binotatus       0.67      0.67      0.67        15
#      Heterothops dissimilis       0.40      0.29      0.33         7
#         Heterothops minutus       0.83      0.83      0.83         6
#           Heterothops niger       0.78      0.78      0.78         9
#        Heterothops praevius       0.69      1.00      0.81        11
# Heterothops quadripunctulus       1.00      1.00      1.00        12
#   Heterothops stiglundbergi       1.00      1.00      1.00         3
#        Lathrobium brunnipes       0.98      0.86      0.92        58
#          Lathrobium dilutum       1.00      0.50      0.67         2
#        Lathrobium elongatum       0.81      0.81      0.81        48
#          Lathrobium fovulum       0.83      0.86      0.85        29
#          Lathrobium geminum       0.53      0.44      0.48        18
#        Lathrobium impressum       0.98      0.96      0.97        54
#         Lathrobium pallidum       0.75      1.00      0.86         9
#        Lathrobium rufipenne       0.81      1.00      0.90        22
#        Leptacinus batychrus       0.94      0.68      0.79        22
#     Leptacinus formicetorum       0.89      1.00      0.94         8
#      Leptacinus intermedius       0.42      0.83      0.56         6
#         Leptacinus pusillus       0.83      0.83      0.83         6
#       Lithocharis nigriceps       0.73      1.00      0.84        16
#        Lithocharis ochracea       1.00      0.90      0.95        39
#     Lobrathium multipunctum       0.81      0.95      0.88        22
#              Medon apicalis       0.69      0.75      0.72        12
#              Medon brunneus       0.89      1.00      0.94        16
#             Medon castaneus       1.00      1.00      1.00         9
#              Medon ripicola       0.79      0.69      0.73        16
#         Megalinus glabratus       1.00      1.00      1.00         7
#            Bisnius sordidus       0.83      0.86      0.84        50
#        Gabronthus thermarum       0.62      1.00      0.77         5
#       Lathrobium fulvipenne       0.93      0.88      0.91        49
#    Neobisnius lathrobioides       1.00      0.97      0.98        30
#       Paederidus ruficollis       1.00      1.00      1.00        49
#          Philonthus debilis       0.82      0.90      0.86        20
#          Philonthus nitidus       0.97      0.97      0.97        32
#    Platydracus stercorarius       0.91      1.00      0.95        10
#          Quedius levicollis       1.00      0.67      0.80         9
#        Quedius semiobscurus       0.67      1.00      0.80         8
#       Neobisnius villosulus       1.00      1.00      1.00         7
#             Nudobius lentus       1.00      0.93      0.96        14
#        Ochthephilum collare       1.00      0.50      0.67         2
#    Ochthephilum fracticorne       0.92      0.92      0.92        37
#        Ocypus aeneocephalus       1.00      1.00      1.00         9
#            Ocypus brunnipes       1.00      0.91      0.95        11
#             Ocypus fuscatus       1.00      0.75      0.86         8
#               Ocypus nitens       0.86      0.92      0.89        13
#                Ocypus olens       0.71      1.00      0.83         5
#         Ocypus ophthalmicus       1.00      0.50      0.67         6
#           Ocypus picipennis       1.00      1.00      1.00        11
#         Ontholestes murinus       0.83      0.91      0.87        11
#     Ontholestes tessellatus       0.78      1.00      0.88         7
#             Othius angustus       1.00      0.72      0.84        18
#          Othius punctulatus       1.00      1.00      1.00        11
#         Othius subuliformis       0.69      1.00      0.81        11
#           Paederus fuscipes       0.97      1.00      0.98        28
#         Paederus littoralis       0.97      1.00      0.99        38
#           Paederus riparius       1.00      0.96      0.98        56
# Phacophallus parumpunctatus       0.71      0.83      0.77         6
#         Philonthus addendus       0.69      0.61      0.65        18
#          Philonthus albipes       0.82      0.90      0.86        30
#          Philonthus alpinus       1.00      0.25      0.40         4
#          Philonthus atratus       0.82      0.82      0.82        34
#        Philonthus binotatus       0.00      0.00      0.00         4
#      Philonthus carbonarius       0.91      0.70      0.79        71
#         Philonthus cognatus       0.97      0.93      0.95        70
#        Philonthus concinnus       0.62      0.71      0.67        14
#         Philonthus confinis       0.38      1.00      0.55         3
#        Philonthus corruscus       1.00      1.00      1.00         4
#         Philonthus corvinus       0.47      0.88      0.61         8
#       Philonthus cruentatus       0.62      1.00      0.76         8
#          Philonthus decorus       0.93      0.91      0.92        45
#       Philonthus discoideus       0.95      1.00      0.98        20
#         Philonthus ebeninus       0.75      0.50      0.60         6
#         Philonthus fumarius       1.00      1.00      1.00        16
#         Philonthus furcifer       0.80      0.50      0.62         8
#      Philonthus intermedius       0.72      0.87      0.79        15
#          Philonthus jurgans       0.00      0.00      0.00         8
#        Philonthus laminatus       0.97      0.94      0.96        34
#          Philonthus lepidus       1.00      1.00      1.00        12
#      Philonthus longicornis       0.75      0.94      0.83        16
#      Philonthus mannerheimi       0.80      0.73      0.76        11
#       Philonthus marginatus       1.00      1.00      1.00        33
#           Philonthus micans       1.00      0.89      0.94        18
#      Philonthus micantoides       0.75      0.75      0.75         4
#          Philonthus nigrita       0.91      0.91      0.91        11
#     Philonthus nitidicollis       1.00      0.50      0.67         2
#      Philonthus parvicornis       0.62      0.89      0.73         9
#          Philonthus politus       0.87      0.67      0.76        51
#          Philonthus punctus       0.54      0.88      0.67         8
#   Philonthus quisquiliarius       0.77      0.77      0.77        13
#      Philonthus rectangulus       0.80      1.00      0.89        16
#      Philonthus rubripennis       0.81      1.00      0.89        17
#          Philonthus rufipes       0.75      0.50      0.60        12
#          Philonthus salinus       1.00      0.85      0.92        13
#   Philonthus sanguinolentus       1.00      1.00      1.00        17
#        Philonthus splendens       0.97      0.94      0.96        35
#        Philonthus succicola       0.67      0.68      0.67        44
#      Philonthus tenuicornis       0.56      0.56      0.56        27
#          Philonthus varians       0.57      0.62      0.59        13
#        Philonthus ventralis       0.78      0.64      0.70        11
#        Platydracus fulvipes       1.00      0.86      0.92         7
#     Platydracus latebricola       1.00      0.80      0.89         5
#     Pseudomedon obscurellus       0.97      0.97      0.97        29
#       Pseudomedon obsoletus       0.86      1.00      0.92        12
#           Quedius auricomus       1.00      1.00      1.00        12
#           Quedius boopoides       0.75      1.00      0.86         6
#               Quedius boops       0.40      0.57      0.47         7
#         Quedius brevicornis       0.48      0.77      0.59        13
#              Quedius brevis       0.88      0.88      0.88         8
#             Quedius cinctus       0.87      0.93      0.90        14
#            Quedius cruentus       0.90      0.95      0.92        19
#         Quedius curtipennis       0.50      0.71      0.59         7
#            Quedius fulgidus       1.00      1.00      1.00         5
#         Quedius fuliginosus       0.83      0.71      0.77        14
#         Quedius fulvicollis       1.00      1.00      1.00         2
#             Quedius fumatus       0.93      0.88      0.90        16
#          Quedius infuscatus       1.00      1.00      1.00         4
#           Quedius lateralis       0.75      1.00      0.86        12
#         Quedius longicornis       0.83      1.00      0.91        15
#           Quedius lucidulus       0.79      0.88      0.83        17
#          Quedius maurorufus       0.75      0.71      0.73        17
#              Quedius maurus       0.56      0.50      0.53        10
#         Quedius mesomelinus       0.75      0.40      0.52        15
#             Quedius microps       1.00      1.00      1.00        21
#          Quedius molochinus       0.93      0.93      0.93        14
#           Quedius nigriceps       1.00      1.00      1.00         9
#      Quedius nigrocaeruleus       0.57      1.00      0.73         4
#          Quedius nitipennis       1.00      0.25      0.40        16
#          Quedius persimilis       0.67      0.67      0.67        12
#             Quedius picipes       1.00      0.92      0.96        12
#        Quedius puncticollis       0.83      0.31      0.45        16
#         Quedius scintillans       0.82      0.78      0.80        18
#              Quedius scitus       1.00      1.00      1.00         9
#          Quedius semiaeneus       0.82      1.00      0.90         9
#       Quedius simplicifrons       0.75      0.86      0.80         7
#           Quedius suturalis       0.88      0.94      0.91        16
#          Quedius truncicola       0.80      1.00      0.89         4
#            Quedius umbrinus       0.74      0.85      0.79        20
#           Quedius xanthopus       0.83      0.95      0.88        20
#              Remus sericeus       1.00      1.00      1.00        24
#           Rugilus erichsoni       0.84      0.87      0.86        31
#         Rugilus orbiculatus       0.93      0.90      0.91        59
#             Rugilus rufipes       0.98      1.00      0.99        49
#         Scopaeus laevigatus       1.00      1.00      1.00         2
#            Scopaeus minutus       0.89      0.84      0.86        19
#        Scopaeus sulcicollis       0.83      0.88      0.86        17
#       Staphylinus caesareus       0.80      0.80      0.80         5
# Staphylinus dimidiaticornis       1.00      1.00      1.00         4
#   Staphylinus erythropterus       0.88      0.88      0.88         8
#              Sunius bicolor       0.83      0.56      0.67        18
#       Sunius melanocephalus       0.75      0.91      0.82        23
#                Tasgius ater       0.75      0.86      0.80         7
#          Tasgius globulifer       0.83      1.00      0.91         5
#          Tasgius melanarius       0.90      0.82      0.86        11
#           Tasgius morsitans       0.90      1.00      0.95         9
#       Tetartopeus quadratus       0.97      0.97      0.97        35
#      Tetartopeus terminatus       0.96      0.98      0.97        45
#          Velleius dilatatus       1.00      1.00      1.00         5
#         Xantholinus dvoraki       0.78      1.00      0.88         7
#        Xantholinus gallicus       0.00      0.00      0.00         2
#      Xantholinus laevigatus       0.83      0.83      0.83         6
#        Xantholinus linearis       0.80      0.67      0.73        12
#    Xantholinus longiventris       0.64      0.82      0.72        11
#        Xantholinus tricolor       1.00      0.93      0.96        14
#
#                   micro avg       0.86      0.86      0.86      3381
#                   macro avg       0.83      0.83      0.82      3381
#                weighted avg       0.87      0.86      0.85      3381
# /usr/local/lib/python2.7/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
y_true = val_generator.classes
matplotlib.rcParams['figure.figsize'] = [10, 10]
plot_confusion_matrix(y_true, y_pred, np.array(labels))
# Out:
# Confusion matrix, without normalization
# [[ 8  0  0 ...,  0  0  0]
#  [ 0 12  0 ...,  0  0  0]
#  [ 0  0  8 ...,  0  0  0]
#  ...,
#  [ 0  0  0 ...,  8  2  0]
#  [ 0  0  0 ...,  1  9  0]
#  [ 0  0  0 ...,  0  0 13]]
# (<matplotlib.figure.Figure at 0x7f66e9de5810>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f66c6ff8ed0>)

# %%
labels = (val_generator.class_indices) # dict of label:index
labels = dict((i,l) for l,i in labels.items()) # dict of index:label

# %%
# create pd.dataframe and save predictions to .csv
filenames=[datasetDir + name for name in val_generator.filenames]
y_pred_labels = [labels[y] for y in y_pred]
y_true_labels = [labels[y] for y in y_true]
y_pred3_labels = []
for i,top3 in enumerate(y_pred3):
    l = []
    for top in top3:
        l.append((labels[top], Y_pred[i][top]))
    y_pred3_labels.append(l)

results=pd.DataFrame({"Filename":filenames,
                      "Label":y_true_labels,
                      "Prediction1":y_pred_labels,
                      "Prediction3":y_pred3_labels})
results.to_csv(results_file,index=True)
